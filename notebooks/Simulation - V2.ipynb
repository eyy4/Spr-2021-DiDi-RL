# %%
import numpy as np
import pandas as pd 
import datetime as dt
from datetime import timedelta 
import random

# %%
class Driver: 
    

    
    def __init__(self, time, location, total_fare, total_cost, is_idle ):
        self.time = time 
        self.location = location 
        self.total_fare = total_fare
        self.total_cost  = total_cost
        self.is_idle = is_idle
    
    def set_time(self, new_time):
        self.time = new_time
    
    def get_time(self):
        return self.__time 
    
    def set_location(self, new_location):
        self.location = new_location
        
    def get_location(self):
        return self.__location 
   
    def set_total_fare(self, new_fare):
        self.total_fare = new_fare
    
    def get_total_fare(self):
        return self.total_fare 
    
    def set_is_idle(self, is_idle):
        self.is_idle = is_idle 
        
    def set_total_cost(self, new_cost):
        self.total_cost = new_cost
    
    def get_total_cost(self):
        return self.total_cost 
    
    def get_shift_time_weekday(self):


        weekend = [5,6]
        weekend_ind = lambda n: 0 if n in weekend else 1
        weekday = weekend_ind(self.time.weekday)

        normtime = driver.time.time()
        roundtime = pd.Timestamp(driver.time).round('30min').time()
        
        
        if weekday:
            if (normtime > dt.time(23, 30)) | (normtime <= dt.time(11, 30)):
                return ('A', roundtime,weekday)
            else:
                return ('B', roundtime,weekday)
        else: ## weekend
            if (normtime > dt.time(2, 0)) & (normtime <= dt.time(14, 0)):
                return ('A', roundtime,weekday)
            else:
                return ('B', roundtime,weekday)

# %%
class Env: 
    
    
    arrivals = pd.read_csv('../data/arrival_rates.csv')[['taxi_zone', 'time_stamp','arr_weekday','arr_weekend']]
    dropoff_counts = pd.read_csv('../data/pickup_dropoff_summary.csv')
    fare_df = pd.read_csv('../data/fare_amount_scr_dst_t.csv')
    dist_df = pd.read_csv('../data/trip_distance_scr_dst.csv')
    trip_time_df = pd.read_csv('../data/trip_time_scr_dst_t.csv')
    prob_df = pd.read_csv('../data/prob_match_combined_new.csv')
    trans_matrix = pd.read_csv('../data/dropoff_after_pickup.csv') # fix this to shift based and a
     # 0 weekend , A night shift 
    
    #time in 1..48,  isWeekday is a boolean
    def __init__(self,  isWeekday):   

        self.isWeekday = isWeekday 
        
    
    def is_matched(self, matching_prob):
        n = random.random()

        if n <= matching_prob:
            return True 
        else: 
            False 
    
    def get_destination(self, zone):
        prob = self.trans_matrix.iloc[zone-1].values[1:]
        n = random.random()

        count = 0
        for i in range(len(prob)):
            count = count + prob[i]
            if n<count:
                return i+1

    def get_adjacent_zone( self, taxi_zone ):
        df = pd.read_csv('../data/adjacent_zone.csv')
        adj_zone_1 = df.loc[df["zone1"]==taxi_zone, "zone2"].values.tolist()
        adj_zone_2 = df.loc[df["zone2"]==taxi_zone, "zone1"].values.tolist()
        adj_zone_list = list(filter(None, adj_zone_1+adj_zone_2))
        return(adj_zone_list)
    
    def get_demand(self, zone, time):
        #row = self.arrivals.loc[ ( self.arrivals['taxi_zone'] == zone ) & (self.arrivals['time_stamp'] == time ) ]
        row = self.prob_df.loc[ ( self.arrivals['taxi_zone'] == zone ) & (self.arrivals['time_stamp'] == time ) ]
       
        if self.isWeekday:
            return row['arr_weekday'].values[0]
        else:
            return row['arr_weekend'].values[0]
    
#  def get_near_arrival():
    
    
    '''TODO： 
        fix policy fucntion - add randomness'''
    
    def reposition_to( self, current_zone, time ):
        #adj = self.get_adjacent_zone( current_zone )
        #adj.append( current_zone )
        #demand_list = [self.get_demand(zone, time) for zone in adj]
        #print(demand_list)
        # find the index of the max value of demand_lisy, and find which zone it is
        #return adj[demand_list.index( max(demand_list))]  
    
         
        adj = self.get_adjacent_zone( current_zone )
        adj.insert(0,current_zone)
        # find the index of the max value of near_prob, and find which zone it is 
        demand_list = [self.get_demand(zone, time) for zone in adj]
        a_arr  = np.array(demand_list)
        print("a_arr: ", a_arr)
        #near_prob = list(np.exp((a_arr-a_arr[0])*10)/np.sum(np.exp((a_arr-a_arr[0])*10))) 
        near_prob = list(np.exp((a_arr-a_arr[0]))/np.sum(np.exp((a_arr-a_arr[0]))))
        print("near prob :", near_prob)  
        
        # 20, 28, 52
        
        r = random.random()
        #25
        
        count = 0
        for i in range(len(near_prob)):
            count = count + near_prob[i]
            if r < count:
                return(adj[i])  
        
        #repo_zone = adj[r_index]   
        
        #repo_prob = near_prob.index( max(near_prob))
        
    
        #print("r, repo, repo_prob", r, repo, repo_prob)
            
      
            
          
        #return (adj[near_prob.index( max(near_prob))],  is_repositioned)
    
        #SOFTMAX 
        #NEAR ARRIVAL 
        # return the highest prob of near arrival 
        
        
        ### paper's calculation of nearest prob
        # zone 1 = 10 , zone2 = 10.1 , zone 3 = 5
        # p(zone 1) = 10/25.5 = 0.392
        # p(zone 2) = 10.1/25.5 = 0.396
        # p(zone 3) = 5/25.5 = 0.196 
        
        
        # softmax suggestion way 
        # zone 1 = 10 , zone2 = 10.1 , zone 3 = 5
        # B  = 10 
        #exp(B * (rho1 - rho1) - e) / exp(B * (rho1 - rho1)) + exp(B * (rho2 - rho1)) + exp(B * (rho3 - rho1) - e) = 0.27
        #exp(B * (rho2 - rho1) - e) / exp(10) + exp(10.2) + exp(5)  = 0.73
        #exp(B * (rho3 - rho1) - e) / exp(10) + exp(10.2) + exp(5)  = 0.0
        
        
     
    def wait_time_before_pickup(self, matching_prob):
        if ( matching_prob >= 0.9 ):
            return random.randint(1,4)
        elif ( matching_prob >= 0.7 ):
            return random.randint(5,10)
        elif ( matching_prob >= 0.5 ):
            return random.randint(11,15)
        elif ( matching_prob >= 0.3 ):
            return random.randint(16,20)
        else:
            return random.randint(21,29)
        
    def wait_time_before_reposition(self):
        return random.randint(1,10)
    
    # can look into histortical data combined with random number 

    
    
    '''TODO: 
        need to fix for when repositioned to zone without data '''
    def get_trip_duration(self, start_zone, end_zone, shift_time):    

        shift,roundtime,weekday_ind = shift_time
        roundtime = roundtime.strftime('%H:%M:%S') 
        
        zone_to_zone = self.trip_time_df[(self.trip_time_df["pickup_taxizone_id"] == start_zone) & 
                                        (self.trip_time_df["dropoff_taxizone_id"] == end_zone)]
                
        if len(zone_to_zone[(zone_to_zone['_PU_shift']==shift) & (zone_to_zone['pickup_datetime_interval']==roundtime) &
                            (zone_to_zone['pickup_weekday'] == weekday_ind)])>0:
            
            dur = zone_to_zone.loc[(zone_to_zone["_PU_shift"] == shift) &
                                   (zone_to_zone["pickup_datetime_interval"] == roundtime) &
                                   (zone_to_zone['pickup_weekday'] == weekday_ind), "mean"].mean() 
        
        elif len(zone_to_zone[(zone_to_zone['_PU_shift']==shift) & (zone_to_zone['pickup_weekday'] == weekday_ind)])>0:
            dur = zone_to_zone.loc[(zone_to_zone["_PU_shift"] == shift) &
                                   (zone_to_zone['pickup_weekday'] == weekday_ind), "mean"].mean()
                    
        else:
            dur = zone_to_zone['mean'].mean()
        
        
        return dur
        
    def get_fare(self, start_zone, end_zone, shift_time): 
        
        shift,roundtime,weekday_ind = shift_time
        roundtime = roundtime.strftime('%H:%M:%S') 
        
        zone_to_zone = self.fare_df[(self.fare_df["pickup_taxizone_id"] == start_zone) & 
                                    (self.fare_df["dropoff_taxizone_id"] == end_zone)]
                
        if len(zone_to_zone[(zone_to_zone['_PU_shift']==shift) & (zone_to_zone['pickup_datetime_interval']==roundtime) &
                            (zone_to_zone['pickup_weekday'] == weekday_ind)])>0:
            
            fare = zone_to_zone.loc[(zone_to_zone["_PU_shift"] == shift) &
                                   (zone_to_zone["pickup_datetime_interval"] == roundtime) &
                                   (zone_to_zone['pickup_weekday'] == weekday_ind), "mean"].mean() 
        
        elif len(zone_to_zone[(zone_to_zone['_PU_shift']==shift) & (zone_to_zone['pickup_weekday'] == weekday_ind)])>0:
            fare = zone_to_zone.loc[(zone_to_zone["_PU_shift"] == shift) &
                                   (zone_to_zone['pickup_weekday'] == weekday_ind), "mean"].mean()
                    
        else:
            fare = zone_to_zone['mean'].mean()
            
        return fare
    
    def get_trip_distance(self, start_zone, end_zone):
        dist = self.dist_df.loc[((self.dist_df["pickup_taxizone_id"] == start_zone) &
                                 (self. dist_df["dropoff_taxizone_id"] == end_zone)), "mean"].mean()
        
        return dist 
    
    def get_fuel_cost(self, start_zone, end_zone): 
        
        cost = self.dist_df.loc[((self.dist_df["pickup_taxizone_id"] == start_zone) &
                                 (self. dist_df["dropoff_taxizone_id"] == end_zone)), "mean"].mean()*0.124
        return cost 
    
    def get_matching_prob(self, zone, time):
        if self.isWeekday:
            prob = self.prob_df.loc[(self.prob_df['taxi_zone'] == zone) & 
                                    (self.prob_df['time_stamp'] == time)].mod_prob_match_weekday.values[0]
        else: 
            prob = self.prob_df.loc[(self.prob_df['taxi_zone'] == zone) & 
                                    (self.prob_df['time_stamp'] == time)].mod_prob_match_weekend.values[0]
            
        return prob 
    
    
    time_bins = [dt.time(0,0),dt.time(0,30), dt.time(1,0), dt.time(1,30), dt.time(2,0), 
        dt.time(2,30), dt.time(3,0), dt.time(3,30), dt.time(4,0),
        dt.time(4,30), dt.time(5,0), dt.time(5,30), dt.time(6,0),
        dt.time(6,30), dt.time(7,0), dt.time(7,30), dt.time(8,0),
        dt.time(8,30), dt.time(9,0), dt.time(9,30), dt.time(10,0),
        dt.time(10,30), dt.time(11,0), dt.time(11,30), dt.time(12,0),
        dt.time(12,30), dt.time(13,0), dt.time(13,30), dt.time(14,0),
        dt.time(14,30), dt.time(15,0), dt.time(15,30), dt.time(16,0), 
        dt.time(16,30), dt.time(17,0), dt.time(17,30), dt.time(18,0),
        dt.time(18,30), dt.time(19,0), dt.time(19,30), dt.time(20,0),
        dt.time(20,30), dt.time(21,0), dt.time(21,30), dt.time(22,0),
        dt.time(22,30), dt.time(23,0), dt.time(23,30), dt.time(23,59,59)] 
    
    
    def get_time_window(self, datetime):
        for i in range(0,48):
            if (datetime.time() >= self.time_bins[i]) & (datetime.time() < self.time_bins[i+1]): 
                return i+1

# %%
# one round of simulation 

init_time = dt.datetime(2013, 6, 3, 5, 0, 0) 
init_zone = 66

#Initialize enviorment and driver 
env = Env( isWeekday = True ) 
driver = Driver( time = init_time, location = init_zone, total_fare = 0, total_cost = 0, is_idle = True) 

# print(driver.location)
# print(driver.time)
# print(driver.total_fare)
# print(driver.total_cost)
# print(driver.is_idle)


while driver.time < init_time + timedelta(seconds=0, minutes=0, hours = 11):
    #get prob that driver will be matched to a passenger 
    matching_prob = env.get_matching_prob( zone = driver.location, time = env.get_time_window(driver.time) )
    #print(matching_prob)
    start_zone = driver.location
    print('current time is ', driver.time, 'and driver is at zone ', driver.location)
    if env.is_matched(matching_prob):

        # time it takes before getting matched 
        wait_time = env.wait_time_before_pickup(matching_prob)
        print('driver waited for ', wait_time, ' min before he picks up')

        # set driver time to new time 
        driver.set_time( driver.time + timedelta(seconds=0, minutes= wait_time, hours=0 ) )
        print('driver gets a pick up and is now at time ', driver.time)    


        #driver is now busy 
        driver.set_is_idle(False)


        # find the destination of the trip and set destination 
        dest = env.get_destination(driver.location)
        driver.set_location(dest)
        print ('driver is going to zone', dest, 'and driver arrived at zone', driver.location)    

         # find the trip duration and update new time 
        duration = env.get_trip_duration(start_zone = start_zone, end_zone = dest, shift_time=driver.get_shift_time_weekday())
        print ('trip duration ', duration)
        driver.set_time( driver.time + timedelta(seconds=0, minutes= duration, hours=0 ) )
        print ('driver drops off passenger at time ', driver.time)


        #find trip fare and update fare 
        fare = env.get_fare( start_zone, dest, driver.get_shift_time_weekday())
        driver.set_total_fare(driver.total_fare + fare)
        print('trip fare from ', start_zone, 'to ', driver.location,   ' is',  fare)
        print('driver total fare earned is ', driver.total_fare )

        #frin trip cost and update cost 
        cost = env.get_fuel_cost(start_zone, dest)
        driver.set_total_cost(driver.total_cost + cost)
        print('fuel cost from ', start_zone, 'to ', driver.location,   ' is', cost  )

        print('************************trip is completed.************************** ')


    else: 
        #time it takes before reposition 
        print('driver does not get a pick up at the current zone: zone ', driver.location )
        
        wait_time = env.wait_time_before_reposition()
        driver.set_time( driver.time + timedelta(seconds=0, minutes= wait_time, hours=0 ) )
        print('driver now decides to check reposition info after ', wait_time, ' min of crusing and current time is ', driver.time)
       
        
        repo = env.reposition_to(driver.location, env.get_time_window(driver.time) ) #fix this to distribution 
        
        '''
            TODO:
            add cost - assume 10 miles a hour '''
                                                                       
                
        driver.set_location(repo)
        print('driver is repostioning to zone ', repo, 'and arrived at zone ', driver.location)

        # find the trip duration and update new time 
        duration = env.get_trip_duration(start_zone = start_zone, end_zone = repo, shift_time=driver.get_shift_time_weekday())
        print ('reposition trip duration ', duration , 'min')
        driver.set_time( driver.time + timedelta(seconds=0, minutes= duration, hours=0 ) )
        print ('After repositioning, it is now ', driver.time)

        #frin trip cost and update cost 
        cost = env.get_fuel_cost(start_zone, repo)
        driver.set_total_cost(driver.total_cost + cost)
        print('fuel cost from ', start_zone, 'to ', driver.location,   ' is', cost  )


        print('************************reposition is completed.************************** ')


        
print('total fare earned from this shift is ', driver.total_fare )
print('total fuel cost is ', driver.total_cost)
print('profit is ', driver.total_fare - driver.total_cost)
# Out:
# current time is  2013-06-03 05:00:00 and driver is at zone  66
# driver waited for  17  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 05:17:00
# driver is going to zone 97 and driver arrived at zone 97
# trip duration  12.688660236342606
# driver drops off passenger at time  2013-06-03 05:29:41.319614
# trip fare from  66 to  97  is 11.743248220585286
# driver total fare earned is  11.743248220585286
# fuel cost from  66 to  97  is 0.1894518479685453
# ************************trip is completed.**************************
# current time is  2013-06-03 05:29:41.319614 and driver is at zone  97
# driver waited for  6  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 05:35:41.319614
# driver is going to zone 225 and driver arrived at zone 225
# trip duration  17.585000703605093
# driver drops off passenger at time  2013-06-03 05:53:16.419656
# trip fare from  97 to  225  is 15.330109403641357
# driver total fare earned is  27.073357624226645
# fuel cost from  97 to  225  is 0.3174160482897386
# ************************trip is completed.**************************
# current time is  2013-06-03 05:53:16.419656 and driver is at zone  225
# driver does not get a pick up at the current zone: zone  225
# driver now decides to check reposition info after  6  min of crusing and current time is  2013-06-03 05:59:16.419656
# a_arr:  [1.75430664 1.97828125 2.48378906 1.77914063 1.93757813]
# near prob : [0.15264072667113604, 0.19095954087909653, 0.3165779156416763, 0.15647886497069372, 0.1833429518373974]
# driver is repostioning to zone  225 and arrived at zone  225
# reposition trip duration  12.126060948110197 min
# After repositioning, it is now  2013-06-03 06:11:23.983313
# fuel cost from  225 to  225  is 0.1786359183673469
# ************************reposition is completed.**************************
# current time is  2013-06-03 06:11:23.983313 and driver is at zone  225
# driver does not get a pick up at the current zone: zone  225
# driver now decides to check reposition info after  1  min of crusing and current time is  2013-06-03 06:12:23.983313
# a_arr:  [1.39546875 1.89681885 1.33335938 1.32228027 1.4934375 ]
# near prob : [0.17783839275101598, 0.29360206487216645, 0.167128981229081, 0.16528756174436143, 0.1961429994033751]
# driver is repostioning to zone  177 and arrived at zone  177
# reposition trip duration  8.812086149214096 min
# After repositioning, it is now  2013-06-03 06:21:12.708482
# fuel cost from  225 to  177  is 0.22014025974025977
# ************************reposition is completed.**************************
# current time is  2013-06-03 06:21:12.708482 and driver is at zone  177
# driver does not get a pick up at the current zone: zone  177
# driver now decides to check reposition info after  4  min of crusing and current time is  2013-06-03 06:25:12.708482
# a_arr:  [1.4934375  1.39546875 1.         1.33335938 1.32228027 0.
#  0.         0.        ]
# near prob : [0.20467621990114526, 0.18557526953443157, 0.12495976624251344, 0.17439994400997796, 0.1724784133893025, 0.04597012897420976, 0.04597012897420976, 0.04597012897420976]
# driver is repostioning to zone  225 and arrived at zone  225
# reposition trip duration  6.0254241987354185 min
# After repositioning, it is now  2013-06-03 06:31:14.233934
# fuel cost from  177 to  225  is 0.1663961904761905
# ************************reposition is completed.**************************
# current time is  2013-06-03 06:31:14.233934 and driver is at zone  225
# driver does not get a pick up at the current zone: zone  225
# driver now decides to check reposition info after  2  min of crusing and current time is  2013-06-03 06:33:14.233934
# a_arr:  [1.30761719 2.07348633 1.53896484 2.45241211 1.55466797]
# near prob : [0.11320923831662083, 0.2434975579780984, 0.14267729891756845, 0.3556804427041753, 0.14493546208353708]
# driver is repostioning to zone  225 and arrived at zone  225
# reposition trip duration  12.126060948110197 min
# After repositioning, it is now  2013-06-03 06:45:21.797591
# fuel cost from  225 to  225  is 0.1786359183673469
# ************************reposition is completed.**************************
# current time is  2013-06-03 06:45:21.797591 and driver is at zone  225
# driver does not get a pick up at the current zone: zone  225
# driver now decides to check reposition info after  8  min of crusing and current time is  2013-06-03 06:53:21.797591
# a_arr:  [1.30761719 2.07348633 1.53896484 2.45241211 1.55466797]
# near prob : [0.11320923831662083, 0.2434975579780984, 0.14267729891756845, 0.3556804427041753, 0.14493546208353708]
# driver is repostioning to zone  17 and arrived at zone  17
# reposition trip duration  8.842359900494754 min
# After repositioning, it is now  2013-06-03 07:02:12.339185
# fuel cost from  225 to  17  is 0.16094146718146712
# ************************reposition is completed.**************************
# current time is  2013-06-03 07:02:12.339185 and driver is at zone  17
# driver does not get a pick up at the current zone: zone  17
# driver now decides to check reposition info after  3  min of crusing and current time is  2013-06-03 07:05:12.339185
# a_arr:  [1.4615918  1.30761719 2.24680176 1.57746094 2.15266846 1.55466797
#  1.93757813]
# near prob : [0.10125536799065056, 0.086805597976009, 0.22203958631509302, 0.11369448132256274, 0.20209186715834865, 0.11113235669781468, 0.1629807425395214]
# driver is repostioning to zone  225 and arrived at zone  225
# reposition trip duration  12.566236348797819 min
# After repositioning, it is now  2013-06-03 07:17:46.313366
# fuel cost from  17 to  225  is 0.1705785915492958
# ************************reposition is completed.**************************
# current time is  2013-06-03 07:17:46.313366 and driver is at zone  225
# driver does not get a pick up at the current zone: zone  225
# driver now decides to check reposition info after  6  min of crusing and current time is  2013-06-03 07:23:46.313366
# a_arr:  [1.93757813 1.4615918  1.30761719 1.57746094 1.93757813]
# near prob : [0.2596405069473335, 0.16130737083773083, 0.1382878069713793, 0.18112380829622285, 0.2596405069473335]
# driver is repostioning to zone  61 and arrived at zone  61
# reposition trip duration  10.690826618425524 min
# After repositioning, it is now  2013-06-03 07:34:27.762963
# fuel cost from  225 to  61  is 0.23584833110814413
# ************************reposition is completed.**************************
# current time is  2013-06-03 07:34:27.762963 and driver is at zone  61
# driver does not get a pick up at the current zone: zone  61
# driver now decides to check reposition info after  10  min of crusing and current time is  2013-06-03 07:44:27.762963
# a_arr:  [1.55888672 1.93757813 1.96335938 2.         3.16835449 1.39546875
#  2.08779297 2.         2.93556396]
# near prob : [0.0538330926693445, 0.07861635759638108, 0.08066953862919934, 0.08368013927539357, 0.26917350101754495, 0.045717008902028324, 0.09135880205336411, 0.08368013927539357, 0.21327142058135046]
# driver is repostioning to zone  177 and arrived at zone  177
# reposition trip duration  14.53577103751614 min
# After repositioning, it is now  2013-06-03 07:58:59.909225
# fuel cost from  61 to  177  is 0.29783028571428566
# ************************reposition is completed.**************************
# current time is  2013-06-03 07:58:59.909225 and driver is at zone  177
# driver does not get a pick up at the current zone: zone  177
# driver now decides to check reposition info after  4  min of crusing and current time is  2013-06-03 08:02:59.909225
# a_arr:  [1.93757813 1.55466797 2.43767578 1.43356445 2.66455078 0.
#  1.93757813 0.        ]
# near prob : [0.1371409042085838, 0.09351283867585405, 0.22612920770394584, 0.08284697432452243, 0.2837182168468341, 0.019755477015837953, 0.1371409042085838, 0.019755477015837953]
# driver is repostioning to zone  61 and arrived at zone  61
# reposition trip duration  9.945457611894412 min
# After repositioning, it is now  2013-06-03 08:12:56.636682
# fuel cost from  177 to  61  is 0.2826845714285714
# ************************reposition is completed.**************************
# current time is  2013-06-03 08:12:56.636682 and driver is at zone  61
# driver waited for  24  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 08:36:56.636682
# driver is going to zone 25 and driver arrived at zone 25
# trip duration  12.188228143591001
# driver drops off passenger at time  2013-06-03 08:49:07.930371
# trip fare from  61 to  25  is 11.555926986581678
# driver total fare earned is  38.62928461080833
# fuel cost from  61 to  25  is 0.2612196162046908
# ************************trip is completed.**************************
# current time is  2013-06-03 08:49:07.930371 and driver is at zone  25
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 08:53:07.930371
# driver is going to zone 140 and driver arrived at zone 140
# trip duration  22.341995527331015
# driver drops off passenger at time  2013-06-03 09:15:28.450103
# trip fare from  25 to  140  is 23.69513687755346
# driver total fare earned is  62.324421488361786
# fuel cost from  25 to  140  is 0.8038512256973795
# ************************trip is completed.**************************
# current time is  2013-06-03 09:15:28.450103 and driver is at zone  140
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 09:18:28.450103
# driver is going to zone 236 and driver arrived at zone 236
# trip duration  11.32414603443659
# driver drops off passenger at time  2013-06-03 09:29:47.898865
# trip fare from  140 to  236  is 11.332440628862832
# driver total fare earned is  73.65686211722462
# fuel cost from  140 to  236  is 0.15528406223781568
# ************************trip is completed.**************************
# current time is  2013-06-03 09:29:47.898865 and driver is at zone  236
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 09:32:47.898865
# driver is going to zone 237 and driver arrived at zone 237
# trip duration  10.71510368525675
# driver drops off passenger at time  2013-06-03 09:43:30.805086
# trip fare from  236 to  237  is 10.932601779596112
# driver total fare earned is  84.58946389682073
# fuel cost from  236 to  237  is 0.13308258442306226
# ************************trip is completed.**************************
# current time is  2013-06-03 09:43:30.805086 and driver is at zone  237
# driver waited for  2  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 09:45:30.805086
# driver is going to zone 142 and driver arrived at zone 142
# trip duration  12.335274450564649
# driver drops off passenger at time  2013-06-03 09:57:50.921553
# trip fare from  237 to  142  is 11.835947205778908
# driver total fare earned is  96.42541110259964
# fuel cost from  237 to  142  is 0.1595911337417013
# ************************trip is completed.**************************
# current time is  2013-06-03 09:57:50.921553 and driver is at zone  142
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 10:00:50.921553
# driver is going to zone 170 and driver arrived at zone 170
# trip duration  17.28486710514092
# driver drops off passenger at time  2013-06-03 10:18:08.013579
# trip fare from  142 to  170  is 14.889001654795461
# driver total fare earned is  111.3144127573951
# fuel cost from  142 to  170  is 0.259587163905229
# ************************trip is completed.**************************
# current time is  2013-06-03 10:18:08.013579 and driver is at zone  170
# driver waited for  9  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 10:27:08.013579
# driver is going to zone 246 and driver arrived at zone 246
# trip duration  15.871138330449636
# driver drops off passenger at time  2013-06-03 10:43:00.281879
# trip fare from  170 to  246  is 13.926187899495027
# driver total fare earned is  125.24060065689014
# fuel cost from  170 to  246  is 0.21058097939885098
# ************************trip is completed.**************************
# current time is  2013-06-03 10:43:00.281879 and driver is at zone  246
# driver waited for  14  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 10:57:00.281879
# driver is going to zone 231 and driver arrived at zone 231
# trip duration  16.088818097078608
# driver drops off passenger at time  2013-06-03 11:13:05.610965
# trip fare from  246 to  231  is 15.132454745699633
# driver total fare earned is  140.37305540258978
# fuel cost from  246 to  231  is 0.30462013222190304
# ************************trip is completed.**************************
# current time is  2013-06-03 11:13:05.610965 and driver is at zone  231
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 11:16:05.610965
# driver is going to zone 233 and driver arrived at zone 233
# trip duration  18.83900282454396
# driver drops off passenger at time  2013-06-03 11:34:55.951134
# trip fare from  231 to  233  is 18.77201322924998
# driver total fare earned is  159.14506863183976
# fuel cost from  231 to  233  is 0.5061941756548543
# ************************trip is completed.**************************
# current time is  2013-06-03 11:34:55.951134 and driver is at zone  233
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 11:37:55.951134
# driver is going to zone 48 and driver arrived at zone 48
# trip duration  15.8320629888416
# driver drops off passenger at time  2013-06-03 11:53:45.874913
# trip fare from  233 to  48  is 13.479439065564247
# driver total fare earned is  172.624507697404
# fuel cost from  233 to  48  is 0.1794201013535184
# ************************trip is completed.**************************
# current time is  2013-06-03 11:53:45.874913 and driver is at zone  48
# driver waited for  2  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 11:55:45.874913
# driver is going to zone 68 and driver arrived at zone 68
# trip duration  11.395082908272158
# driver drops off passenger at time  2013-06-03 12:07:09.579887
# trip fare from  48 to  68  is 11.369719528932958
# driver total fare earned is  183.99422722633696
# fuel cost from  48 to  68  is 0.1557346224167196
# ************************trip is completed.**************************
# current time is  2013-06-03 12:07:09.579887 and driver is at zone  68
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 12:08:09.579887
# driver is going to zone 234 and driver arrived at zone 234
# trip duration  11.619695881081984
# driver drops off passenger at time  2013-06-03 12:19:46.761640
# trip fare from  68 to  234  is 11.221426009050575
# driver total fare earned is  195.21565323538755
# fuel cost from  68 to  234  is 0.137736503417126
# ************************trip is completed.**************************
# current time is  2013-06-03 12:19:46.761640 and driver is at zone  234
# driver waited for  5  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 12:24:46.761640
# driver is going to zone 148 and driver arrived at zone 148
# trip duration  15.344349647933791
# driver drops off passenger at time  2013-06-03 12:40:07.422619
# trip fare from  234 to  148  is 13.655098551239771
# driver total fare earned is  208.87075178662732
# fuel cost from  234 to  148  is 0.22077338277974914
# ************************trip is completed.**************************
# current time is  2013-06-03 12:40:07.422619 and driver is at zone  148
# driver waited for  2  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 12:42:07.422619
# driver is going to zone 25 and driver arrived at zone 25
# trip duration  18.225515432382174
# driver drops off passenger at time  2013-06-03 13:00:20.953545
# trip fare from  148 to  25  is 16.871052719048972
# driver total fare earned is  225.7418045056763
# fuel cost from  148 to  25  is 0.3911271365638761
# ************************trip is completed.**************************
# current time is  2013-06-03 13:00:20.953545 and driver is at zone  25
# driver waited for  5  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 13:05:20.953545
# driver is going to zone 40 and driver arrived at zone 40
# trip duration  15.22377850682191
# driver drops off passenger at time  2013-06-03 13:20:34.380255
# trip fare from  25 to  40  is 10.886947566878046
# driver total fare earned is  236.62875207255433
# fuel cost from  25 to  40  is 0.14194910299003322
# ************************trip is completed.**************************
# current time is  2013-06-03 13:20:34.380255 and driver is at zone  40
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 13:24:34.380255
# driver is going to zone 33 and driver arrived at zone 33
# trip duration  11.870375664492515
# driver drops off passenger at time  2013-06-03 13:36:26.602795
# trip fare from  40 to  33  is 11.334645930549524
# driver total fare earned is  247.96339800310386
# fuel cost from  40 to  33  is 0.14646023809523812
# ************************trip is completed.**************************
# current time is  2013-06-03 13:36:26.602795 and driver is at zone  33
# driver waited for  8  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 13:44:26.602795
# driver is going to zone 7 and driver arrived at zone 7
# trip duration  27.994461476718392
# driver drops off passenger at time  2013-06-03 14:12:26.270484
# trip fare from  33 to  7  is 25.779727731144376
# driver total fare earned is  273.7431257342482
# fuel cost from  33 to  7  is 1.0248869565217393
# ************************trip is completed.**************************
# current time is  2013-06-03 14:12:26.270484 and driver is at zone  7
# driver waited for  11  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 14:23:26.270484
# driver is going to zone 145 and driver arrived at zone 145
# trip duration  13.06088551337303
# driver drops off passenger at time  2013-06-03 14:36:29.923615
# trip fare from  7 to  145  is 13.01928870111947
# driver total fare earned is  286.7624144353677
# fuel cost from  7 to  145  is 0.2387121412520065
# ************************trip is completed.**************************
# current time is  2013-06-03 14:36:29.923615 and driver is at zone  145
# driver waited for  14  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 14:50:29.923615
# driver is going to zone 138 and driver arrived at zone 138
# trip duration  20.269690713159882
# driver drops off passenger at time  2013-06-03 15:10:46.105058
# trip fare from  145 to  138  is 23.287795671732106
# driver total fare earned is  310.0502101070998
# fuel cost from  145 to  138  is 0.817021553398058
# ************************trip is completed.**************************
# current time is  2013-06-03 15:10:46.105058 and driver is at zone  138
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 15:14:46.105058
# driver is going to zone 162 and driver arrived at zone 162
# trip duration  26.228953463755126
# driver drops off passenger at time  2013-06-03 15:40:59.842266
# trip fare from  138 to  162  is 28.82883904017227
# driver total fare earned is  338.8790491472721
# fuel cost from  138 to  162  is 1.0574619890402115
# ************************trip is completed.**************************
# current time is  2013-06-03 15:40:59.842266 and driver is at zone  162
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 15:41:59.842266
# driver is going to zone 186 and driver arrived at zone 186
# trip duration  14.94818326778173
# driver drops off passenger at time  2013-06-03 15:56:56.733262
# trip fare from  162 to  186  is 13.049558962378093
# driver total fare earned is  351.9286081096502
# fuel cost from  162 to  186  is 0.17840087959550965
# ************************trip is completed.**************************
# current time is  2013-06-03 15:56:56.733262 and driver is at zone  186
# driver waited for  9  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 16:05:56.733262
# driver is going to zone 161 and driver arrived at zone 161
# trip duration  13.836725832724234
# driver drops off passenger at time  2013-06-03 16:19:46.936812
# trip fare from  186 to  161  is 12.38988554308479
# driver total fare earned is  364.318493652735
# fuel cost from  186 to  161  is 0.1593139574136156
# ************************trip is completed.**************************
# total fare earned from this shift is  364.318493652735
# total fuel cost is  10.04156906851408
# profit is  354.2769245842209

# %%
'''TODO: 
Monte Carlo Simulation'''
# Out:
# 'TODO: \nMonte Carlo Simulation'

# %%
# # one round of simulation 

# init_time = dt.datetime(2013, 6, 3, 5, 0, 0) 
# init_zone = 66

# #Initialize enviorment and driver 
# env = Env( isWeekday = True ) 
# driver = Driver( time = init_time, location = init_zone, total_fare = 0, total_cost = 0, is_idle = True) 

# # print(driver.location)
# # print(driver.time)
# # print(driver.total_fare)
# # print(driver.total_cost)
# # print(driver.is_idle)

# #get prob that driver will be matched to a passenger 
# matching_prob = env.get_matching_prob( zone = driver.location, time = env.get_time_window(driver.time) )
# #print(matching_prob)
# start_zone = driver.location
# print('current time is ', driver.time, 'and driver is at zone ', driver.location)
# if env.is_matched(matching_prob):
    
#     # time it takes before getting matched 
#     wait_time = env.wait_time_before_pickup(matching_prob)
#     print('driver waited for ', wait_time, ' min before he picks up')
    
#     # set driver time to new time 
#     driver.set_time( driver.time + timedelta(seconds=0, minutes= wait_time, hours=0 ) )
#     print('driver gets a pick up and is now at time ', driver.time)    
    
    
#     #driver is now busy 
#     driver.set_is_idle(False)
    
                        
#     # find the destination of the trip and set destination 
#     dest = env.get_destination(driver.location)
#     driver.set_location(dest)
#     print ('driver is going to zone', dest, 'and driver arrived at zone', driver.location)    
    
#      # find the trip duration and update new time 
#     duration = env.get_trip_duration(start_zone = start_zone, end_zone = dest)
#     print ('trip duration ', duration)
#     driver.set_time( driver.time + timedelta(seconds=0, minutes= duration, hours=0 ) )
#     print ('driver drops off passenger at time ', driver.time)

    
#     #find trip fare and update fare 
#     fare = env.get_fare( start_zone, dest)
#     driver.set_total_fare(driver.total_fare + fare)
#     print('trip fare from ', start_zone, 'to ', driver.location,   ' is',  fare)
#     print('driver total fare earned is ', driver.total_fare )
    
#     #frin trip cost and update cost 
#     cost = env.get_fuel_cost(start_zone, dest)
#     driver.set_total_cost(driver.total_cost + cost)
#     print('fuel cost from ', start_zone, 'to ', driver.location,   ' is', cost  )
    
#     print('************************trip is completed.************************** ')
    

# else: 
#     #time it takes before reposition 
#     print('driver does not get a pick up at the current zone: zone ', driver.location )
#     wait_time = env.wait_time_before_reposition()
#     driver.set_time( driver.time + timedelta(seconds=0, minutes= wait_time, hours=0 ) )
#     print('driver now decides to reposition after ', wait_time, ' min of crusing and current time is ', driver.time)
    
#     #find where to reposition to and update location 
#     repo = env.reposition_to(driver.location, env.get_time_window(driver.time) ) #fix this to distribution 
#     driver.set_location(repo)
#     print('driver is repostioning to zone ', repo, 'and arrived at zone ', driver.location)
    
#     # find the trip duration and update new time 
#     duration = env.get_trip_duration(start_zone = start_zone, end_zone = repo)
#     print ('reposition trip duration ', duration , 'min')
#     driver.set_time( driver.time + timedelta(seconds=0, minutes= duration, hours=0 ) )
#     print ('After repositioning, it is now ', driver.time)
                    
#     #frin trip cost and update cost 
#     cost = env.get_fuel_cost(start_zone, repo)
#     driver.set_total_cost(driver.total_cost + cost)
#     print('fuel cost from ', start_zone, 'to ', driver.location,   ' is', cost  )
                    
                    
#     print('************************reposition is completed.************************** ')
