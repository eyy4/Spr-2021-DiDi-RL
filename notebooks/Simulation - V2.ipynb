# %%
import numpy as np
import pandas as pd 
import datetime as dt
from datetime import timedelta 
import random

# %%
class Driver: 
    

    
    def __init__(self, time, location, total_fare, total_cost, is_idle ):
        self.time = time 
        self.location = location 
        self.total_fare = total_fare
        self.total_cost  = total_cost
        self.is_idle = is_idle
    
    def set_time(self, new_time):
        self.time = new_time
    
    def get_time(self):
        return self.__time 
    
    def set_location(self, new_location):
        self.location = new_location
        
    def get_location(self):
        return self.__location 
   
    def set_total_fare(self, new_fare):
        self.total_fare = new_fare
    
    def get_total_fare(self):
        return self.total_fare 
    
    def set_is_idle(self, is_idle):
        self.is_idle = is_idle 
        
    def set_total_cost(self, new_cost):
        self.total_cost = new_cost
    
    def get_total_cost(self):
        return self.total_cost

# %%
class Env: 
    
    
    arrivals = pd.read_csv('arrival_rates.csv')[['taxi_zone', 'time_stamp','arr_weekday','arr_weekend']]
    dropoff_counts = pd.read_csv('pickup_dropoff_summary.csv')
    fare_df = pd.read_csv('fare_amount_scr_dst_t.csv')
    dist_df = pd.read_csv('trip_distance_scr_dst.csv')
    trip_time_df = pd.read_csv('trip_time_scr_dst_t.csv')
    prob_df = pd.read_csv('prob_match_combined_new.csv')
    trans_matrix = pd.read_csv('dropoff_after_pickup.csv') # fix this to shift based and a
     # 0 weekend , A night shift 
    
    #time in 1..48,  isWeekday is a boolean
    def __init__(self,  isWeekday):   

        self.isWeekday = isWeekday 
        
    
    def is_matched(self, matching_prob):
        n = random.random()

        if n <= matching_prob:
            return True 
        else: 
            False 
    
    def get_destination(self, zone):
        prob = self.trans_matrix.iloc[zone-1].values[1:]
        n = random.random()

        count = 0
        for i in range(len(prob)):
            count = count + prob[i]
            if n<count:
                return i+1

    def get_adjacent_zone( self, taxi_zone ):
        df = pd.read_csv('adjacent_zone.csv')
        adj_zone_1 = df.loc[df["zone1"]==taxi_zone, "zone2"].values.tolist()
        adj_zone_2 = df.loc[df["zone2"]==taxi_zone, "zone1"].values.tolist()
        adj_zone_list = list(filter(None, adj_zone_1+adj_zone_2))
        return(adj_zone_list)
    
    def get_demand(self, zone, time):
        row = self.arrivals.loc[ ( self.arrivals['taxi_zone'] == zone ) & (self.arrivals['time_stamp'] == time ) ]
        if self.isWeekday:
            return row['arr_weekday'].values[0]
        else:
            return row['arr_weekend'].values[0]
    
#  def get_near_arrival():
    
    
    '''TODO： 
        fix policy fucntion - add randomness'''
    
    def reposition_to( self, current_zone, time ):
        adj = self.get_adjacent_zone( current_zone )
        adj.append( current_zone )
         # find the index of the max value of demand_list, and find which zone it is 
        demand_list = [self.get_demand(zone, time) for zone in adj]
       # print(demand_list)
        return adj[demand_list.index( max(demand_list))]  
        #SOFTMAX 
        #NEAR ARRIVAL 
        # return the highest prob of near arrival 
        
        
    ### paper's way 
        # zone 1 = 10 , zone2 = 10.1 , zone 3 = 5
        # p(zone 1) = 10/25.5 = 0.392
        # p(zone 2) = 10.1/25.5 = 0.396
        # p(zone 3) = 5/25.5 = 0.196 
        
        
   #    vineet's way 
        # zone 1 = 10 , zone2 = 10.1 , zone 3 = 5
        # B  = 10 
        #exp(B * (rho1 - rho1) - e) / exp(B * (rho1 - rho1)) + exp(B * (rho2 - rho1)) + exp(B * (rho3 - rho1) - e) = 0.27
        #exp(B * (rho2 - rho1) - e) / exp(10) + exp(10.2) + exp(5)  = 0.73
        #exp(B * (rho3 - rho1) - e) / exp(10) + exp(10.2) + exp(5)  = 0.0
        
        
     
    def wait_time_before_pickup(self, matching_prob):
        if ( matching_prob >= 0.9 ):
            return random.randint(1,4)
        elif ( matching_prob >= 0.7 ):
            return random.randint(5,10)
        elif ( matching_prob >= 0.5 ):
            return random.randint(11,15)
        elif ( matching_prob >= 0.3 ):
            return random.randint(16,20)
        else:
            return random.randint(21,29)
        
    def wait_time_before_reposition(self):
        return random.randint(1,10)
    
    # can look into histortical data combined with random number 

    
    
    '''TODO: 
        fix the three functions below '''
    def get_trip_duration(self, start_zone, end_zone):    
        dur = self.trip_time_df.loc[(
            (self.trip_time_df["pickup_taxizone_id"] == start_zone )  & 
            (self.trip_time_df["dropoff_taxizone_id"] == end_zone)), "mean"].describe().mean()  
        
        return dur
        
    def get_fare(self, start_zone, end_zone): 
        fare = self.fare_df.loc[((self.fare_df["pickup_taxizone_id"] == start_zone) & 
                                 (self.fare_df["dropoff_taxizone_id"] == end_zone)), "mean"].describe().mean()
        return fare
    
    def get_trip_distance(self, start_zone, end_zone):
        dist = self.dist_df.loc[((self.dist_df["pickup_taxizone_id"] == start_zone) &
                                 (self. dist_df["dropoff_taxizone_id"] == end_zone)), "mean"].describe().mean()
        
        return dist 
    
    def get_fuel_cost(self, start_zone, end_zone): 
        
        cost = self.dist_df.loc[((self.dist_df["pickup_taxizone_id"] == start_zone) &
                                 (self. dist_df["dropoff_taxizone_id"] == end_zone)), "mean"].describe().mean()*0.124
        return cost 
    
    def get_matching_prob(self, zone, time):
        if self.isWeekday:
            prob = self.prob_df.loc[(self.prob_df['taxi_zone'] == zone) & 
                                    (self.prob_df['time_stamp'] == time)].mod_prob_match_weekday.values[0]
        else: 
            prob = self.prob_df.loc[(self.prob_df['taxi_zone'] == zone) & 
                                    (self.prob_df['time_stamp'] == time)].mod_prob_match_weekend.values[0]
            
        return prob 
    
    
    time_bins = [dt.time(0,0),dt.time(0,30), dt.time(1,0), dt.time(1,30), dt.time(2,0), 
        dt.time(2,30), dt.time(3,0), dt.time(3,30), dt.time(4,0),
        dt.time(4,30), dt.time(5,0), dt.time(5,30), dt.time(6,0),
        dt.time(6,30), dt.time(7,0), dt.time(7,30), dt.time(8,0),
        dt.time(8,30), dt.time(9,0), dt.time(9,30), dt.time(10,0),
        dt.time(10,30), dt.time(11,0), dt.time(11,30), dt.time(12,0),
        dt.time(12,30), dt.time(13,0), dt.time(13,30), dt.time(14,0),
        dt.time(14,30), dt.time(15,0), dt.time(15,30), dt.time(16,0), 
        dt.time(16,30), dt.time(17,0), dt.time(17,30), dt.time(18,0),
        dt.time(18,30), dt.time(19,0), dt.time(19,30), dt.time(20,0),
        dt.time(20,30), dt.time(21,0), dt.time(21,30), dt.time(22,0),
        dt.time(22,30), dt.time(23,0), dt.time(23,30), dt.time(23,59,59)] 
    
    
    def get_time_window(self, datetime):
        for i in range(0,48):
            if (datetime.time() >= self.time_bins[i]) & (datetime.time() < self.time_bins[i+1]): 
                return i+1

# %%
# one round of simulation 

init_time = dt.datetime(2013, 6, 3, 5, 0, 0) 
init_zone = 66

#Initialize enviorment and driver 
env = Env( isWeekday = True ) 
driver = Driver( time = init_time, location = init_zone, total_fare = 0, total_cost = 0, is_idle = True) 

# print(driver.location)
# print(driver.time)
# print(driver.total_fare)
# print(driver.total_cost)
# print(driver.is_idle)


while driver.time < init_time + timedelta(seconds=0, minutes=0, hours = 11):
    #get prob that driver will be matched to a passenger 
    matching_prob = env.get_matching_prob( zone = driver.location, time = env.get_time_window(driver.time) )
    #print(matching_prob)
    start_zone = driver.location
    print('current time is ', driver.time, 'and driver is at zone ', driver.location)
    if env.is_matched(matching_prob):

        # time it takes before getting matched 
        wait_time = env.wait_time_before_pickup(matching_prob)
        print('driver waited for ', wait_time, ' min before he picks up')

        # set driver time to new time 
        driver.set_time( driver.time + timedelta(seconds=0, minutes= wait_time, hours=0 ) )
        print('driver gets a pick up and is now at time ', driver.time)    


        #driver is now busy 
        driver.set_is_idle(False)


        # find the destination of the trip and set destination 
        dest = env.get_destination(driver.location)
        driver.set_location(dest)
        print ('driver is going to zone', dest, 'and driver arrived at zone', driver.location)    

         # find the trip duration and update new time 
        duration = env.get_trip_duration(start_zone = start_zone, end_zone = dest)
        print ('trip duration ', duration)
        driver.set_time( driver.time + timedelta(seconds=0, minutes= duration, hours=0 ) )
        print ('driver drops off passenger at time ', driver.time)


        #find trip fare and update fare 
        fare = env.get_fare( start_zone, dest)
        driver.set_total_fare(driver.total_fare + fare)
        print('trip fare from ', start_zone, 'to ', driver.location,   ' is',  fare)
        print('driver total fare earned is ', driver.total_fare )

        #frin trip cost and update cost 
        cost = env.get_fuel_cost(start_zone, dest)
        driver.set_total_cost(driver.total_cost + cost)
        print('fuel cost from ', start_zone, 'to ', driver.location,   ' is', cost  )

        print('************************trip is completed.************************** ')


    else: 
        #time it takes before reposition 
        print('driver does not get a pick up at the current zone: zone ', driver.location )
        wait_time = env.wait_time_before_reposition()
        driver.set_time( driver.time + timedelta(seconds=0, minutes= wait_time, hours=0 ) )
        print('driver now decides to reposition after ', wait_time, ' min of crusing and current time is ', driver.time)
        
        '''
        TODO:
        add cost - assume 10 miles a hour '''
        
        
        #find where to reposition to and update location 
        repo = env.reposition_to(driver.location, env.get_time_window(driver.time) ) #fix this to distribution 
        driver.set_location(repo)
        print('driver is repostioning to zone ', repo, 'and arrived at zone ', driver.location)

        # find the trip duration and update new time 
        duration = env.get_trip_duration(start_zone = start_zone, end_zone = repo)
        print ('reposition trip duration ', duration , 'min')
        driver.set_time( driver.time + timedelta(seconds=0, minutes= duration, hours=0 ) )
        print ('After repositioning, it is now ', driver.time)

        #frin trip cost and update cost 
        cost = env.get_fuel_cost(start_zone, repo)
        driver.set_total_cost(driver.total_cost + cost)
        print('fuel cost from ', start_zone, 'to ', driver.location,   ' is', cost  )


        print('************************reposition is completed.************************** ')


        
print('total fare earned from this shift is ', driver.total_fare )
print('total fuel cost is ', driver.total_cost)
print('profit is ', driver.total_fare - driver.total_cost)
# Out:
# current time is  2013-06-03 05:00:00 and driver is at zone  66
# driver waited for  17  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 05:17:00
# driver is going to zone 234 and driver arrived at zone 234
# trip duration  19.72912623662975
# driver drops off passenger at time  2013-06-03 05:36:43.747574
# trip fare from  66 to  234  is 18.42764957012644
# driver total fare earned is  18.42764957012644
# fuel cost from  66 to  234  is 0.46957245165315037
# ************************trip is completed.**************************
# current time is  2013-06-03 05:36:43.747574 and driver is at zone  234
# driver does not get a pick up at the current zone: zone  234
# driver now decides to reposition after  7  min of crusing and current time is  2013-06-03 05:43:43.747574
# driver is repostioning to zone  186 and arrived at zone  186
# reposition trip duration  11.443773770017081 min
# After repositioning, it is now  2013-06-03 05:55:10.374000
# fuel cost from  234 to  186  is 0.11573716615150298
# ************************reposition is completed.**************************
# current time is  2013-06-03 05:55:10.374000 and driver is at zone  186
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 05:59:10.374000
# driver is going to zone 140 and driver arrived at zone 140
# trip duration  20.06605975435832
# driver drops off passenger at time  2013-06-03 06:19:14.337585
# trip fare from  186 to  140  is 17.118591746575444
# driver total fare earned is  35.54624131670188
# fuel cost from  186 to  140  is 0.35445661409243895
# ************************trip is completed.**************************
# current time is  2013-06-03 06:19:14.337585 and driver is at zone  140
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 06:20:14.337585
# driver is going to zone 236 and driver arrived at zone 236
# trip duration  11.32414603443659
# driver drops off passenger at time  2013-06-03 06:31:33.786347
# trip fare from  140 to  236  is 11.332440628862832
# driver total fare earned is  46.878681945564715
# fuel cost from  140 to  236  is 0.1552826320253902
# ************************trip is completed.**************************
# current time is  2013-06-03 06:31:33.786347 and driver is at zone  236
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 06:32:33.786347
# driver is going to zone 140 and driver arrived at zone 140
# trip duration  12.438240833326015
# driver drops off passenger at time  2013-06-03 06:45:00.080797
# trip fare from  236 to  140  is 11.808259975183502
# driver total fare earned is  58.68694192074822
# fuel cost from  236 to  140  is 0.16123803194888223
# ************************trip is completed.**************************
# current time is  2013-06-03 06:45:00.080797 and driver is at zone  140
# driver waited for  6  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 06:51:00.080797
# driver is going to zone 237 and driver arrived at zone 237
# trip duration  11.0859854161966
# driver drops off passenger at time  2013-06-03 07:02:05.239922
# trip fare from  140 to  237  is 10.808688339771171
# driver total fare earned is  69.49563026051939
# fuel cost from  140 to  237  is 0.11866064941581263
# ************************trip is completed.**************************
# current time is  2013-06-03 07:02:05.239922 and driver is at zone  237
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 07:03:05.239922
# driver is going to zone 235 and driver arrived at zone 235
# trip duration  26.959915013017437
# driver drops off passenger at time  2013-06-03 07:30:02.834823
# trip fare from  237 to  235  is 25.573698336053255
# driver total fare earned is  95.06932859657265
# fuel cost from  237 to  235  is 0.9158285714285715
# ************************trip is completed.**************************
# current time is  2013-06-03 07:30:02.834823 and driver is at zone  235
# driver does not get a pick up at the current zone: zone  235
# driver now decides to reposition after  9  min of crusing and current time is  2013-06-03 07:39:02.834823
# driver is repostioning to zone  247 and arrived at zone  247
# reposition trip duration  4.428571428571429 min
# After repositioning, it is now  2013-06-03 07:43:28.549109
# fuel cost from  235 to  247  is 0.3121257142857143
# ************************reposition is completed.**************************
# current time is  2013-06-03 07:43:28.549109 and driver is at zone  247
# driver waited for  6  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 07:49:28.549109
# driver is going to zone 247 and driver arrived at zone 247
# trip duration  13.978595205235408
# driver drops off passenger at time  2013-06-03 08:03:27.264821
# trip fare from  247 to  247  is 17.2841988037068
# driver total fare earned is  112.35352740027945
# fuel cost from  247 to  247  is 0.23853955918367364
# ************************trip is completed.**************************
# current time is  2013-06-03 08:03:27.264821 and driver is at zone  247
# driver does not get a pick up at the current zone: zone  247
# driver now decides to reposition after  5  min of crusing and current time is  2013-06-03 08:08:27.264821
# driver is repostioning to zone  235 and arrived at zone  235
# reposition trip duration  10.182949582110894 min
# After repositioning, it is now  2013-06-03 08:18:38.241796
# fuel cost from  247 to  235  is 0.3238171428571428
# ************************reposition is completed.**************************
# current time is  2013-06-03 08:18:38.241796 and driver is at zone  235
# driver does not get a pick up at the current zone: zone  235
# driver now decides to reposition after  3  min of crusing and current time is  2013-06-03 08:21:38.241796
# driver is repostioning to zone  235 and arrived at zone  235
# reposition trip duration  10.72605447374693 min
# After repositioning, it is now  2013-06-03 08:32:21.805064
# fuel cost from  235 to  235  is 0.21787990632318507
# ************************reposition is completed.**************************
# current time is  2013-06-03 08:32:21.805064 and driver is at zone  235
# driver does not get a pick up at the current zone: zone  235
# driver now decides to reposition after  2  min of crusing and current time is  2013-06-03 08:34:21.805064
# driver is repostioning to zone  235 and arrived at zone  235
# reposition trip duration  10.72605447374693 min
# After repositioning, it is now  2013-06-03 08:45:05.368332
# fuel cost from  235 to  235  is 0.21787990632318507
# ************************reposition is completed.**************************
# current time is  2013-06-03 08:45:05.368332 and driver is at zone  235
# driver waited for  19  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 09:04:05.368332
# driver is going to zone 235 and driver arrived at zone 235
# trip duration  10.72605447374693
# driver drops off passenger at time  2013-06-03 09:14:48.931600
# trip fare from  235 to  235  is 12.05865617623483
# driver total fare earned is  124.41218357651428
# fuel cost from  235 to  235  is 0.21787990632318507
# ************************trip is completed.**************************
# current time is  2013-06-03 09:14:48.931600 and driver is at zone  235
# driver does not get a pick up at the current zone: zone  235
# driver now decides to reposition after  3  min of crusing and current time is  2013-06-03 09:17:48.931600
# driver is repostioning to zone  235 and arrived at zone  235
# reposition trip duration  10.72605447374693 min
# After repositioning, it is now  2013-06-03 09:28:32.494868
# fuel cost from  235 to  235  is 0.21787990632318507
# ************************reposition is completed.**************************
# current time is  2013-06-03 09:28:32.494868 and driver is at zone  235
# driver does not get a pick up at the current zone: zone  235
# driver now decides to reposition after  11  min of crusing and current time is  2013-06-03 09:39:32.494868
# driver is repostioning to zone  169 and arrived at zone  169
# reposition trip duration  5.90332146414114 min
# After repositioning, it is now  2013-06-03 09:45:26.694156
# fuel cost from  235 to  169  is 0.1524845714285714
# ************************reposition is completed.**************************
# current time is  2013-06-03 09:45:26.694156 and driver is at zone  169
# driver does not get a pick up at the current zone: zone  169
# driver now decides to reposition after  9  min of crusing and current time is  2013-06-03 09:54:26.694156
# driver is repostioning to zone  169 and arrived at zone  169
# reposition trip duration  12.690211361992496 min
# After repositioning, it is now  2013-06-03 10:07:08.106838
# fuel cost from  169 to  169  is 0.22821184668989541
# ************************reposition is completed.**************************
# current time is  2013-06-03 10:07:08.106838 and driver is at zone  169
# driver does not get a pick up at the current zone: zone  169
# driver now decides to reposition after  3  min of crusing and current time is  2013-06-03 10:10:08.106838
# driver is repostioning to zone  247 and arrived at zone  247
# reposition trip duration  8.032354001789226 min
# After repositioning, it is now  2013-06-03 10:18:10.048078
# fuel cost from  169 to  247  is 0.18564571428571428
# ************************reposition is completed.**************************
# current time is  2013-06-03 10:18:10.048078 and driver is at zone  247
# driver waited for  26  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 10:44:10.048078
# driver is going to zone 223 and driver arrived at zone 223
# trip duration  11.312787397967679
# driver drops off passenger at time  2013-06-03 10:55:28.815322
# trip fare from  247 to  223  is 14.793007967005696
# driver total fare earned is  139.20519154352
# fuel cost from  247 to  223  is 0.6623371428571428
# ************************trip is completed.**************************
# current time is  2013-06-03 10:55:28.815322 and driver is at zone  223
# driver waited for  6  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 11:01:28.815322
# driver is going to zone 230 and driver arrived at zone 230
# trip duration  28.196719399032773
# driver drops off passenger at time  2013-06-03 11:29:40.618486
# trip fare from  223 to  230  is 25.913704484090587
# driver total fare earned is  165.11889602761056
# fuel cost from  223 to  230  is 0.7167338392857144
# ************************trip is completed.**************************
# current time is  2013-06-03 11:29:40.618486 and driver is at zone  230
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 11:30:40.618486
# driver is going to zone 100 and driver arrived at zone 100
# trip duration  11.072808141031505
# driver drops off passenger at time  2013-06-03 11:41:44.986974
# trip fare from  230 to  100  is 10.72500364100569
# driver total fare earned is  175.84389966861625
# fuel cost from  230 to  100  is 0.10330811274065976
# ************************trip is completed.**************************
# current time is  2013-06-03 11:41:44.986974 and driver is at zone  100
# driver waited for  2  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 11:43:44.986974
# driver is going to zone 90 and driver arrived at zone 90
# trip duration  10.565652006581756
# driver drops off passenger at time  2013-06-03 11:54:18.926094
# trip fare from  100 to  90  is 10.822188644971305
# driver total fare earned is  186.66608831358755
# fuel cost from  100 to  90  is 0.1355420469083155
# ************************trip is completed.**************************
# current time is  2013-06-03 11:54:18.926094 and driver is at zone  90
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 11:55:18.926094
# driver is going to zone 231 and driver arrived at zone 231
# trip duration  14.205066509559218
# driver drops off passenger at time  2013-06-03 12:09:31.230085
# trip fare from  90 to  231  is 13.518801531356292
# driver total fare earned is  200.18488984494385
# fuel cost from  90 to  231  is 0.24241550321897223
# ************************trip is completed.**************************
# current time is  2013-06-03 12:09:31.230085 and driver is at zone  231
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 12:10:31.230085
# driver is going to zone 114 and driver arrived at zone 114
# trip duration  12.119443484963002
# driver drops off passenger at time  2013-06-03 12:22:38.396694
# trip fare from  231 to  114  is 11.657488980141968
# driver total fare earned is  211.84237882508583
# fuel cost from  231 to  114  is 0.15379934059097947
# ************************trip is completed.**************************
# current time is  2013-06-03 12:22:38.396694 and driver is at zone  114
# driver does not get a pick up at the current zone: zone  114
# driver now decides to reposition after  2  min of crusing and current time is  2013-06-03 12:24:38.396694
# driver is repostioning to zone  113 and arrived at zone  113
# reposition trip duration  9.472639598416126 min
# After repositioning, it is now  2013-06-03 12:34:06.755070
# fuel cost from  114 to  113  is 0.09991053807580191
# ************************reposition is completed.**************************
# current time is  2013-06-03 12:34:06.755070 and driver is at zone  113
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 12:38:06.755070
# driver is going to zone 162 and driver arrived at zone 162
# trip duration  15.989610674605833
# driver drops off passenger at time  2013-06-03 12:54:06.131710
# trip fare from  113 to  162  is 14.470234379570375
# driver total fare earned is  226.3126132046562
# fuel cost from  113 to  162  is 0.26452550693004473
# ************************trip is completed.**************************
# current time is  2013-06-03 12:54:06.131710 and driver is at zone  162
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 12:55:06.131710
# driver is going to zone 140 and driver arrived at zone 140
# trip duration  12.429042609082755
# driver drops off passenger at time  2013-06-03 13:07:31.874267
# trip fare from  162 to  140  is 12.005640010814663
# driver total fare earned is  238.31825321547086
# fuel cost from  162 to  140  is 0.1794004395604405
# ************************trip is completed.**************************
# current time is  2013-06-03 13:07:31.874267 and driver is at zone  140
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 13:11:31.874267
# driver is going to zone 230 and driver arrived at zone 230
# trip duration  18.69191995199773
# driver drops off passenger at time  2013-06-03 13:30:13.389464
# trip fare from  140 to  230  is 15.668630280950183
# driver total fare earned is  253.98688349642106
# fuel cost from  140 to  230  is 0.2712335794542534
# ************************trip is completed.**************************
# current time is  2013-06-03 13:30:13.389464 and driver is at zone  230
# driver waited for  7  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 13:37:13.389464
# driver is going to zone 161 and driver arrived at zone 161
# trip duration  11.792696128197845
# driver drops off passenger at time  2013-06-03 13:49:00.951232
# trip fare from  230 to  161  is 11.000043540456508
# driver total fare earned is  264.98692703687755
# fuel cost from  230 to  161  is 0.10603478918047791
# ************************trip is completed.**************************
# current time is  2013-06-03 13:49:00.951232 and driver is at zone  161
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 13:53:00.951232
# driver is going to zone 263 and driver arrived at zone 263
# trip duration  14.755283181966796
# driver drops off passenger at time  2013-06-03 14:07:46.268223
# trip fare from  161 to  263  is 13.94730248187923
# driver total fare earned is  278.93422951875675
# fuel cost from  161 to  263  is 0.2711971757632387
# ************************trip is completed.**************************
# current time is  2013-06-03 14:07:46.268223 and driver is at zone  263
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 14:08:46.268223
# driver is going to zone 164 and driver arrived at zone 164
# trip duration  19.68976937831978
# driver drops off passenger at time  2013-06-03 14:28:27.654386
# trip fare from  263 to  164  is 17.14896395965446
# driver total fare earned is  296.0831934784112
# fuel cost from  263 to  164  is 0.37248234079173836
# ************************trip is completed.**************************
# current time is  2013-06-03 14:28:27.654386 and driver is at zone  164
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 14:32:27.654386
# driver is going to zone 246 and driver arrived at zone 246
# trip duration  13.991420023830196
# driver drops off passenger at time  2013-06-03 14:46:27.139587
# trip fare from  164 to  246  is 12.589528140292654
# driver total fare earned is  308.67272161870386
# fuel cost from  164 to  246  is 0.16995455149501626
# ************************trip is completed.**************************
# current time is  2013-06-03 14:46:27.139587 and driver is at zone  246
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 14:49:27.139587
# driver is going to zone 68 and driver arrived at zone 68
# trip duration  10.517708293988765
# driver drops off passenger at time  2013-06-03 14:59:58.202085
# trip fare from  246 to  68  is 10.599192211924443
# driver total fare earned is  319.2719138306283
# fuel cost from  246 to  68  is 0.11861600419607105
# ************************trip is completed.**************************
# current time is  2013-06-03 14:59:58.202085 and driver is at zone  68
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 15:00:58.202085
# driver is going to zone 114 and driver arrived at zone 114
# trip duration  14.542238729412041
# driver drops off passenger at time  2013-06-03 15:15:30.736409
# trip fare from  68 to  114  is 13.045713770366966
# driver total fare earned is  332.31762760099525
# fuel cost from  68 to  114  is 0.20576806859286464
# ************************trip is completed.**************************
# current time is  2013-06-03 15:15:30.736409 and driver is at zone  114
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 15:16:30.736409
# driver is going to zone 237 and driver arrived at zone 237
# trip duration  19.496990186445853
# driver drops off passenger at time  2013-06-03 15:36:00.555820
# trip fare from  114 to  237  is 17.290375056332753
# driver total fare earned is  349.60800265732803
# fuel cost from  114 to  237  is 0.3991208728058348
# ************************trip is completed.**************************
# current time is  2013-06-03 15:36:00.555820 and driver is at zone  237
# driver waited for  2  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 15:38:00.555820
# driver is going to zone 236 and driver arrived at zone 236
# trip duration  9.880906232814112
# driver drops off passenger at time  2013-06-03 15:47:53.410194
# trip fare from  237 to  236  is 10.533118453377067
# driver total fare earned is  360.1411211107051
# fuel cost from  237 to  236  is 0.13253664600605938
# ************************trip is completed.**************************
# current time is  2013-06-03 15:47:53.410194 and driver is at zone  236
# driver waited for  2  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 15:49:53.410194
# driver is going to zone 68 and driver arrived at zone 68
# trip duration  21.7046665775516
# driver drops off passenger at time  2013-06-03 16:11:35.690189
# trip fare from  236 to  68  is 18.963068383819355
# driver total fare earned is  379.10418949452446
# fuel cost from  236 to  68  is 0.45389242793081436
# ************************trip is completed.**************************
# total fare earned from this shift is  379.10418949452446
# total fuel cost is  9.661929217123637
# profit is  369.4422602774008

# %%
'''TODO: 
Monte Carlo Simulation'''

# %%
# # one round of simulation 

# init_time = dt.datetime(2013, 6, 3, 5, 0, 0) 
# init_zone = 66

# #Initialize enviorment and driver 
# env = Env( isWeekday = True ) 
# driver = Driver( time = init_time, location = init_zone, total_fare = 0, total_cost = 0, is_idle = True) 

# # print(driver.location)
# # print(driver.time)
# # print(driver.total_fare)
# # print(driver.total_cost)
# # print(driver.is_idle)

# #get prob that driver will be matched to a passenger 
# matching_prob = env.get_matching_prob( zone = driver.location, time = env.get_time_window(driver.time) )
# #print(matching_prob)
# start_zone = driver.location
# print('current time is ', driver.time, 'and driver is at zone ', driver.location)
# if env.is_matched(matching_prob):
    
#     # time it takes before getting matched 
#     wait_time = env.wait_time_before_pickup(matching_prob)
#     print('driver waited for ', wait_time, ' min before he picks up')
    
#     # set driver time to new time 
#     driver.set_time( driver.time + timedelta(seconds=0, minutes= wait_time, hours=0 ) )
#     print('driver gets a pick up and is now at time ', driver.time)    
    
    
#     #driver is now busy 
#     driver.set_is_idle(False)
    
                        
#     # find the destination of the trip and set destination 
#     dest = env.get_destination(driver.location)
#     driver.set_location(dest)
#     print ('driver is going to zone', dest, 'and driver arrived at zone', driver.location)    
    
#      # find the trip duration and update new time 
#     duration = env.get_trip_duration(start_zone = start_zone, end_zone = dest)
#     print ('trip duration ', duration)
#     driver.set_time( driver.time + timedelta(seconds=0, minutes= duration, hours=0 ) )
#     print ('driver drops off passenger at time ', driver.time)

    
#     #find trip fare and update fare 
#     fare = env.get_fare( start_zone, dest)
#     driver.set_total_fare(driver.total_fare + fare)
#     print('trip fare from ', start_zone, 'to ', driver.location,   ' is',  fare)
#     print('driver total fare earned is ', driver.total_fare )
    
#     #frin trip cost and update cost 
#     cost = env.get_fuel_cost(start_zone, dest)
#     driver.set_total_cost(driver.total_cost + cost)
#     print('fuel cost from ', start_zone, 'to ', driver.location,   ' is', cost  )
    
#     print('************************trip is completed.************************** ')
    

# else: 
#     #time it takes before reposition 
#     print('driver does not get a pick up at the current zone: zone ', driver.location )
#     wait_time = env.wait_time_before_reposition()
#     driver.set_time( driver.time + timedelta(seconds=0, minutes= wait_time, hours=0 ) )
#     print('driver now decides to reposition after ', wait_time, ' min of crusing and current time is ', driver.time)
    
#     #find where to reposition to and update location 
#     repo = env.reposition_to(driver.location, env.get_time_window(driver.time) ) #fix this to distribution 
#     driver.set_location(repo)
#     print('driver is repostioning to zone ', repo, 'and arrived at zone ', driver.location)
    
#     # find the trip duration and update new time 
#     duration = env.get_trip_duration(start_zone = start_zone, end_zone = repo)
#     print ('reposition trip duration ', duration , 'min')
#     driver.set_time( driver.time + timedelta(seconds=0, minutes= duration, hours=0 ) )
#     print ('After repositioning, it is now ', driver.time)
                    
#     #frin trip cost and update cost 
#     cost = env.get_fuel_cost(start_zone, repo)
#     driver.set_total_cost(driver.total_cost + cost)
#     print('fuel cost from ', start_zone, 'to ', driver.location,   ' is', cost  )
                    
                    
#     print('************************reposition is completed.************************** ')
