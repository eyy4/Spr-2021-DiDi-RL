# %%
import numpy as np
import pandas as pd 
import datetime as dt
from datetime import timedelta 
import random

# %%
class Driver: 
    

    
    def __init__(self, time, location, total_fare, total_cost, is_idle ):
        self.time = time 
        self.location = location 
        self.total_fare = total_fare
        self.total_cost  = total_cost
        self.is_idle = is_idle
    
    def set_time(self, new_time):
        self.time = new_time
    
    def get_time(self):
        return self.__time 
    
    def set_location(self, new_location):
        self.location = new_location
        
    def get_location(self):
        return self.__location 
   
    def set_total_fare(self, new_fare):
        self.total_fare = new_fare
    
    def get_total_fare(self):
        return self.total_fare 
    
    def set_is_idle(self, is_idle):
        self.is_idle = is_idle 
        
    def set_total_cost(self, new_cost):
        self.total_cost = new_cost
    
    def get_total_cost(self):
        return self.total_cost

# %%
class Env: 
    
    
    arrivals = pd.read_csv('../data/arrival_rates.csv')[['taxi_zone', 'time_stamp','arr_weekday','arr_weekend']]
    dropoff_counts = pd.read_csv('../data/pickup_dropoff_summary.csv')
    fare_df = pd.read_csv('../data/fare_amount_scr_dst_t.csv')
    dist_df = pd.read_csv('../data/trip_distance_scr_dst.csv')
    trip_time_df = pd.read_csv('../data/trip_time_scr_dst_t.csv')
    prob_df = pd.read_csv('../data/prob_match_combined_new.csv')
    trans_matrix = pd.read_csv('../data/dropoff_after_pickup.csv') # fix this to shift based and a
     # 0 weekend , A night shift 
    
    #time in 1..48,  isWeekday is a boolean
    def __init__(self,  isWeekday):   

        self.isWeekday = isWeekday 
        
    
    def is_matched(self, matching_prob):
        n = random.random()

        if n <= matching_prob:
            return True 
        else: 
            False 
    
    def get_destination(self, zone):
        prob = self.trans_matrix.iloc[zone-1].values[1:]
        n = random.random()

        count = 0
        for i in range(len(prob)):
            count = count + prob[i]
            if n<count:
                return i+1

    def get_adjacent_zone( self, taxi_zone ):
        df = pd.read_csv('../data/adjacent_zone.csv')
        adj_zone_1 = df.loc[df["zone1"]==taxi_zone, "zone2"].values.tolist()
        adj_zone_2 = df.loc[df["zone2"]==taxi_zone, "zone1"].values.tolist()
        adj_zone_list = list(filter(None, adj_zone_1+adj_zone_2))
        return(adj_zone_list)
    
    def get_demand(self, zone, time):
        #row = self.arrivals.loc[ ( self.arrivals['taxi_zone'] == zone ) & (self.arrivals['time_stamp'] == time ) ]
        row = self.prob_df.loc[ ( self.arrivals['taxi_zone'] == zone ) & (self.arrivals['time_stamp'] == time ) ]
       
        if self.isWeekday:
            return row['arr_weekday'].values[0]
        else:
            return row['arr_weekend'].values[0]
    
#  def get_near_arrival():
    
    
    '''TODO： 
        fix policy fucntion - add randomness'''
    
    def reposition_to( self, current_zone, time ):
        #adj = self.get_adjacent_zone( current_zone )
        #adj.append( current_zone )
        #demand_list = [self.get_demand(zone, time) for zone in adj]
        #print(demand_list)
        # find the index of the max value of demand_lisy, and find which zone it is
        #return adj[demand_list.index( max(demand_list))]  
    
         
        adj = self.get_adjacent_zone( current_zone )
        adj.insert(0,current_zone)
        # find the index of the max value of near_prob, and find which zone it is 
        demand_list = [self.get_demand(zone, time) for zone in adj]
        a_arr  = np.array(demand_list)
        print("a_arr: ", a_arr)
        #near_prob = list(np.exp((a_arr-a_arr[0])*10)/np.sum(np.exp((a_arr-a_arr[0])*10))) 
        near_prob = list(np.exp((a_arr-a_arr[0]))/np.sum(np.exp((a_arr-a_arr[0]))))
        print("near prob :", near_prob)  
        
        r = random.random()
            
        print("r, repo, repo_prob", r, repo, repo_prob)
            
        if r <= repo_prob:
            is_repositioned = True
        else :
            is_repositioned = False
            
        return (adj[near_prob.index( max(near_prob))],  is_repositioned)
    
        #SOFTMAX 
        #NEAR ARRIVAL 
        # return the highest prob of near arrival 
        
        
        ### paper's calculation of nearest prob
        # zone 1 = 10 , zone2 = 10.1 , zone 3 = 5
        # p(zone 1) = 10/25.5 = 0.392
        # p(zone 2) = 10.1/25.5 = 0.396
        # p(zone 3) = 5/25.5 = 0.196 
        
        
        # softmax suggestion way 
        # zone 1 = 10 , zone2 = 10.1 , zone 3 = 5
        # B  = 10 
        #exp(B * (rho1 - rho1) - e) / exp(B * (rho1 - rho1)) + exp(B * (rho2 - rho1)) + exp(B * (rho3 - rho1) - e) = 0.27
        #exp(B * (rho2 - rho1) - e) / exp(10) + exp(10.2) + exp(5)  = 0.73
        #exp(B * (rho3 - rho1) - e) / exp(10) + exp(10.2) + exp(5)  = 0.0
        
        
     
    def wait_time_before_pickup(self, matching_prob):
        if ( matching_prob >= 0.9 ):
            return random.randint(1,4)
        elif ( matching_prob >= 0.7 ):
            return random.randint(5,10)
        elif ( matching_prob >= 0.5 ):
            return random.randint(11,15)
        elif ( matching_prob >= 0.3 ):
            return random.randint(16,20)
        else:
            return random.randint(21,29)
        
    def wait_time_before_reposition(self):
        return random.randint(1,10)
    
    # can look into histortical data combined with random number 

    
    
    '''TODO: 
        fix the three functions below '''
    def get_trip_duration(self, start_zone, end_zone):    
        dur = self.trip_time_df.loc[(
            (self.trip_time_df["pickup_taxizone_id"] == start_zone )  & 
            (self.trip_time_df["dropoff_taxizone_id"] == end_zone)), "mean"].describe().mean()  
        
        return dur
        
    def get_fare(self, start_zone, end_zone): 
        fare = self.fare_df.loc[((self.fare_df["pickup_taxizone_id"] == start_zone) & 
                                 (self.fare_df["dropoff_taxizone_id"] == end_zone)), "mean"].describe().mean()
        return fare
    
    def get_trip_distance(self, start_zone, end_zone):
        dist = self.dist_df.loc[((self.dist_df["pickup_taxizone_id"] == start_zone) &
                                 (self. dist_df["dropoff_taxizone_id"] == end_zone)), "mean"].describe().mean()
        
        return dist 
    
    def get_fuel_cost(self, start_zone, end_zone): 
        
        cost = self.dist_df.loc[((self.dist_df["pickup_taxizone_id"] == start_zone) &
                                 (self. dist_df["dropoff_taxizone_id"] == end_zone)), "mean"].describe().mean()*0.124
        return cost 
    
    def get_matching_prob(self, zone, time):
        if self.isWeekday:
            prob = self.prob_df.loc[(self.prob_df['taxi_zone'] == zone) & 
                                    (self.prob_df['time_stamp'] == time)].mod_prob_match_weekday.values[0]
        else: 
            prob = self.prob_df.loc[(self.prob_df['taxi_zone'] == zone) & 
                                    (self.prob_df['time_stamp'] == time)].mod_prob_match_weekend.values[0]
            
        return prob 
    
    
    time_bins = [dt.time(0,0),dt.time(0,30), dt.time(1,0), dt.time(1,30), dt.time(2,0), 
        dt.time(2,30), dt.time(3,0), dt.time(3,30), dt.time(4,0),
        dt.time(4,30), dt.time(5,0), dt.time(5,30), dt.time(6,0),
        dt.time(6,30), dt.time(7,0), dt.time(7,30), dt.time(8,0),
        dt.time(8,30), dt.time(9,0), dt.time(9,30), dt.time(10,0),
        dt.time(10,30), dt.time(11,0), dt.time(11,30), dt.time(12,0),
        dt.time(12,30), dt.time(13,0), dt.time(13,30), dt.time(14,0),
        dt.time(14,30), dt.time(15,0), dt.time(15,30), dt.time(16,0), 
        dt.time(16,30), dt.time(17,0), dt.time(17,30), dt.time(18,0),
        dt.time(18,30), dt.time(19,0), dt.time(19,30), dt.time(20,0),
        dt.time(20,30), dt.time(21,0), dt.time(21,30), dt.time(22,0),
        dt.time(22,30), dt.time(23,0), dt.time(23,30), dt.time(23,59,59)] 
    
    
    def get_time_window(self, datetime):
        for i in range(0,48):
            if (datetime.time() >= self.time_bins[i]) & (datetime.time() < self.time_bins[i+1]): 
                return i+1

# %%
# one round of simulation 

init_time = dt.datetime(2013, 6, 3, 5, 0, 0) 
init_zone = 66

#Initialize enviorment and driver 
env = Env( isWeekday = True ) 
driver = Driver( time = init_time, location = init_zone, total_fare = 0, total_cost = 0, is_idle = True) 

# print(driver.location)
# print(driver.time)
# print(driver.total_fare)
# print(driver.total_cost)
# print(driver.is_idle)


while driver.time < init_time + timedelta(seconds=0, minutes=0, hours = 11):
    #get prob that driver will be matched to a passenger 
    matching_prob = env.get_matching_prob( zone = driver.location, time = env.get_time_window(driver.time) )
    #print(matching_prob)
    start_zone = driver.location
    print('current time is ', driver.time, 'and driver is at zone ', driver.location)
    if env.is_matched(matching_prob):

        # time it takes before getting matched 
        wait_time = env.wait_time_before_pickup(matching_prob)
        print('driver waited for ', wait_time, ' min before he picks up')

        # set driver time to new time 
        driver.set_time( driver.time + timedelta(seconds=0, minutes= wait_time, hours=0 ) )
        print('driver gets a pick up and is now at time ', driver.time)    


        #driver is now busy 
        driver.set_is_idle(False)


        # find the destination of the trip and set destination 
        dest = env.get_destination(driver.location)
        driver.set_location(dest)
        print ('driver is going to zone', dest, 'and driver arrived at zone', driver.location)    

         # find the trip duration and update new time 
        duration = env.get_trip_duration(start_zone = start_zone, end_zone = dest)
        print ('trip duration ', duration)
        driver.set_time( driver.time + timedelta(seconds=0, minutes= duration, hours=0 ) )
        print ('driver drops off passenger at time ', driver.time)


        #find trip fare and update fare 
        fare = env.get_fare( start_zone, dest)
        driver.set_total_fare(driver.total_fare + fare)
        print('trip fare from ', start_zone, 'to ', driver.location,   ' is',  fare)
        print('driver total fare earned is ', driver.total_fare )

        #frin trip cost and update cost 
        cost = env.get_fuel_cost(start_zone, dest)
        driver.set_total_cost(driver.total_cost + cost)
        print('fuel cost from ', start_zone, 'to ', driver.location,   ' is', cost  )

        print('************************trip is completed.************************** ')


    else: 
        #time it takes before reposition 
        print('driver does not get a pick up at the current zone: zone ', driver.location )
        
        wait_time = env.wait_time_before_reposition()
        driver.set_time( driver.time + timedelta(seconds=0, minutes= wait_time, hours=0 ) )
        print('driver now decides to check reposition info after ', wait_time, ' min of crusing and current time is ', driver.time)
        '''
            TODO:
            add cost - assume 10 miles a hour '''
        
        repo,repo_status = env.reposition_to(driver.location, env.get_time_window(driver.time) ) #fix this to distribution 
        
        while(repo_status == False ):
            wait_time = env.wait_time_before_reposition()
            driver.set_time( driver.time + timedelta(seconds=0, minutes= wait_time, hours=0 ) )
            print('driver now decides to check reposition info again after ', wait_time, ' min of crusing and current time is ', driver.time)
            repo,repo_status = env.reposition_to(driver.location, env.get_time_window(driver.time) ) #fix this to distribution 
            '''
            TODO:
            add cost - assume 10 miles a hour '''
                                                                       
                
        driver.set_location(repo)
        print('driver is repostioning to zone ', repo, 'and arrived at zone ', driver.location)

        # find the trip duration and update new time 
        duration = env.get_trip_duration(start_zone = start_zone, end_zone = repo)
        print ('reposition trip duration ', duration , 'min')
        driver.set_time( driver.time + timedelta(seconds=0, minutes= duration, hours=0 ) )
        print ('After repositioning, it is now ', driver.time)

        #frin trip cost and update cost 
        cost = env.get_fuel_cost(start_zone, repo)
        driver.set_total_cost(driver.total_cost + cost)
        print('fuel cost from ', start_zone, 'to ', driver.location,   ' is', cost  )


        print('************************reposition is completed.************************** ')


        
print('total fare earned from this shift is ', driver.total_fare )
print('total fuel cost is ', driver.total_cost)
print('profit is ', driver.total_fare - driver.total_cost)
# Out:
# current time is  2013-06-03 05:00:00 and driver is at zone  66
# driver waited for  19  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 05:19:00
# driver is going to zone 87 and driver arrived at zone 87
# trip duration  13.398095320065348
# driver drops off passenger at time  2013-06-03 05:32:23.885719
# trip fare from  66 to  87  is 13.675607717169186
# driver total fare earned is  13.675607717169186
# fuel cost from  66 to  87  is 0.26185306122448976
# ************************trip is completed.**************************
# current time is  2013-06-03 05:32:23.885719 and driver is at zone  87
# driver waited for  2  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 05:34:23.885719
# driver is going to zone 140 and driver arrived at zone 140
# trip duration  18.051764993400713
# driver drops off passenger at time  2013-06-03 05:52:26.991619
# trip fare from  87 to  140  is 20.744797849698983
# driver total fare earned is  34.42040556686817
# fuel cost from  87 to  140  is 0.6547810290827748
# ************************trip is completed.**************************
# current time is  2013-06-03 05:52:26.991619 and driver is at zone  140
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 05:56:26.991619
# driver is going to zone 164 and driver arrived at zone 164
# trip duration  18.385263006343322
# driver drops off passenger at time  2013-06-03 06:14:50.107399
# trip fare from  140 to  164  is 16.093174830208152
# driver total fare earned is  50.513580397076325
# fuel cost from  140 to  164  is 0.3123013236281399
# ************************trip is completed.**************************
# current time is  2013-06-03 06:14:50.107399 and driver is at zone  164
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 06:17:50.107399
# driver is going to zone 170 and driver arrived at zone 170
# trip duration  10.176847907864286
# driver drops off passenger at time  2013-06-03 06:28:00.718273
# trip fare from  164 to  170  is 10.243299327058228
# driver total fare earned is  60.75687972413455
# fuel cost from  164 to  170  is 0.09538944117961339
# ************************trip is completed.**************************
# current time is  2013-06-03 06:28:00.718273 and driver is at zone  170
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 06:32:00.718273
# driver is going to zone 261 and driver arrived at zone 261
# trip duration  19.136969000433922
# driver drops off passenger at time  2013-06-03 06:51:08.936413
# trip fare from  170 to  261  is 19.17812334710125
# driver total fare earned is  79.9350030712358
# fuel cost from  170 to  261  is 0.520674178905206
# ************************trip is completed.**************************
# current time is  2013-06-03 06:51:08.936413 and driver is at zone  261
# driver waited for  7  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 06:58:08.936413
# driver is going to zone 148 and driver arrived at zone 148
# trip duration  16.032469747073122
# driver drops off passenger at time  2013-06-03 07:14:10.884598
# trip fare from  261 to  148  is 14.335804171421
# driver total fare earned is  94.2708072426568
# fuel cost from  261 to  148  is 0.25948005811138036
# ************************trip is completed.**************************
# current time is  2013-06-03 07:14:10.884598 and driver is at zone  148
# driver waited for  2  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 07:16:10.884598
# driver is going to zone 7 and driver arrived at zone 7
# trip duration  25.46082629966591
# driver drops off passenger at time  2013-06-03 07:41:38.534176
# trip fare from  148 to  7  is 24.730798443080594
# driver total fare earned is  119.00160568573739
# fuel cost from  148 to  7  is 0.8215501643489239
# ************************trip is completed.**************************
# current time is  2013-06-03 07:41:38.534176 and driver is at zone  7
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 07:45:38.534176
# driver is going to zone 186 and driver arrived at zone 186
# trip duration  24.38681641465596
# driver drops off passenger at time  2013-06-03 08:10:01.743161
# trip fare from  7 to  186  is 21.283561496945822
# driver total fare earned is  140.2851671826832
# fuel cost from  7 to  186  is 0.5607674172185433
# ************************trip is completed.**************************
# current time is  2013-06-03 08:10:01.743161 and driver is at zone  186
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 08:14:01.743161
# driver is going to zone 143 and driver arrived at zone 143
# trip duration  15.497252559987016
# driver drops off passenger at time  2013-06-03 08:29:31.578315
# trip fare from  186 to  143  is 14.327589125583371
# driver total fare earned is  154.61275630826657
# fuel cost from  186 to  143  is 0.2742130282920011
# ************************trip is completed.**************************
# current time is  2013-06-03 08:29:31.578315 and driver is at zone  143
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 08:33:31.578315
# driver is going to zone 239 and driver arrived at zone 239
# trip duration  9.089338649743771
# driver drops off passenger at time  2013-06-03 08:42:36.938634
# trip fare from  143 to  239  is 9.95552884284311
# driver total fare earned is  164.56828515110968
# fuel cost from  143 to  239  is 0.11074141712250334
# ************************trip is completed.**************************
# current time is  2013-06-03 08:42:36.938634 and driver is at zone  239
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 08:43:36.938634
# driver is going to zone 170 and driver arrived at zone 170
# trip duration  19.563611964505874
# driver drops off passenger at time  2013-06-03 09:03:10.755352
# trip fare from  239 to  170  is 16.923402691321783
# driver total fare earned is  181.49168784243147
# fuel cost from  239 to  170  is 0.3558806494696866
# ************************trip is completed.**************************
# current time is  2013-06-03 09:03:10.755352 and driver is at zone  170
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 09:06:10.755352
# driver is going to zone 48 and driver arrived at zone 48
# trip duration  14.977226265403846
# driver drops off passenger at time  2013-06-03 09:21:09.388928
# trip fare from  170 to  48  is 13.205203243881936
# driver total fare earned is  194.6968910863134
# fuel cost from  170 to  48  is 0.17645074389610368
# ************************trip is completed.**************************
# current time is  2013-06-03 09:21:09.388928 and driver is at zone  48
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 09:25:09.388928
# driver is going to zone 141 and driver arrived at zone 141
# trip duration  16.176504262642908
# driver drops off passenger at time  2013-06-03 09:41:19.979184
# trip fare from  48 to  141  is 14.497387709526638
# driver total fare earned is  209.19427879584003
# fuel cost from  48 to  141  is 0.2638447761194033
# ************************trip is completed.**************************
# current time is  2013-06-03 09:41:19.979184 and driver is at zone  141
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 09:45:19.979184
# driver is going to zone 43 and driver arrived at zone 43
# trip duration  12.88782413855616
# driver drops off passenger at time  2013-06-03 09:58:13.248632
# trip fare from  141 to  43  is 12.17128551561418
# driver total fare earned is  221.36556431145422
# fuel cost from  141 to  43  is 0.17435697693774016
# ************************trip is completed.**************************
# current time is  2013-06-03 09:58:13.248632 and driver is at zone  43
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 10:01:13.248632
# driver is going to zone 107 and driver arrived at zone 107
# trip duration  18.530368288741357
# driver drops off passenger at time  2013-06-03 10:19:45.070729
# trip fare from  43 to  107  is 16.214837554603363
# driver total fare earned is  237.58040186605757
# fuel cost from  43 to  107  is 0.3480643875043876
# ************************trip is completed.**************************
# current time is  2013-06-03 10:19:45.070729 and driver is at zone  107
# driver waited for  2  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 10:21:45.070729
# driver is going to zone 211 and driver arrived at zone 211
# trip duration  13.231173108082807
# driver drops off passenger at time  2013-06-03 10:34:58.941115
# trip fare from  107 to  211  is 12.445810443270473
# driver total fare earned is  250.02621230932803
# fuel cost from  107 to  211  is 0.1919430057988662
# ************************trip is completed.**************************
# current time is  2013-06-03 10:34:58.941115 and driver is at zone  211
# driver does not get a pick up at the current zone: zone  211
# driver now decides to check reposition info after  9  min of crusing and current time is  2013-06-03 10:43:58.941115
# a_arr:  [ 97.22854248 222.70183392  95.49358719  81.61881668  89.67741566]
# near prob : [3.2184139607328617e-55, 1.0, 5.6775425001027925e-56, 5.3508666092558844e-62, 1.6913332698721644e-58]
# r, repo, repo_prob 0.0813092710897152 237 0.36581419853136365
# driver is repostioning to zone  231 and arrived at zone  231
# reposition trip duration  11.279395052818519 min
# After repositioning, it is now  2013-06-03 10:55:15.704818
# fuel cost from  211 to  231  is 0.12267789018810342
# ************************reposition is completed.**************************
# current time is  2013-06-03 10:55:15.704818 and driver is at zone  231
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 10:59:15.704818
# driver is going to zone 114 and driver arrived at zone 114
# trip duration  12.119443484963002
# driver drops off passenger at time  2013-06-03 11:11:22.871427
# trip fare from  231 to  114  is 11.657488980141968
# driver total fare earned is  261.68370128947
# fuel cost from  231 to  114  is 0.15381919459507476
# ************************trip is completed.**************************
# current time is  2013-06-03 11:11:22.871427 and driver is at zone  114
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 11:15:22.871427
# driver is going to zone 170 and driver arrived at zone 170
# trip duration  14.579556023237418
# driver drops off passenger at time  2013-06-03 11:29:57.644788
# trip fare from  114 to  170  is 13.611064858047605
# driver total fare earned is  275.2947661475176
# fuel cost from  114 to  170  is 0.23611954561760026
# ************************trip is completed.**************************
# current time is  2013-06-03 11:29:57.644788 and driver is at zone  170
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 11:32:57.644788
# driver is going to zone 234 and driver arrived at zone 234
# trip duration  10.955772761697729
# driver drops off passenger at time  2013-06-03 11:43:54.991154
# trip fare from  170 to  234  is 10.91298489379334
# driver total fare earned is  286.2077510413109
# fuel cost from  170 to  234  is 0.1311631741541098
# ************************trip is completed.**************************
# current time is  2013-06-03 11:43:54.991154 and driver is at zone  234
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 11:44:54.991154
# driver is going to zone 142 and driver arrived at zone 142
# trip duration  17.755016274071693
# driver drops off passenger at time  2013-06-03 12:02:40.292130
# trip fare from  234 to  142  is 15.833151911805766
# driver total fare earned is  302.0409029531167
# fuel cost from  234 to  142  is 0.32394752361228
# ************************trip is completed.**************************
# current time is  2013-06-03 12:02:40.292130 and driver is at zone  142
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 12:06:40.292130
# driver is going to zone 141 and driver arrived at zone 141
# trip duration  14.382828760149406
# driver drops off passenger at time  2013-06-03 12:21:03.261856
# trip fare from  142 to  141  is 13.135699334972804
# driver total fare earned is  315.1766022880895
# fuel cost from  142 to  141  is 0.20225784182892118
# ************************trip is completed.**************************
# current time is  2013-06-03 12:21:03.261856 and driver is at zone  141
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 12:24:03.261856
# driver is going to zone 237 and driver arrived at zone 237
# trip duration  10.112903552406367
# driver drops off passenger at time  2013-06-03 12:34:10.036069
# trip fare from  141 to  237  is 10.252221723754904
# driver total fare earned is  325.4288240118444
# fuel cost from  141 to  237  is 0.10030071558278283
# ************************trip is completed.**************************
# current time is  2013-06-03 12:34:10.036069 and driver is at zone  237
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 12:35:10.036069
# driver is going to zone 48 and driver arrived at zone 48
# trip duration  15.96145962427923
# driver drops off passenger at time  2013-06-03 12:51:07.723646
# trip fare from  237 to  48  is 13.962771573748896
# driver total fare earned is  339.39159558559334
# fuel cost from  237 to  48  is 0.21942464285714292
# ************************trip is completed.**************************
# current time is  2013-06-03 12:51:07.723646 and driver is at zone  48
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 12:54:07.723646
# driver is going to zone 161 and driver arrived at zone 161
# trip duration  13.12798927101002
# driver drops off passenger at time  2013-06-03 13:07:15.403002
# trip fare from  48 to  161  is 11.79130323021202
# driver total fare earned is  351.18289881580534
# fuel cost from  48 to  161  is 0.12885702091055115
# ************************trip is completed.**************************
# current time is  2013-06-03 13:07:15.403002 and driver is at zone  161
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 13:10:15.403002
# driver is going to zone 138 and driver arrived at zone 138
# trip duration  25.63215248326073
# driver drops off passenger at time  2013-06-03 13:35:53.332151
# trip fare from  161 to  138  is 28.2760585873911
# driver total fare earned is  379.45895740319645
# fuel cost from  161 to  138  is 1.1074637441602617
# ************************trip is completed.**************************
# current time is  2013-06-03 13:35:53.332151 and driver is at zone  138
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 13:39:53.332151
# driver is going to zone 181 and driver arrived at zone 181
# trip duration  32.54970710663282
# driver drops off passenger at time  2013-06-03 14:12:26.314577
# trip fare from  138 to  181  is 33.73982074613167
# driver total fare earned is  413.1987781493281
# fuel cost from  138 to  181  is 1.2978403118773283
# ************************trip is completed.**************************
# current time is  2013-06-03 14:12:26.314577 and driver is at zone  181
# driver waited for  28  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 14:40:26.314577
# driver is going to zone 228 and driver arrived at zone 228
# trip duration  13.64449589902529
# driver drops off passenger at time  2013-06-03 14:54:04.984331
# trip fare from  181 to  228  is 13.43009389786198
# driver total fare earned is  426.6288720471901
# fuel cost from  181 to  228  is 0.2207342985265854
# ************************trip is completed.**************************
# current time is  2013-06-03 14:54:04.984331 and driver is at zone  228
# driver does not get a pick up at the current zone: zone  228
# driver now decides to check reposition info after  2  min of crusing and current time is  2013-06-03 14:56:04.984331
# a_arr:  [1.61609375 1.93757813 1.93757813 5.37520996 1.97736328 0.
#  4.7604541  1.75430664 2.        ]
# near prob : [0.013490959662239236, 0.018606373465803565, 0.018606373465803565, 0.5789036275893092, 0.019361553816152226, 0.00268029283803404, 0.3130553957286511, 0.015490589292211294, 0.019804834141795725]
# r, repo, repo_prob 0.9787023853645352 231 0.36581419853136365
# driver now decides to check reposition info again after  1  min of crusing and current time is  2013-06-03 14:57:04.984331
# a_arr:  [1.61609375 1.93757813 1.93757813 5.37520996 1.97736328 0.
#  4.7604541  1.75430664 2.        ]
# near prob : [0.013490959662239236, 0.018606373465803565, 0.018606373465803565, 0.5789036275893092, 0.019361553816152226, 0.00268029283803404, 0.3130553957286511, 0.015490589292211294, 0.019804834141795725]
# r, repo, repo_prob 0.22178884965214996 40 0.36581419853136365
# driver is repostioning to zone  40 and arrived at zone  40
# reposition trip duration  9.11077254289053 min
# After repositioning, it is now  2013-06-03 15:06:11.630684
# fuel cost from  228 to  40  is 0.21749600000000002
# ************************reposition is completed.**************************
# current time is  2013-06-03 15:06:11.630684 and driver is at zone  40
# driver waited for  5  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 15:11:11.630684
# driver is going to zone 181 and driver arrived at zone 181
# trip duration  12.331817920673547
# driver drops off passenger at time  2013-06-03 15:23:31.539759
# trip fare from  40 to  181  is 12.025880127210444
# driver total fare earned is  438.6547521744005
# fuel cost from  40 to  181  is 0.18648277583435735
# ************************trip is completed.**************************
# current time is  2013-06-03 15:23:31.539759 and driver is at zone  181
# driver does not get a pick up at the current zone: zone  181
# driver now decides to check reposition info after  5  min of crusing and current time is  2013-06-03 15:28:31.539759
# a_arr:  [5.82632324 2.26821533 1.62169922 1.6420752  1.93757813 7.42237976
#  6.38807739 1.77976563]
# near prob : [0.1284704519352244, 0.0036604680498438158, 0.001917600967024277, 0.0019570747521255095, 0.0026299210183070043, 0.6338139457575731, 0.2253045589503219, 0.0022459785695799236]
# r, repo, repo_prob 0.8590610170993609 40 0.36581419853136365
# driver now decides to check reposition info again after  4  min of crusing and current time is  2013-06-03 15:32:31.539759
# a_arr:  [5.85660156 2.41274414 1.47119141 1.68320313 1.         8.50924866
#  6.12692566 1.75225586]
# near prob : [0.0602917361655455, 0.001925792607436134, 0.0007511010312867219, 0.0009284828318997981, 0.000468880887735109, 0.8556335115242493, 0.07900563236410402, 0.0009948625877435268]
# r, repo, repo_prob 0.10318699165100553 25 0.36581419853136365
# driver is repostioning to zone  25 and arrived at zone  25
# reposition trip duration  13.111868134847388 min
# After repositioning, it is now  2013-06-03 15:45:38.251847
# fuel cost from  181 to  25  is 0.15997807580174944
# ************************reposition is completed.**************************
# current time is  2013-06-03 15:45:38.251847 and driver is at zone  25
# driver waited for  2  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 15:47:38.251847
# driver is going to zone 181 and driver arrived at zone 181
# trip duration  12.363504003790556
# driver drops off passenger at time  2013-06-03 16:00:00.062087
# trip fare from  25 to  181  is 12.319959256810574
# driver total fare earned is  450.9747114312111
# fuel cost from  25 to  181  is 0.19142663321625697
# ************************trip is completed.**************************
# total fare earned from this shift is  450.9747114312111
# total fuel cost is  10.382281047602868
# profit is  440.59243038360825

# %%
'''TODO: 
Monte Carlo Simulation'''
# Out:
# 'TODO: \nMonte Carlo Simulation'

# %%
# # one round of simulation 

# init_time = dt.datetime(2013, 6, 3, 5, 0, 0) 
# init_zone = 66

# #Initialize enviorment and driver 
# env = Env( isWeekday = True ) 
# driver = Driver( time = init_time, location = init_zone, total_fare = 0, total_cost = 0, is_idle = True) 

# # print(driver.location)
# # print(driver.time)
# # print(driver.total_fare)
# # print(driver.total_cost)
# # print(driver.is_idle)

# #get prob that driver will be matched to a passenger 
# matching_prob = env.get_matching_prob( zone = driver.location, time = env.get_time_window(driver.time) )
# #print(matching_prob)
# start_zone = driver.location
# print('current time is ', driver.time, 'and driver is at zone ', driver.location)
# if env.is_matched(matching_prob):
    
#     # time it takes before getting matched 
#     wait_time = env.wait_time_before_pickup(matching_prob)
#     print('driver waited for ', wait_time, ' min before he picks up')
    
#     # set driver time to new time 
#     driver.set_time( driver.time + timedelta(seconds=0, minutes= wait_time, hours=0 ) )
#     print('driver gets a pick up and is now at time ', driver.time)    
    
    
#     #driver is now busy 
#     driver.set_is_idle(False)
    
                        
#     # find the destination of the trip and set destination 
#     dest = env.get_destination(driver.location)
#     driver.set_location(dest)
#     print ('driver is going to zone', dest, 'and driver arrived at zone', driver.location)    
    
#      # find the trip duration and update new time 
#     duration = env.get_trip_duration(start_zone = start_zone, end_zone = dest)
#     print ('trip duration ', duration)
#     driver.set_time( driver.time + timedelta(seconds=0, minutes= duration, hours=0 ) )
#     print ('driver drops off passenger at time ', driver.time)

    
#     #find trip fare and update fare 
#     fare = env.get_fare( start_zone, dest)
#     driver.set_total_fare(driver.total_fare + fare)
#     print('trip fare from ', start_zone, 'to ', driver.location,   ' is',  fare)
#     print('driver total fare earned is ', driver.total_fare )
    
#     #frin trip cost and update cost 
#     cost = env.get_fuel_cost(start_zone, dest)
#     driver.set_total_cost(driver.total_cost + cost)
#     print('fuel cost from ', start_zone, 'to ', driver.location,   ' is', cost  )
    
#     print('************************trip is completed.************************** ')
    

# else: 
#     #time it takes before reposition 
#     print('driver does not get a pick up at the current zone: zone ', driver.location )
#     wait_time = env.wait_time_before_reposition()
#     driver.set_time( driver.time + timedelta(seconds=0, minutes= wait_time, hours=0 ) )
#     print('driver now decides to reposition after ', wait_time, ' min of crusing and current time is ', driver.time)
    
#     #find where to reposition to and update location 
#     repo = env.reposition_to(driver.location, env.get_time_window(driver.time) ) #fix this to distribution 
#     driver.set_location(repo)
#     print('driver is repostioning to zone ', repo, 'and arrived at zone ', driver.location)
    
#     # find the trip duration and update new time 
#     duration = env.get_trip_duration(start_zone = start_zone, end_zone = repo)
#     print ('reposition trip duration ', duration , 'min')
#     driver.set_time( driver.time + timedelta(seconds=0, minutes= duration, hours=0 ) )
#     print ('After repositioning, it is now ', driver.time)
                    
#     #frin trip cost and update cost 
#     cost = env.get_fuel_cost(start_zone, repo)
#     driver.set_total_cost(driver.total_cost + cost)
#     print('fuel cost from ', start_zone, 'to ', driver.location,   ' is', cost  )
                    
                    
#     print('************************reposition is completed.************************** ')
