# %%
import numpy as np
import pandas as pd 
import datetime as dt
from datetime import timedelta 
import random

# %%
class Driver: 
    

    
    def __init__(self, time, location, total_fare, total_cost, is_idle ):
        self.time = time 
        self.location = location 
        self.total_fare = total_fare
        self.total_cost  = total_cost
        self.is_idle = is_idle
    
    def set_time(self, new_time):
        self.time = new_time
    
    def get_time(self):
        return self.__time 
    
    def set_location(self, new_location):
        self.location = new_location
        
    def get_location(self):
        return self.__location 
   
    def set_total_fare(self, new_fare):
        self.total_fare = new_fare
    
    def get_total_fare(self):
        return self.total_fare 
    
    def set_is_idle(self, is_idle):
        self.is_idle = is_idle 
        
    def set_total_cost(self, new_cost):
        self.total_cost = new_cost
    
    def get_total_cost(self):
        return self.total_cost 
    
    def get_shift_time_weekday(self):


        weekend = [5,6]
        weekend_ind = lambda n: 0 if n in weekend else 1
        weekday = weekend_ind(self.time.weekday)

        normtime = driver.time.time()
        roundtime = pd.Timestamp(driver.time).round('30min').time()
        
        
        if weekday:
            if (normtime > dt.time(23, 30)) | (normtime <= dt.time(11, 30)):
                return ('A', roundtime,weekday)
            else:
                return ('B', roundtime,weekday)
        else: ## weekend
            if (normtime > dt.time(2, 0)) & (normtime <= dt.time(14, 0)):
                return ('A', roundtime,weekday)
            else:
                return ('B', roundtime,weekday)

# %%
class Env: 
    
    
    arrivals = pd.read_csv('../data/arrival_rates.csv')[['taxi_zone', 'time_stamp','arr_weekday','arr_weekend']]
    dropoff_counts = pd.read_csv('../data/pickup_dropoff_summary.csv')
    fare_df = pd.read_csv('../data/fare_amount_scr_dst_t.csv')
    dist_df = pd.read_csv('../data/trip_distance_scr_dst.csv')
    trip_time_df = pd.read_csv('../data/trip_time_scr_dst_t.csv')
    prob_df = pd.read_csv('../data/prob_match_combined_new.csv')
    trans_matrix = pd.read_csv('../data/dropoff_after_pickup.csv') # fix this to shift based and a
     # 0 weekend , A night shift 
    
    #time in 1..48,  isWeekday is a boolean
    def __init__(self,  isWeekday):   

        self.isWeekday = isWeekday 
        
    
    def is_matched(self, matching_prob):
        n = random.random()

        if n <= matching_prob:
            return True 
        else: 
            False 
    
    def get_destination(self, zone):
        prob = self.trans_matrix.iloc[zone-1].values[1:]
        n = random.random()

        count = 0
        for i in range(len(prob)):
            count = count + prob[i]
            if n<count:
                return i+1

    def get_adjacent_zone( self, taxi_zone ):
        df = pd.read_csv('../data/adjacent_zone.csv')
        adj_zone_1 = df.loc[df["zone1"]==taxi_zone, "zone2"].values.tolist()
        adj_zone_2 = df.loc[df["zone2"]==taxi_zone, "zone1"].values.tolist()
        adj_zone_list = list(filter(None, adj_zone_1+adj_zone_2))
        return(adj_zone_list)
    
    def get_demand(self, zone, time):
        #row = self.arrivals.loc[ ( self.arrivals['taxi_zone'] == zone ) & (self.arrivals['time_stamp'] == time ) ]
        row = self.prob_df.loc[ ( self.arrivals['taxi_zone'] == zone ) & (self.arrivals['time_stamp'] == time ) ]
       
        if self.isWeekday:
            return row['arr_weekday'].values[0]
        else:
            return row['arr_weekend'].values[0]
    
     #  def get_near_arrival():
    
    
    '''TODO： 
        fix policy fucntion - add randomness'''
   
       
            
    def reposition_to( self, current_zone, time ):
        #adj = self.get_adjacent_zone( current_zone )
        #adj.append( current_zone )
        #demand_list = [self.get_demand(zone, time) for zone in adj]
        #print(demand_list)
        # find the index of the max value of demand_lisy, and find which zone it is
        #return adj[demand_list.index( max(demand_list))]  
    
         
        adj = self.get_adjacent_zone( current_zone )
        adj.insert(0,current_zone)
        # find the index of the max value of near_prob, and find which zone it is 
        demand_list = [self.get_demand(zone, time) for zone in adj]
        a_arr  = np.array(demand_list)
        print("a_arr: ", a_arr)
        #near_prob = list(np.exp((a_arr-a_arr[0])*10)/np.sum(np.exp((a_arr-a_arr[0])*10))) 
        near_prob = list(np.exp((a_arr-a_arr[0]))/np.sum(np.exp((a_arr-a_arr[0]))))
        print("near prob :", near_prob)  
        
        # 20, 28, 52
        
        r = random.random()
        #25
        
        count = 0
        for i in range(len(near_prob)):
            count = count + near_prob[i]
            if r < count:
                return(adj[i])  
        
        #repo_zone = adj[r_index]   
        
        #repo_prob = near_prob.index( max(near_prob))
        
    
        #print("r, repo, repo_prob", r, repo, repo_prob)
            
      
            
          
        #return (adj[near_prob.index( max(near_prob))],  is_repositioned)
    
        #SOFTMAX 
        #NEAR ARRIVAL 
        # return the highest prob of near arrival 
        
        
        ### paper's calculation of nearest prob
        # zone 1 = 10 , zone2 = 10.1 , zone 3 = 5
        # p(zone 1) = 10/25.5 = 0.392
        # p(zone 2) = 10.1/25.5 = 0.396
        # p(zone 3) = 5/25.5 = 0.196 
        
        
        # softmax suggestion way 
        # zone 1 = 10 , zone2 = 10.1 , zone 3 = 5
        # B  = 10 
        #exp(B * (rho1 - rho1) - e) / exp(B * (rho1 - rho1)) + exp(B * (rho2 - rho1)) + exp(B * (rho3 - rho1) - e) = 0.27
        #exp(B * (rho2 - rho1) - e) / exp(10) + exp(10.2) + exp(5)  = 0.73
        #exp(B * (rho3 - rho1) - e) / exp(10) + exp(10.2) + exp(5)  = 0.0
        
        
     
    def wait_time_before_pickup(self, matching_prob):
        if ( matching_prob >= 0.9 ):
            return random.randint(1,4)
        elif ( matching_prob >= 0.7 ):
            return random.randint(5,10)
        elif ( matching_prob >= 0.5 ):
            return random.randint(11,15)
        elif ( matching_prob >= 0.3 ):
            return random.randint(16,20)
        else:
            return random.randint(21,29)
        
    def wait_time_before_reposition(self):
        return random.randint(1,10)
    
    # can look into histortical data combined with random number 

    
    
    def get_trip_duration(self, start_zone, end_zone, shift_time):    
        shift,roundtime,weekday_ind = shift_time
        roundtime = roundtime.strftime('%H:%M:%S') 
        
        zone_to_zone = self.trip_time_df[(self.trip_time_df["pickup_taxizone_id"] == start_zone) & 
                                        (self.trip_time_df["dropoff_taxizone_id"] == end_zone) &
                                        (self.trip_time_df["actual_data"] == 1)]
        
        if len(zone_to_zone)!=0:
            if len(zone_to_zone[(zone_to_zone['_PU_shift']==shift) & (zone_to_zone['pickup_datetime_interval']==roundtime) &
                                (zone_to_zone['pickup_weekday'] == weekday_ind)])>0:

                dur = zone_to_zone.loc[(zone_to_zone["_PU_shift"] == shift) &
                                       (zone_to_zone["pickup_datetime_interval"] == roundtime) &
                                       (zone_to_zone['pickup_weekday'] == weekday_ind), "mean"].mean() 

            elif len(zone_to_zone[(zone_to_zone['_PU_shift']==shift) & (zone_to_zone['pickup_weekday'] == weekday_ind)])>0:
                dur = zone_to_zone.loc[(zone_to_zone["_PU_shift"] == shift) &
                                       (zone_to_zone['pickup_weekday'] == weekday_ind), "mean"].mean()

            else:
                dur = zone_to_zone['mean'].mean()
        else: 
            dur = self.trip_time_df.loc[(self.trip_time_df["pickup_taxizone_id"] == start_zone) & 
                                    (self.trip_time_df["dropoff_taxizone_id"] == end_zone) &
                                    (self.trip_time_df["actual_data"] == 0),"mean"].mean()
        
        return dur
        
    def get_fare(self, start_zone, end_zone, shift_time): 
        
        shift,roundtime,weekday_ind = shift_time
        roundtime = roundtime.strftime('%H:%M:%S') 
        
        zone_to_zone = self.fare_df[(self.fare_df["pickup_taxizone_id"] == start_zone) & 
                                    (self.fare_df["dropoff_taxizone_id"] == end_zone) &
                                    (self.fare_df["actual_data"] == 1)]
                
        if len(zone_to_zone)!=0:
            if len(zone_to_zone[(zone_to_zone['_PU_shift']==shift) & (zone_to_zone['pickup_datetime_interval']==roundtime) &
                                (zone_to_zone['pickup_weekday'] == weekday_ind)])>0:

                fare = zone_to_zone.loc[(zone_to_zone["_PU_shift"] == shift) &
                                       (zone_to_zone["pickup_datetime_interval"] == roundtime) &
                                       (zone_to_zone['pickup_weekday'] == weekday_ind), "mean"].mean() 

            elif len(zone_to_zone[(zone_to_zone['_PU_shift']==shift) & (zone_to_zone['pickup_weekday'] == weekday_ind)])>0:
                fare = zone_to_zone.loc[(zone_to_zone["_PU_shift"] == shift) &
                                       (zone_to_zone['pickup_weekday'] == weekday_ind), "mean"].mean()

            else:
                fare = zone_to_zone['mean'].mean()
        else:
            dur = self.fare_df.loc[(self.fare_df["pickup_taxizone_id"] == start_zone) & 
                                    (self.fare_df["dropoff_taxizone_id"] == end_zone) &
                                    (self.fare_df["actual_data"] == 0),"mean"].mean()
        
        return fare
    
    def get_trip_distance(self, start_zone, end_zone):
        zone_to_zone = self.dist_df.loc[((self.dist_df["pickup_taxizone_id"] == start_zone) &
                                 (self. dist_df["dropoff_taxizone_id"] == end_zone) &
                                 (self.trip_time_df["actual_data"] == 1)), "mean"]
        if len(zone_to_zone) != 0:
            dist = zone_to_zone.mean()
        else:
            dist = self.dist_df.loc[((self.dist_df["pickup_taxizone_id"] == start_zone) &
                                 (self. dist_df["dropoff_taxizone_id"] == end_zone) &
                                 (self.trip_time_df["actual_data"] == 0)), "mean"]
        
        return dist 
    
    def get_fuel_cost(self, start_zone, end_zone): 
        
        cost = self.dist_df.loc[((self.dist_df["pickup_taxizone_id"] == start_zone) &
                                 (self. dist_df["dropoff_taxizone_id"] == end_zone)), "mean"].mean()*0.124
        return cost 
    
    def get_matching_prob(self, zone, time):
        if self.isWeekday:
            prob = self.prob_df.loc[(self.prob_df['taxi_zone'] == zone) & 
                                    (self.prob_df['time_stamp'] == time)].mod_prob_match_weekday.values[0]
        else: 
            prob = self.prob_df.loc[(self.prob_df['taxi_zone'] == zone) & 
                                    (self.prob_df['time_stamp'] == time)].mod_prob_match_weekend.values[0]
            
        return prob 
    
    
    time_bins = [dt.time(0,0),dt.time(0,30), dt.time(1,0), dt.time(1,30), dt.time(2,0), 
        dt.time(2,30), dt.time(3,0), dt.time(3,30), dt.time(4,0),
        dt.time(4,30), dt.time(5,0), dt.time(5,30), dt.time(6,0),
        dt.time(6,30), dt.time(7,0), dt.time(7,30), dt.time(8,0),
        dt.time(8,30), dt.time(9,0), dt.time(9,30), dt.time(10,0),
        dt.time(10,30), dt.time(11,0), dt.time(11,30), dt.time(12,0),
        dt.time(12,30), dt.time(13,0), dt.time(13,30), dt.time(14,0),
        dt.time(14,30), dt.time(15,0), dt.time(15,30), dt.time(16,0), 
        dt.time(16,30), dt.time(17,0), dt.time(17,30), dt.time(18,0),
        dt.time(18,30), dt.time(19,0), dt.time(19,30), dt.time(20,0),
        dt.time(20,30), dt.time(21,0), dt.time(21,30), dt.time(22,0),
        dt.time(22,30), dt.time(23,0), dt.time(23,30), dt.time(23,59,59)] 
    
    
    def get_time_window(self, datetime):
        for i in range(0,48):
            if (datetime.time() >= self.time_bins[i]) & (datetime.time() < self.time_bins[i+1]): 
                return i+1 
    
     
    def reposition_to_high( self, current_zone, time ):
        #adj = self.get_adjacent_zone( current_zone )
        #adj.append( current_zone )
        #demand_list = [self.get_demand(zone, time) for zone in adj]
        #print(demand_list)
        # find the index of the max value of demand_lisy, and find which zone it is
        #return adj[demand_list.index( max(demand_list))]  
    
         
        adj = self.get_adjacent_zone( current_zone )
        adj.insert(0,current_zone)
        # find the index of the max value of near_prob, and find which zone it is 
        demand_list = [self.get_demand(zone, time) for zone in adj]
        a_arr  = np.array(demand_list)
        print("a_arr: ", a_arr)
        #near_prob = list(np.exp((a_arr-a_arr[0])*10)/np.sum(np.exp((a_arr-a_arr[0])*10))) 
        near_prob = list(np.exp((a_arr-a_arr[0]))/np.sum(np.exp((a_arr-a_arr[0]))))
        print("near prob :", near_prob) 
        
        return(adj[near_prob.index( max(near_prob))])
    
    def reposition_to_any( self, current_zone, time ):
        #adj = self.get_adjacent_zone( current_zone )
        #adj.append( current_zone )
        #demand_list = [self.get_demand(zone, time) for zone in adj]
        #print(demand_list)
        # find the index of the max value of demand_lisy, and find which zone it is
        #return adj[demand_list.index( max(demand_list))]  
    
         
        adj = self.get_adjacent_zone( current_zone )
        adj.insert(0,current_zone)
        # find the index of the max value of near_prob, and find which zone it is 
        r = random.randint(0,len(adj)-1) 
        
        
        return(adj[r])

# %%
# one round of simulation 
random.seed(500)
init_time = dt.datetime(2013, 6, 3, 5, 0, 0) 
init_zone = 12
avg_speed_waiting = 10 # defined in mph

#Initialize enviorment and driver 
env = Env( isWeekday = False ) 
driver = Driver( time = init_time, location = init_zone, total_fare = 0, total_cost = 0, is_idle = True) 

# print(driver.location)
# print(driver.time)
# print(driver.total_fare)
# print(driver.total_cost)
# print(driver.is_idle)


while driver.time < init_time + timedelta(seconds=0, minutes=0, hours = 11):
    #get prob that driver will be matched to a passenger 
    matching_prob = env.get_matching_prob( zone = driver.location, time = env.get_time_window(driver.time) )
    #print(matching_prob)
    start_zone = driver.location
    print('current time is ', driver.time, 'and driver is at zone ', driver.location)
    if env.is_matched(matching_prob):

        # time it takes before getting matched 
        wait_time = env.wait_time_before_pickup(matching_prob)
        print('driver waited for ', wait_time, ' min before he picks up')

        # cost of cruising
        driver.set_total_cost(driver.total_cost + avg_speed_waiting * wait_time/60 * 0.124)

        # set driver time to new time 
        driver.set_time( driver.time + timedelta(seconds=0, minutes= wait_time, hours=0 ) )
        print('driver gets a pick up and is now at time ', driver.time)    


        #driver is now busy 
        driver.set_is_idle(False)


        # find the destination of the trip and set destination 
        dest = env.get_destination(driver.location)
        driver.set_location(dest)
        print ('driver is going to zone', dest, 'and driver arrived at zone', driver.location)    

         # find the trip duration and update new time 
        duration = env.get_trip_duration(start_zone = start_zone, end_zone = dest, shift_time=driver.get_shift_time_weekday())
        print ('trip duration ', duration)
        driver.set_time( driver.time + timedelta(seconds=0, minutes= duration, hours=0 ) )
        print ('driver drops off passenger at time ', driver.time)


        #find trip fare and update fare 
        fare = env.get_fare( start_zone, dest, driver.get_shift_time_weekday())
        driver.set_total_fare(driver.total_fare + fare)
        print('trip fare from ', start_zone, 'to ', driver.location,   ' is',  fare)
        print('driver total fare earned is ', driver.total_fare )

        #frin trip cost and update cost 
        cost = env.get_fuel_cost(start_zone, dest)
        driver.set_total_cost(driver.total_cost + cost)
        print('fuel cost from ', start_zone, 'to ', driver.location,   ' is', cost  )

        print('************************trip is completed.************************** ')


    else: 
        #time it takes before reposition 
        print('driver does not get a pick up at the current zone: zone ', driver.location )
        
        wait_time = env.wait_time_before_reposition()
        driver.set_time( driver.time + timedelta(seconds=0, minutes= wait_time, hours=0 ) )
        print('driver now decides to check reposition info after ', wait_time, ' min of crusing and current time is ', driver.time)
       
        # cost of cruising
        driver.set_total_cost(driver.total_cost + avg_speed_waiting * wait_time/60 * 0.124)

        
        repo = env.reposition_to(driver.location, env.get_time_window(driver.time) ) #fix this to distribution 
        
        '''
            TODO:
            add cost - assume 10 miles a hour '''
                                                                       
                
        driver.set_location(repo)
        print('driver is repostioning to zone ', repo, 'and arrived at zone ', driver.location)

        # find the trip duration and update new time 
        duration = env.get_trip_duration(start_zone = start_zone, end_zone = repo, shift_time=driver.get_shift_time_weekday())
        print ('reposition trip duration ', duration , 'min')
        driver.set_time( driver.time + timedelta(seconds=0, minutes= duration, hours=0 ) )
        print ('After repositioning, it is now ', driver.time)

        #frin trip cost and update cost 
        cost = env.get_fuel_cost(start_zone, repo)
        driver.set_total_cost(driver.total_cost + cost)
        print('fuel cost from ', start_zone, 'to ', driver.location,   ' is', cost  )


        print('************************reposition is completed.************************** ')


        
print('total fare earned from this shift is ', driver.total_fare )
print('total fuel cost is ', driver.total_cost)
print('profit is ', driver.total_fare - driver.total_cost)
# Out:
# current time is  2013-06-03 05:00:00 and driver is at zone  12
# driver does not get a pick up at the current zone: zone  12
# driver now decides to check reposition info after  9  min of crusing and current time is  2013-06-03 05:09:00
# a_arr:  [1.43356445 9.17509094 6.14044189 9.        ]
# near prob : [0.00023010033613637168, 0.5296872129806424, 0.02547347259492599, 0.44460921408829523]
# driver is repostioning to zone  261 and arrived at zone  261
# reposition trip duration  7.338888888888889 min
# After repositioning, it is now  2013-06-03 05:16:20.333333
# fuel cost from  12 to  261  is 0.08881506563164852
# ************************reposition is completed.**************************
# current time is  2013-06-03 05:16:20.333333 and driver is at zone  261
# driver waited for  19  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 05:35:20.333333
# driver is going to zone 87 and driver arrived at zone 87
# trip duration  7.051592851592853
# driver drops off passenger at time  2013-06-03 05:42:23.428904
# trip fare from  261 to  87  is 6.344988344988345
# driver total fare earned is  6.344988344988345
# fuel cost from  261 to  87  is 0.10623081124218992
# ************************trip is completed.**************************
# current time is  2013-06-03 05:42:23.428904 and driver is at zone  87
# driver waited for  9  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 05:51:23.428904
# driver is going to zone 229 and driver arrived at zone 229
# trip duration  15.367345679012356
# driver drops off passenger at time  2013-06-03 06:06:45.469645
# trip fare from  87 to  229  is 18.09351851851852
# driver total fare earned is  24.438506863506863
# fuel cost from  87 to  229  is 0.6064737379868333
# ************************trip is completed.**************************
# current time is  2013-06-03 06:06:45.469645 and driver is at zone  229
# driver waited for  2  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 06:08:45.469645
# driver is going to zone 141 and driver arrived at zone 141
# trip duration  5.617011851340462
# driver drops off passenger at time  2013-06-03 06:14:22.490356
# trip fare from  229 to  141  is 5.965826717293752
# driver total fare earned is  30.404333580800614
# fuel cost from  229 to  141  is 0.11008437674797945
# ************************trip is completed.**************************
# current time is  2013-06-03 06:14:22.490356 and driver is at zone  141
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 06:17:22.490356
# driver is going to zone 48 and driver arrived at zone 48
# trip duration  14.783587140439929
# driver drops off passenger at time  2013-06-03 06:32:09.505584
# trip fare from  141 to  48  is 11.821827411167511
# driver total fare earned is  42.22616099196813
# fuel cost from  141 to  48  is 0.28358830683901626
# ************************trip is completed.**************************
# current time is  2013-06-03 06:32:09.505584 and driver is at zone  48
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 06:35:09.505584
# driver is going to zone 144 and driver arrived at zone 144
# trip duration  19.845664909197428
# driver drops off passenger at time  2013-06-03 06:55:00.245479
# trip fare from  48 to  144  is 15.681898066783832
# driver total fare earned is  57.90805905875196
# fuel cost from  48 to  144  is 0.37559676563561667
# ************************trip is completed.**************************
# current time is  2013-06-03 06:55:00.245479 and driver is at zone  144
# driver waited for  2  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 06:57:00.245479
# driver is going to zone 148 and driver arrived at zone 148
# trip duration  5.920594479830156
# driver drops off passenger at time  2013-06-03 07:02:55.481148
# trip fare from  144 to  148  is 5.740673339399455
# driver total fare earned is  63.64873239815142
# fuel cost from  144 to  148  is 0.08669492282932345
# ************************trip is completed.**************************
# current time is  2013-06-03 07:02:55.481148 and driver is at zone  148
# driver waited for  2  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 07:04:55.481148
# driver is going to zone 112 and driver arrived at zone 112
# trip duration  10.519910625620662
# driver drops off passenger at time  2013-06-03 07:15:26.675786
# trip fare from  148 to  112  is 13.40069513406157
# driver total fare earned is  77.04942753221299
# fuel cost from  148 to  112  is 0.4512834741666459
# ************************trip is completed.**************************
# current time is  2013-06-03 07:15:26.675786 and driver is at zone  112
# driver does not get a pick up at the current zone: zone  112
# driver now decides to check reposition info after  6  min of crusing and current time is  2013-06-03 07:21:26.675786
# a_arr:  [4.16963623 9.07606934 3.00783691]
# near prob : [0.007327650685746194, 0.9903793616103787, 0.0022929877038750566]
# driver is repostioning to zone  255 and arrived at zone  255
# reposition trip duration  4.891414141414143 min
# After repositioning, it is now  2013-06-03 07:26:20.160634
# fuel cost from  112 to  255  is 0.12397591587271395
# ************************reposition is completed.**************************
# current time is  2013-06-03 07:26:20.160634 and driver is at zone  255
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 07:27:20.160634
# driver is going to zone 145 and driver arrived at zone 145
# trip duration  9.729012345679012
# driver drops off passenger at time  2013-06-03 07:37:03.901375
# trip fare from  255 to  145  is 10.523148148148149
# driver total fare earned is  87.57257568036114
# fuel cost from  255 to  145  is 0.2816903094955956
# ************************trip is completed.**************************
# current time is  2013-06-03 07:37:03.901375 and driver is at zone  145
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 07:41:03.901375
# driver is going to zone 255 and driver arrived at zone 255
# trip duration  9.202482269503546
# driver drops off passenger at time  2013-06-03 07:50:16.050311
# trip fare from  145 to  255  is 10.25531914893617
# driver total fare earned is  97.8278948292973
# fuel cost from  145 to  255  is 0.27726180605830403
# ************************trip is completed.**************************
# current time is  2013-06-03 07:50:16.050311 and driver is at zone  255
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 07:54:16.050311
# driver is going to zone 162 and driver arrived at zone 162
# trip duration  19.960049019607847
# driver drops off passenger at time  2013-06-03 08:14:13.653252
# trip fare from  255 to  162  is 19.389705882352946
# driver total fare earned is  117.21760071165025
# fuel cost from  255 to  162  is 0.5724231345899758
# ************************trip is completed.**************************
# current time is  2013-06-03 08:14:13.653252 and driver is at zone  162
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 08:18:13.653252
# driver is going to zone 100 and driver arrived at zone 100
# trip duration  11.674190210079676
# driver drops off passenger at time  2013-06-03 08:29:54.104665
# trip fare from  162 to  100  is 8.78329711269792
# driver total fare earned is  126.00089782434817
# fuel cost from  162 to  100  is 0.1543710723649646
# ************************trip is completed.**************************
# current time is  2013-06-03 08:29:54.104665 and driver is at zone  100
# driver does not get a pick up at the current zone: zone  100
# driver now decides to check reposition info after  8  min of crusing and current time is  2013-06-03 08:37:54.104665
# a_arr:  [ 62.19772797  87.15694969  84.9754306  125.99751709 146.61644932
#  201.45301819 101.22191895]
# near prob : [3.328096272145288e-61, 2.3006372574107677e-50, 2.5967279124535243e-51, 1.6986043956545222e-33, 1.5303146399876543e-24, 1.0, 2.95247809100948e-44]
# driver is repostioning to zone  48 and arrived at zone  48
# reposition trip duration  5.5108426585283175 min
# After repositioning, it is now  2013-06-03 08:43:24.755225
# fuel cost from  100 to  48  is 0.09460420395001616
# ************************reposition is completed.**************************
# current time is  2013-06-03 08:43:24.755225 and driver is at zone  48
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 08:46:24.755225
# driver is going to zone 170 and driver arrived at zone 170
# trip duration  11.752004271398064
# driver drops off passenger at time  2013-06-03 08:58:09.875481
# trip fare from  48 to  170  is 9.19467718087728
# driver total fare earned is  135.19557500522546
# fuel cost from  48 to  170  is 0.17194946069818492
# ************************trip is completed.**************************
# current time is  2013-06-03 08:58:09.875481 and driver is at zone  170
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 08:59:09.875481
# driver is going to zone 234 and driver arrived at zone 234
# trip duration  6.600355315520162
# driver drops off passenger at time  2013-06-03 09:05:45.896800
# trip fare from  170 to  234  is 6.458996588971006
# driver total fare earned is  141.65457159419648
# fuel cost from  170 to  234  is 0.13010811379626927
# ************************trip is completed.**************************
# current time is  2013-06-03 09:05:45.896800 and driver is at zone  234
# driver waited for  7  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 09:12:45.896800
# driver is going to zone 107 and driver arrived at zone 107
# trip duration  5.520210552087154
# driver drops off passenger at time  2013-06-03 09:18:17.109433
# trip fare from  234 to  107  is 5.622291590157914
# driver total fare earned is  147.2768631843544
# fuel cost from  234 to  107  is 0.08945052608983951
# ************************trip is completed.**************************
# current time is  2013-06-03 09:18:17.109433 and driver is at zone  107
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 09:21:17.109433
# driver is going to zone 186 and driver arrived at zone 186
# trip duration  9.999026059489342
# driver drops off passenger at time  2013-06-03 09:31:17.050997
# trip fare from  107 to  186  is 8.319557778362727
# driver total fare earned is  155.59642096271713
# fuel cost from  107 to  186  is 0.14806886955820234
# ************************trip is completed.**************************
# current time is  2013-06-03 09:31:17.050997 and driver is at zone  186
# driver waited for  13  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 09:44:17.050997
# driver is going to zone 230 and driver arrived at zone 230
# trip duration  8.795509019805731
# driver drops off passenger at time  2013-06-03 09:53:04.781538
# trip fare from  186 to  230  is 7.522101677810016
# driver total fare earned is  163.11852264052715
# fuel cost from  186 to  230  is 0.12788088747054518
# ************************trip is completed.**************************
# current time is  2013-06-03 09:53:04.781538 and driver is at zone  230
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 09:57:04.781538
# driver is going to zone 263 and driver arrived at zone 263
# trip duration  11.880825242718442
# driver drops off passenger at time  2013-06-03 10:08:57.631053
# trip fare from  230 to  263  is 11.689805825242718
# driver total fare earned is  174.80832846576988
# fuel cost from  230 to  263  is 0.3472331317533535
# ************************trip is completed.**************************
# current time is  2013-06-03 10:08:57.631053 and driver is at zone  263
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 10:11:57.631053
# driver is going to zone 244 and driver arrived at zone 244
# trip duration  16.79711538461538
# driver drops off passenger at time  2013-06-03 10:28:45.457976
# trip fare from  263 to  244  is 20.32451923076923
# driver total fare earned is  195.1328476965391
# fuel cost from  263 to  244  is 0.6331805780101544
# ************************trip is completed.**************************
# current time is  2013-06-03 10:28:45.457976 and driver is at zone  244
# driver does not get a pick up at the current zone: zone  244
# driver now decides to check reposition info after  1  min of crusing and current time is  2013-06-03 10:29:45.457976
# a_arr:  [11.73730469 15.6         0.          2.16863281]
# near prob : [0.020578868861430552, 0.9794195285744348, 1.6442764679861353e-07, 1.4381364878870372e-06]
# driver is repostioning to zone  116 and arrived at zone  116
# reposition trip duration  4.937962962962962 min
# After repositioning, it is now  2013-06-03 10:34:41.735754
# fuel cost from  244 to  116  is 0.12470368100394937
# ************************reposition is completed.**************************
# current time is  2013-06-03 10:34:41.735754 and driver is at zone  116
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 10:35:41.735754
# driver is going to zone 24 and driver arrived at zone 24
# trip duration  9.235820895522384
# driver drops off passenger at time  2013-06-03 10:44:55.885008
# trip fare from  116 to  24  is 9.64179104477612
# driver total fare earned is  204.77463874131521
# fuel cost from  116 to  24  is 0.24266406866802775
# ************************trip is completed.**************************
# current time is  2013-06-03 10:44:55.885008 and driver is at zone  24
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 10:48:55.885008
# driver is going to zone 186 and driver arrived at zone 186
# trip duration  20.51004901960784
# driver drops off passenger at time  2013-06-03 11:09:26.487949
# trip fare from  24 to  186  is 18.06985294117647
# driver total fare earned is  222.84449168249168
# fuel cost from  24 to  186  is 0.49843636977430344
# ************************trip is completed.**************************
# current time is  2013-06-03 11:09:26.487949 and driver is at zone  186
# driver waited for  6  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 11:15:26.487949
# driver is going to zone 107 and driver arrived at zone 107
# trip duration  8.214251352976543
# driver drops off passenger at time  2013-06-03 11:23:39.343030
# trip fare from  186 to  107  is 7.581479254359591
# driver total fare earned is  230.42597093685126
# fuel cost from  186 to  107  is 0.15321051539251082
# ************************trip is completed.**************************
# current time is  2013-06-03 11:23:39.343030 and driver is at zone  107
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 11:27:39.343030
# driver is going to zone 237 and driver arrived at zone 237
# trip duration  14.024231974921642
# driver drops off passenger at time  2013-06-03 11:41:40.796948
# trip fare from  107 to  237  is 12.461799137399876
# driver total fare earned is  242.88777007425114
# fuel cost from  107 to  237  is 0.28707576423404907
# ************************trip is completed.**************************
# current time is  2013-06-03 11:41:40.796948 and driver is at zone  237
# driver waited for  2  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 11:43:40.796948
# driver is going to zone 223 and driver arrived at zone 223
# trip duration  21.63922651933701
# driver drops off passenger at time  2013-06-03 12:05:19.150539
# trip fare from  237 to  223  is 19.4792817679558
# driver total fare earned is  262.36705184220693
# fuel cost from  237 to  223  is 0.6170920119896266
# ************************trip is completed.**************************
# current time is  2013-06-03 12:05:19.150539 and driver is at zone  223
# driver waited for  5  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 12:10:19.150539
# driver is going to zone 237 and driver arrived at zone 237
# trip duration  23.04803921568627
# driver drops off passenger at time  2013-06-03 12:33:22.032892
# trip fare from  223 to  237  is 23.573529411764707
# driver total fare earned is  285.94058125397163
# fuel cost from  223 to  237  is 0.6323692917233268
# ************************trip is completed.**************************
# current time is  2013-06-03 12:33:22.032892 and driver is at zone  237
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 12:37:22.032892
# driver is going to zone 88 and driver arrived at zone 88
# trip duration  20.921715686274503
# driver drops off passenger at time  2013-06-03 12:58:17.335833
# trip fare from  237 to  88  is 22.78970588235294
# driver total fare earned is  308.7302871363246
# fuel cost from  237 to  88  is 0.7406623079967826
# ************************trip is completed.**************************
# current time is  2013-06-03 12:58:17.335833 and driver is at zone  88
# driver waited for  2  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 13:00:17.335833
# driver is going to zone 100 and driver arrived at zone 100
# trip duration  24.945111111111117
# driver drops off passenger at time  2013-06-03 13:25:14.042500
# trip fare from  88 to  100  is 21.01833333333333
# driver total fare earned is  329.7486204696579
# fuel cost from  88 to  100  is 0.5438988563805081
# ************************trip is completed.**************************
# current time is  2013-06-03 13:25:14.042500 and driver is at zone  100
# driver waited for  10  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 13:35:14.042500
# driver is going to zone 234 and driver arrived at zone 234
# trip duration  9.52611532501428
# driver drops off passenger at time  2013-06-03 13:44:45.609420
# trip fare from  100 to  234  is 7.98629801810619
# driver total fare earned is  337.7349184877641
# fuel cost from  100 to  234  is 0.13990657772731668
# ************************trip is completed.**************************
# current time is  2013-06-03 13:44:45.609420 and driver is at zone  234
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 13:45:45.609420
# driver is going to zone 163 and driver arrived at zone 163
# trip duration  16.09292869537785
# driver drops off passenger at time  2013-06-03 14:01:51.185142
# trip fare from  234 to  163  is 11.8059630856602
# driver total fare earned is  349.5408815734243
# fuel cost from  234 to  163  is 0.23073276118875502
# ************************trip is completed.**************************
# current time is  2013-06-03 14:01:51.185142 and driver is at zone  163
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 14:02:51.185142
# driver is going to zone 234 and driver arrived at zone 234
# trip duration  15.318995459008349
# driver drops off passenger at time  2013-06-03 14:18:10.324870
# trip fare from  163 to  234  is 11.42120765832106
# driver total fare earned is  360.9620892317454
# fuel cost from  163 to  234  is 0.22666665118429297
# ************************trip is completed.**************************
# current time is  2013-06-03 14:18:10.324870 and driver is at zone  234
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 14:21:10.324870
# driver is going to zone 113 and driver arrived at zone 113
# trip duration  5.51827497176053
# driver drops off passenger at time  2013-06-03 14:26:41.421368
# trip fare from  234 to  113  is 5.66798450863321
# driver total fare earned is  366.6300737403786
# fuel cost from  234 to  113  is 0.09344014000292096
# ************************trip is completed.**************************
# current time is  2013-06-03 14:26:41.421368 and driver is at zone  113
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 14:27:41.421368
# driver is going to zone 211 and driver arrived at zone 211
# trip duration  7.431667682307538
# driver drops off passenger at time  2013-06-03 14:35:07.321429
# trip fare from  113 to  211  is 6.637568555758683
# driver total fare earned is  373.26764229613724
# fuel cost from  113 to  211  is 0.1110492289065539
# ************************trip is completed.**************************
# current time is  2013-06-03 14:35:07.321429 and driver is at zone  211
# driver does not get a pick up at the current zone: zone  211
# driver now decides to check reposition info after  8  min of crusing and current time is  2013-06-03 14:43:07.321429
# a_arr:  [151.51069988 205.6515057  151.60678734  61.00436829 150.01590729]
# near prob : [3.068645979258078e-24, 1.0, 3.378135300293177e-24, 1.5154667019275578e-63, 6.882823177139884e-25]
# driver is repostioning to zone  231 and arrived at zone  231
# reposition trip duration  7.652947845804983 min
# After repositioning, it is now  2013-06-03 14:50:46.498300
# fuel cost from  211 to  231  is 0.10773127308543133
# ************************reposition is completed.**************************
# current time is  2013-06-03 14:50:46.498300 and driver is at zone  231
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 14:54:46.498300
# driver is going to zone 162 and driver arrived at zone 162
# trip duration  21.86993735431235
# driver drops off passenger at time  2013-06-03 15:16:38.694541
# trip fare from  231 to  162  is 19.509178321678323
# driver total fare earned is  392.7768206178156
# fuel cost from  231 to  162  is 0.5176690210217779
# ************************trip is completed.**************************
# current time is  2013-06-03 15:16:38.694541 and driver is at zone  162
# driver waited for  2  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 15:18:38.694541
# driver is going to zone 141 and driver arrived at zone 141
# trip duration  7.391055239299996
# driver drops off passenger at time  2013-06-03 15:26:02.157855
# trip fare from  162 to  141  is 7.092293906810036
# driver total fare earned is  399.8691145246256
# fuel cost from  162 to  141  is 0.14530695307993904
# ************************trip is completed.**************************
# current time is  2013-06-03 15:26:02.157855 and driver is at zone  141
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 15:27:02.157855
# driver is going to zone 234 and driver arrived at zone 234
# trip duration  18.22452080411408
# driver drops off passenger at time  2013-06-03 15:45:15.629103
# trip fare from  141 to  234  is 14.104908835904627
# driver total fare earned is  413.9740233605302
# fuel cost from  141 to  234  is 0.3507692673152669
# ************************trip is completed.**************************
# current time is  2013-06-03 15:45:15.629103 and driver is at zone  234
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 15:49:15.629103
# driver is going to zone 211 and driver arrived at zone 211
# trip duration  10.446705177578073
# driver drops off passenger at time  2013-06-03 15:59:42.431414
# trip fare from  234 to  211  is 8.593068035943517
# driver total fare earned is  422.56709139647376
# fuel cost from  234 to  211  is 0.1716897539366727
# ************************trip is completed.**************************
# current time is  2013-06-03 15:59:42.431414 and driver is at zone  211
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 16:00:42.431414
# driver is going to zone 249 and driver arrived at zone 249
# trip duration  6.608256835455544
# driver drops off passenger at time  2013-06-03 16:07:18.926824
# trip fare from  211 to  249  is 6.32306781166716
# driver total fare earned is  428.8901592081409
# fuel cost from  211 to  249  is 0.1079921442942702
# ************************trip is completed.**************************
# total fare earned from this shift is  428.8901592081409
# total fuel cost is  14.920698776360323
# profit is  413.9694604317806

# %%
'''TODO: 
Monte Carlo Simulation'''
# Out:
# 'TODO: \nMonte Carlo Simulation'
