# %%
import numpy as np
import pandas as pd 
import datetime as dt
from datetime import timedelta 
import random

# %%
class Driver: 
    

    
    def __init__(self, time, location, total_fare, total_cost, is_idle ):
        self.time = time 
        self.location = location 
        self.total_fare = total_fare
        self.total_cost  = total_cost
        self.is_idle = is_idle
    
    def set_time(self, new_time):
        self.time = new_time
    
    def get_time(self):
        return self.__time 
    
    def set_location(self, new_location):
        self.location = new_location
        
    def get_location(self):
        return self.__location 
   
    def set_total_fare(self, new_fare):
        self.total_fare = new_fare
    
    def get_total_fare(self):
        return self.total_fare 
    
    def set_is_idle(self, is_idle):
        self.is_idle = is_idle 
        
    def set_total_cost(self, new_cost):
        self.total_cost = new_cost
    
    def get_total_cost(self):
        return self.total_cost 
    
    def get_shift_time_weekday(self):


        weekend = [5,6]
        weekend_ind = lambda n: 0 if n in weekend else 1
        weekday = weekend_ind(self.time.weekday)

        normtime = driver.time.time()
        roundtime = pd.Timestamp(driver.time).round('30min').time()
        
        
        if weekday:
            if (normtime > dt.time(23, 30)) | (normtime <= dt.time(11, 30)):
                return ('A', roundtime,weekday)
            else:
                return ('B', roundtime,weekday)
        else: ## weekend
            if (normtime > dt.time(2, 0)) & (normtime <= dt.time(14, 0)):
                return ('A', roundtime,weekday)
            else:
                return ('B', roundtime,weekday)

# %%
class Env: 
    
    
    arrivals = pd.read_csv('../data/arrival_rates.csv')[['taxi_zone', 'time_stamp','arr_weekday','arr_weekend']]
    dropoff_counts = pd.read_csv('../data/pickup_dropoff_summary.csv')
    fare_df = pd.read_csv('../data/fare_amount_scr_dst_t.csv')
    dist_df = pd.read_csv('../data/trip_distance_scr_dst.csv')
    trip_time_df = pd.read_csv('../data/trip_time_scr_dst_t.csv')
    prob_df = pd.read_csv('../data/prob_match_combined_new.csv')
    trans_matrix = pd.read_csv('../data/dropoff_after_pickup.csv') # fix this to shift based and a
     # 0 weekend , A night shift 
    
    #time in 1..48,  isWeekday is a boolean
    def __init__(self,  isWeekday):   

        self.isWeekday = isWeekday 
        
    
    def is_matched(self, matching_prob):
        n = random.random()

        if n <= matching_prob:
            return True 
        else: 
            False 
    
    def get_destination(self, zone):
        prob = self.trans_matrix.iloc[zone-1].values[1:]
        n = random.random()

        count = 0
        for i in range(len(prob)):
            count = count + prob[i]
            if n<count:
                return i+1

    def get_adjacent_zone( self, taxi_zone ):
        df = pd.read_csv('../data/adjacent_zone.csv')
        adj_zone_1 = df.loc[df["zone1"]==taxi_zone, "zone2"].values.tolist()
        adj_zone_2 = df.loc[df["zone2"]==taxi_zone, "zone1"].values.tolist()
        adj_zone_list = list(filter(None, adj_zone_1+adj_zone_2))
        return(adj_zone_list)
    
    def get_demand(self, zone, time):
        #row = self.arrivals.loc[ ( self.arrivals['taxi_zone'] == zone ) & (self.arrivals['time_stamp'] == time ) ]
        row = self.prob_df.loc[ ( self.arrivals['taxi_zone'] == zone ) & (self.arrivals['time_stamp'] == time ) ]
       
        if self.isWeekday:
            return row['arr_weekday'].values[0]
        else:
            return row['arr_weekend'].values[0]
    
     #  def get_near_arrival():
    
    
    '''TODO： 
        fix policy fucntion - add randomness'''
   
       
            
    def reposition_to( self, current_zone, time ):
        #adj = self.get_adjacent_zone( current_zone )
        #adj.append( current_zone )
        #demand_list = [self.get_demand(zone, time) for zone in adj]
        #print(demand_list)
        # find the index of the max value of demand_lisy, and find which zone it is
        #return adj[demand_list.index( max(demand_list))]  
    
         
        adj = self.get_adjacent_zone( current_zone )
        adj.insert(0,current_zone)
        # find the index of the max value of near_prob, and find which zone it is 
        demand_list = [self.get_demand(zone, time) for zone in adj]
        a_arr  = np.array(demand_list)
        print("a_arr: ", a_arr)
        #near_prob = list(np.exp((a_arr-a_arr[0])*10)/np.sum(np.exp((a_arr-a_arr[0])*10))) 
        near_prob = list(np.exp((a_arr-a_arr[0]))/np.sum(np.exp((a_arr-a_arr[0]))))
        print("near prob :", near_prob)  
        
        # 20, 28, 52
        
        r = random.random()
        #25
        
        count = 0
        for i in range(len(near_prob)):
            count = count + near_prob[i]
            if r < count:
                return(adj[i])  
        
        #repo_zone = adj[r_index]   
        
        #repo_prob = near_prob.index( max(near_prob))
        
    
        #print("r, repo, repo_prob", r, repo, repo_prob)
            
      
            
          
        #return (adj[near_prob.index( max(near_prob))],  is_repositioned)
    
        #SOFTMAX 
        #NEAR ARRIVAL 
        # return the highest prob of near arrival 
        
        
        ### paper's calculation of nearest prob
        # zone 1 = 10 , zone2 = 10.1 , zone 3 = 5
        # p(zone 1) = 10/25.5 = 0.392
        # p(zone 2) = 10.1/25.5 = 0.396
        # p(zone 3) = 5/25.5 = 0.196 
        
        
        # softmax suggestion way 
        # zone 1 = 10 , zone2 = 10.1 , zone 3 = 5
        # B  = 10 
        #exp(B * (rho1 - rho1) - e) / exp(B * (rho1 - rho1)) + exp(B * (rho2 - rho1)) + exp(B * (rho3 - rho1) - e) = 0.27
        #exp(B * (rho2 - rho1) - e) / exp(10) + exp(10.2) + exp(5)  = 0.73
        #exp(B * (rho3 - rho1) - e) / exp(10) + exp(10.2) + exp(5)  = 0.0
        
        
     
    def wait_time_before_pickup(self, matching_prob):
        if ( matching_prob >= 0.9 ):
            return random.randint(1,4)
        elif ( matching_prob >= 0.7 ):
            return random.randint(5,10)
        elif ( matching_prob >= 0.5 ):
            return random.randint(11,15)
        elif ( matching_prob >= 0.3 ):
            return random.randint(16,20)
        else:
            return random.randint(21,29)
        
    def wait_time_before_reposition(self):
        return random.randint(1,10)
    
    # can look into histortical data combined with random number 

    
    
    def get_trip_duration(self, start_zone, end_zone, shift_time):    
        shift,roundtime,weekday_ind = shift_time
        roundtime = roundtime.strftime('%H:%M:%S') 
        
        zone_to_zone = self.trip_time_df[(self.trip_time_df["pickup_taxizone_id"] == start_zone) & 
                                        (self.trip_time_df["dropoff_taxizone_id"] == end_zone) &
                                        (self.trip_time_df["actual_data"] == 1)]
        
        if len(zone_to_zone)!=0:
            if len(zone_to_zone[(zone_to_zone['_PU_shift']==shift) & (zone_to_zone['pickup_datetime_interval']==roundtime) &
                                (zone_to_zone['pickup_weekday'] == weekday_ind)])>0:

                dur = zone_to_zone.loc[(zone_to_zone["_PU_shift"] == shift) &
                                       (zone_to_zone["pickup_datetime_interval"] == roundtime) &
                                       (zone_to_zone['pickup_weekday'] == weekday_ind), "mean"].mean() 

            elif len(zone_to_zone[(zone_to_zone['_PU_shift']==shift) & (zone_to_zone['pickup_weekday'] == weekday_ind)])>0:
                dur = zone_to_zone.loc[(zone_to_zone["_PU_shift"] == shift) &
                                       (zone_to_zone['pickup_weekday'] == weekday_ind), "mean"].mean()

            else:
                dur = zone_to_zone['mean'].mean()
        else: 
            dur = self.trip_time_df.loc[(self.trip_time_df["pickup_taxizone_id"] == start_zone) & 
                                    (self.trip_time_df["dropoff_taxizone_id"] == end_zone) &
                                    (self.trip_time_df["actual_data"] == 0),"mean"].mean()
        
        return dur
        
    def get_fare(self, start_zone, end_zone, shift_time): 
        
        shift,roundtime,weekday_ind = shift_time
        roundtime = roundtime.strftime('%H:%M:%S') 
        
        zone_to_zone = self.fare_df[(self.fare_df["pickup_taxizone_id"] == start_zone) & 
                                    (self.fare_df["dropoff_taxizone_id"] == end_zone) &
                                    (self.fare_df["actual_data"] == 1)]
                
        if len(zone_to_zone)!=0:
            if len(zone_to_zone[(zone_to_zone['_PU_shift']==shift) & (zone_to_zone['pickup_datetime_interval']==roundtime) &
                                (zone_to_zone['pickup_weekday'] == weekday_ind)])>0:

                fare = zone_to_zone.loc[(zone_to_zone["_PU_shift"] == shift) &
                                       (zone_to_zone["pickup_datetime_interval"] == roundtime) &
                                       (zone_to_zone['pickup_weekday'] == weekday_ind), "mean"].mean() 

            elif len(zone_to_zone[(zone_to_zone['_PU_shift']==shift) & (zone_to_zone['pickup_weekday'] == weekday_ind)])>0:
                fare = zone_to_zone.loc[(zone_to_zone["_PU_shift"] == shift) &
                                       (zone_to_zone['pickup_weekday'] == weekday_ind), "mean"].mean()

            else:
                fare = zone_to_zone['mean'].mean()
        else:
            dur = self.fare_df.loc[(self.fare_df["pickup_taxizone_id"] == start_zone) & 
                                    (self.fare_df["dropoff_taxizone_id"] == end_zone) &
                                    (self.fare_df["actual_data"] == 0),"mean"].mean()
        
        return fare
    
    def get_trip_distance(self, start_zone, end_zone):
        zone_to_zone = self.dist_df.loc[((self.dist_df["pickup_taxizone_id"] == start_zone) &
                                 (self. dist_df["dropoff_taxizone_id"] == end_zone) &
                                 (self.trip_time_df["actual_data"] == 1)), "mean"]
        if len(zone_to_zone) != 0:
            dist = zone_to_zone.mean()
        else:
            dist = self.dist_df.loc[((self.dist_df["pickup_taxizone_id"] == start_zone) &
                                 (self. dist_df["dropoff_taxizone_id"] == end_zone) &
                                 (self.trip_time_df["actual_data"] == 0)), "mean"]
        
        return dist 
    
    def get_fuel_cost(self, start_zone, end_zone): 
        
        cost = self.dist_df.loc[((self.dist_df["pickup_taxizone_id"] == start_zone) &
                                 (self. dist_df["dropoff_taxizone_id"] == end_zone)), "mean"].mean()*0.124
        return cost 
    
    def get_matching_prob(self, zone, time):
        if self.isWeekday:
            prob = self.prob_df.loc[(self.prob_df['taxi_zone'] == zone) & 
                                    (self.prob_df['time_stamp'] == time)].mod_prob_match_weekday.values[0]
        else: 
            prob = self.prob_df.loc[(self.prob_df['taxi_zone'] == zone) & 
                                    (self.prob_df['time_stamp'] == time)].mod_prob_match_weekend.values[0]
            
        return prob 
    
    
    time_bins = [dt.time(0,0),dt.time(0,30), dt.time(1,0), dt.time(1,30), dt.time(2,0), 
        dt.time(2,30), dt.time(3,0), dt.time(3,30), dt.time(4,0),
        dt.time(4,30), dt.time(5,0), dt.time(5,30), dt.time(6,0),
        dt.time(6,30), dt.time(7,0), dt.time(7,30), dt.time(8,0),
        dt.time(8,30), dt.time(9,0), dt.time(9,30), dt.time(10,0),
        dt.time(10,30), dt.time(11,0), dt.time(11,30), dt.time(12,0),
        dt.time(12,30), dt.time(13,0), dt.time(13,30), dt.time(14,0),
        dt.time(14,30), dt.time(15,0), dt.time(15,30), dt.time(16,0), 
        dt.time(16,30), dt.time(17,0), dt.time(17,30), dt.time(18,0),
        dt.time(18,30), dt.time(19,0), dt.time(19,30), dt.time(20,0),
        dt.time(20,30), dt.time(21,0), dt.time(21,30), dt.time(22,0),
        dt.time(22,30), dt.time(23,0), dt.time(23,30), dt.time(23,59,59)] 
    
    
    def get_time_window(self, datetime):
        for i in range(0,48):
            if (datetime.time() >= self.time_bins[i]) & (datetime.time() < self.time_bins[i+1]): 
                return i+1 
            else :
                return 48
    
     
    def reposition_to_high( self, current_zone, time ):
        #adj = self.get_adjacent_zone( current_zone )
        #adj.append( current_zone )
        #demand_list = [self.get_demand(zone, time) for zone in adj]
        #print(demand_list)
        # find the index of the max value of demand_lisy, and find which zone it is
        #return adj[demand_list.index( max(demand_list))]  
    
         
        adj = self.get_adjacent_zone( current_zone )
        adj.insert(0,current_zone)
        # find the index of the max value of near_prob, and find which zone it is 
        demand_list = [self.get_demand(zone, time) for zone in adj]
        a_arr  = np.array(demand_list)
        print("a_arr: ", a_arr)
        #near_prob = list(np.exp((a_arr-a_arr[0])*10)/np.sum(np.exp((a_arr-a_arr[0])*10))) 
        near_prob = list(np.exp((a_arr-a_arr[0]))/np.sum(np.exp((a_arr-a_arr[0]))))
        print("near prob :", near_prob) 
        
        return(adj[near_prob.index( max(near_prob))])
    
    def reposition_to_any( self, current_zone, time ):
        #adj = self.get_adjacent_zone( current_zone )
        #adj.append( current_zone )
        #demand_list = [self.get_demand(zone, time) for zone in adj]
        #print(demand_list)
        # find the index of the max value of demand_lisy, and find which zone it is
        #return adj[demand_list.index( max(demand_list))]  
    
         
        adj = self.get_adjacent_zone( current_zone )
        adj.insert(0,current_zone)
        # find the index of the max value of near_prob, and find which zone it is 
        r = random.randint(0,len(adj)-1) 
        
        
        return(adj[r])

# %%
# one round of simulation 
#random.seed(500)
init_time = dt.datetime(2013, 6, 3, 5, 0, 0) 
init_zone = 12
avg_speed_waiting = 10 # defined in mph

#Initialize enviorment and driver 
env = Env( isWeekday = True ) 
driver = Driver( time = init_time, location = init_zone, total_fare = 0, total_cost = 0, is_idle = True) 

# print(driver.location)
# print(driver.time)
# print(driver.total_fare)
# print(driver.total_cost)
# print(driver.is_idle)


while driver.time < init_time + timedelta(seconds=0, minutes=0, hours = 11):
    #get prob that driver will be matched to a passenger 
    matching_prob = env.get_matching_prob( zone = driver.location, time = env.get_time_window(driver.time) )
    #print(matching_prob)
    start_zone = driver.location
    print('current time is ', driver.time, 'and driver is at zone ', driver.location)
    if env.is_matched(matching_prob):

        # time it takes before getting matched 
        wait_time = env.wait_time_before_pickup(matching_prob)
        print('driver waited for ', wait_time, ' min before he picks up')

        # cost of cruising
        driver.set_total_cost(driver.total_cost + avg_speed_waiting * wait_time/60 * 0.124)

        # set driver time to new time 
        driver.set_time( driver.time + timedelta(seconds=0, minutes= wait_time, hours=0 ) )
        print('driver gets a pick up and is now at time ', driver.time)    


        #driver is now busy 
        driver.set_is_idle(False)


        # find the destination of the trip and set destination 
        dest = env.get_destination(driver.location)
        driver.set_location(dest)
        print ('driver is going to zone', dest, 'and driver arrived at zone', driver.location)    

         # find the trip duration and update new time 
        duration = env.get_trip_duration(start_zone = start_zone, end_zone = dest, shift_time=driver.get_shift_time_weekday())
        print ('trip duration ', duration)
        driver.set_time( driver.time + timedelta(seconds=0, minutes= duration, hours=0 ) )
        print ('driver drops off passenger at time ', driver.time)


        #find trip fare and update fare 
        fare = env.get_fare( start_zone, dest, driver.get_shift_time_weekday())
        driver.set_total_fare(driver.total_fare + fare)
        print('trip fare from ', start_zone, 'to ', driver.location,   ' is',  fare)
        print('driver total fare earned is ', driver.total_fare )

        #frin trip cost and update cost 
        cost = env.get_fuel_cost(start_zone, dest)
        driver.set_total_cost(driver.total_cost + cost)
        print('fuel cost from ', start_zone, 'to ', driver.location,   ' is', cost  )

        print('************************trip is completed.************************** ')


    else: 
        #time it takes before reposition 
        print('driver does not get a pick up at the current zone: zone ', driver.location )
        
        wait_time = env.wait_time_before_reposition()
        driver.set_time( driver.time + timedelta(seconds=0, minutes= wait_time, hours=0 ) )
        print('driver now decides to check reposition info after ', wait_time, ' min of crusing and current time is ', driver.time)
       
        # cost of cruising
        driver.set_total_cost(driver.total_cost + avg_speed_waiting * wait_time/60 * 0.124)

        
        repo = env.reposition_to(driver.location, env.get_time_window(driver.time) ) #fix this to distribution 
        
        '''
            TODO:
            add cost - assume 10 miles a hour '''
                                                                       
                
        driver.set_location(repo)
        print('driver is repostioning to zone ', repo, 'and arrived at zone ', driver.location)

        # find the trip duration and update new time 
        duration = env.get_trip_duration(start_zone = start_zone, end_zone = repo, shift_time=driver.get_shift_time_weekday())
        print ('reposition trip duration ', duration , 'min')
        driver.set_time( driver.time + timedelta(seconds=0, minutes= duration, hours=0 ) )
        print ('After repositioning, it is now ', driver.time)

        #frin trip cost and update cost 
        cost = env.get_fuel_cost(start_zone, repo)
        driver.set_total_cost(driver.total_cost + cost)
        print('fuel cost from ', start_zone, 'to ', driver.location,   ' is', cost  )


        print('************************reposition is completed.************************** ')


        
print('total fare earned from this shift is ', driver.total_fare )
print('total fuel cost is ', driver.total_cost)
print('profit is ', driver.total_fare - driver.total_cost)
# Out:
# current time is  2013-06-03 05:00:00 and driver is at zone  12
# driver does not get a pick up at the current zone: zone  12
# driver now decides to check reposition info after  7  min of crusing and current time is  2013-06-03 05:07:00
# a_arr:  [ 3.23552734 64.90819679 40.7921283  40.97870819]
# near prob : [1.6439930381327084e-27, 0.9999999999258763, 3.361433521042715e-11, 4.050933794866688e-11]
# driver is repostioning to zone  13 and arrived at zone  13
# reposition trip duration  5.317857142857141 min
# After repositioning, it is now  2013-06-03 05:12:19.071429
# fuel cost from  12 to  13  is 0.09376399918380383
# ************************reposition is completed.**************************
# current time is  2013-06-03 05:12:19.071429 and driver is at zone  13
# driver does not get a pick up at the current zone: zone  13
# driver now decides to check reposition info after  4  min of crusing and current time is  2013-06-03 05:16:19.071429
# a_arr:  [ 64.90819679 273.68433875  40.97870819   3.23552734]
# near prob : [2.136355851190561e-91, 1.0, 8.654236116090517e-102, 3.512154146591693e-118]
# driver is repostioning to zone  231 and arrived at zone  231
# reposition trip duration  5.96365466177844 min
# After repositioning, it is now  2013-06-03 05:22:16.890709
# fuel cost from  13 to  231  is 0.11366661753577893
# ************************reposition is completed.**************************
# current time is  2013-06-03 05:22:16.890709 and driver is at zone  231
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 05:25:16.890709
# driver is going to zone 13 and driver arrived at zone 13
# trip duration  5.660451661067567
# driver drops off passenger at time  2013-06-03 05:30:56.517809
# trip fare from  231 to  13  is 5.911720791340052
# driver total fare earned is  5.911720791340052
# fuel cost from  231 to  13  is 0.11112757785466237
# ************************trip is completed.**************************
# current time is  2013-06-03 05:30:56.517809 and driver is at zone  13
# driver waited for  13  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 05:43:56.517809
# driver is going to zone 161 and driver arrived at zone 161
# trip duration  22.51043244152782
# driver drops off passenger at time  2013-06-03 06:06:27.143755
# trip fare from  13 to  161  is 20.4994952044422
# driver total fare earned is  26.411215995782253
# fuel cost from  13 to  161  is 0.625103805401925
# ************************trip is completed.**************************
# current time is  2013-06-03 06:06:27.143755 and driver is at zone  161
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 06:10:27.143755
# driver is going to zone 234 and driver arrived at zone 234
# trip duration  9.480321141126783
# driver drops off passenger at time  2013-06-03 06:19:55.963023
# trip fare from  161 to  234  is 8.33397083432943
# driver total fare earned is  34.745186830111685
# fuel cost from  161 to  234  is 0.17546927483012453
# ************************trip is completed.**************************
# current time is  2013-06-03 06:19:55.963023 and driver is at zone  234
# driver waited for  2  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 06:21:55.963023
# driver is going to zone 234 and driver arrived at zone 234
# trip duration  5.92387961128409
# driver drops off passenger at time  2013-06-03 06:27:51.395800
# trip fare from  234 to  234  is 5.947353523917351
# driver total fare earned is  40.692540354029035
# fuel cost from  234 to  234  is 0.08994164632550714
# ************************trip is completed.**************************
# current time is  2013-06-03 06:27:51.395800 and driver is at zone  234
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 06:31:51.395800
# driver is going to zone 211 and driver arrived at zone 211
# trip duration  9.026232993197276
# driver drops off passenger at time  2013-06-03 06:40:52.969780
# trip fare from  234 to  211  is 8.077168367346939
# driver total fare earned is  48.76970872137598
# fuel cost from  234 to  211  is 0.1716897539366727
# ************************trip is completed.**************************
# current time is  2013-06-03 06:40:52.969780 and driver is at zone  211
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 06:41:52.969780
# driver is going to zone 223 and driver arrived at zone 223
# trip duration  23.425
# driver drops off passenger at time  2013-06-03 07:05:18.469780
# trip fare from  211 to  223  is 27.73684210526316
# driver total fare earned is  76.50655082663914
# fuel cost from  211 to  223  is 1.074750694010498
# ************************trip is completed.**************************
# current time is  2013-06-03 07:05:18.469780 and driver is at zone  223
# driver does not get a pick up at the current zone: zone  223
# driver now decides to check reposition info after  8  min of crusing and current time is  2013-06-03 07:13:18.469780
# a_arr:  [ 13.13313477  35.67191093   1.39546875   5.49765747 325.1126424
#    9.55785187   1.33335938]
# near prob : [3.228652960532526e-136, 1.983752491969781e-126, 2.5788007351057636e-141, 1.5594652814888871e-139, 1.0, 9.042650227565714e-138, 2.4235055939492534e-141]
# driver is repostioning to zone  138 and arrived at zone  138
# reposition trip duration  8.683926218708825 min
# After repositioning, it is now  2013-06-03 07:21:59.505353
# fuel cost from  223 to  138  is 0.39758546760232477
# ************************reposition is completed.**************************
# current time is  2013-06-03 07:21:59.505353 and driver is at zone  138
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 07:24:59.505353
# driver is going to zone 161 and driver arrived at zone 161
# trip duration  38.011769141133705
# driver drops off passenger at time  2013-06-03 08:03:00.211501
# trip fare from  138 to  161  is 35.55490438001234
# driver total fare earned is  112.06145520665149
# fuel cost from  138 to  161  is 1.184233152236627
# ************************trip is completed.**************************
# current time is  2013-06-03 08:03:00.211501 and driver is at zone  161
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 08:04:00.211501
# driver is going to zone 181 and driver arrived at zone 181
# trip duration  29.98423913043479
# driver drops off passenger at time  2013-06-03 08:33:59.265849
# trip fare from  161 to  181  is 27.98641304347826
# driver total fare earned is  140.04786825012974
# fuel cost from  161 to  181  is 0.8568254501151016
# ************************trip is completed.**************************
# current time is  2013-06-03 08:33:59.265849 and driver is at zone  181
# driver waited for  12  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 08:45:59.265849
# driver is going to zone 188 and driver arrived at zone 188
# trip duration  9.182674199623351
# driver drops off passenger at time  2013-06-03 08:55:10.226301
# trip fare from  181 to  188  is 10.16101694915254
# driver total fare earned is  150.2088851992823
# fuel cost from  181 to  188  is 0.30423164293013494
# ************************trip is completed.**************************
# current time is  2013-06-03 08:55:10.226301 and driver is at zone  188
# driver does not get a pick up at the current zone: zone  188
# driver now decides to check reposition info after  8  min of crusing and current time is  2013-06-03 09:03:10.226301
# a_arr:  [2.5640625  2.25344971 1.88045898 1.         1.39546875 1.55466797
#  1.88766113]
# near prob : [0.2754241923733661, 0.20188528377114665, 0.13903266580387408, 0.0576419111318854, 0.0856028585554453, 0.1003754741136496, 0.140037614250633]
# driver is repostioning to zone  190 and arrived at zone  190
# reposition trip duration  5.9433333333333325 min
# After repositioning, it is now  2013-06-03 09:09:06.826301
# fuel cost from  188 to  190  is 0.16976635833107168
# ************************reposition is completed.**************************
# current time is  2013-06-03 09:09:06.826301 and driver is at zone  190
# driver does not get a pick up at the current zone: zone  190
# driver now decides to check reposition info after  4  min of crusing and current time is  2013-06-03 09:13:06.826301
# a_arr:  [ 2.25344971  2.04365479  1.88045898  1.88766113 71.35        2.5640625
#  16.06301208]
# near prob : [9.81181812106133e-31, 7.954936409431338e-31, 6.757120698803908e-31, 6.805962155677105e-31, 1.0, 1.3385879501603884e-30, 9.7536288919812e-25]
# driver is repostioning to zone  181 and arrived at zone  181
# reposition trip duration  5.927450980392157 min
# After repositioning, it is now  2013-06-03 09:19:02.473360
# fuel cost from  190 to  181  is 0.19232822869552108
# ************************reposition is completed.**************************
# current time is  2013-06-03 09:19:02.473360 and driver is at zone  181
# driver does not get a pick up at the current zone: zone  181
# driver now decides to check reposition info after  1  min of crusing and current time is  2013-06-03 09:20:02.473360
# a_arr:  [71.35       16.06301208  2.25344971  2.34195313  2.04365479 40.44467834
#  39.35053711  6.16577087]
# near prob : [0.9999999999999496, 9.753628891980708e-25, 9.811818121060836e-31, 1.0719784017467344e-30, 7.954936409430947e-31, 3.784332989446728e-14, 1.2670969418183911e-14, 4.9073720321390557e-29]
# driver is repostioning to zone  181 and arrived at zone  181
# reposition trip duration  5.704335511982572 min
# After repositioning, it is now  2013-06-03 09:25:44.733491
# fuel cost from  181 to  181  is 0.12517573096339915
# ************************reposition is completed.**************************
# current time is  2013-06-03 09:25:44.733491 and driver is at zone  181
# driver waited for  11  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 09:36:44.733491
# driver is going to zone 65 and driver arrived at zone 65
# trip duration  10.596584699453553
# driver drops off passenger at time  2013-06-03 09:47:20.528573
# trip fare from  181 to  65  is 9.204918032786884
# driver total fare earned is  159.41380323206917
# fuel cost from  181 to  65  is 0.18098992204833264
# ************************trip is completed.**************************
# current time is  2013-06-03 09:47:20.528573 and driver is at zone  65
# driver waited for  14  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 10:01:20.528573
# driver is going to zone 107 and driver arrived at zone 107
# trip duration  14.879787234042558
# driver drops off passenger at time  2013-06-03 10:16:13.315807
# trip fare from  65 to  107  is 14.680851063829786
# driver total fare earned is  174.09465429589895
# fuel cost from  65 to  107  is 0.4042659021338275
# ************************trip is completed.**************************
# current time is  2013-06-03 10:16:13.315807 and driver is at zone  107
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 10:17:13.315807
# driver is going to zone 209 and driver arrived at zone 209
# trip duration  13.246050096339118
# driver drops off passenger at time  2013-06-03 10:30:28.078813
# trip fare from  107 to  209  is 12.992774566473988
# driver total fare earned is  187.08742886237295
# fuel cost from  107 to  209  is 0.3539397684562921
# ************************trip is completed.**************************
# current time is  2013-06-03 10:30:28.078813 and driver is at zone  209
# driver waited for  14  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 10:44:28.078813
# driver is going to zone 170 and driver arrived at zone 170
# trip duration  14.692571428571425
# driver drops off passenger at time  2013-06-03 10:59:09.633099
# trip fare from  209 to  170  is 15.977142857142857
# driver total fare earned is  203.0645717195158
# fuel cost from  209 to  170  is 0.47883356964650653
# ************************trip is completed.**************************
# current time is  2013-06-03 10:59:09.633099 and driver is at zone  170
# driver waited for  2  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 11:01:09.633099
# driver is going to zone 48 and driver arrived at zone 48
# trip duration  11.249025475751964
# driver drops off passenger at time  2013-06-03 11:12:24.574628
# trip fare from  170 to  48  is 9.22720994475138
# driver total fare earned is  212.2917816642672
# fuel cost from  170 to  48  is 0.1720680103894003
# ************************trip is completed.**************************
# current time is  2013-06-03 11:12:24.574628 and driver is at zone  48
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 11:13:24.574628
# driver is going to zone 141 and driver arrived at zone 141
# trip duration  12.560314061384725
# driver drops off passenger at time  2013-06-03 11:25:58.193472
# trip fare from  48 to  141  is 10.89507494646681
# driver total fare earned is  223.18685661073403
# fuel cost from  48 to  141  is 0.2824269683093404
# ************************trip is completed.**************************
# current time is  2013-06-03 11:25:58.193472 and driver is at zone  141
# driver waited for  8  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 11:33:58.193472
# driver is going to zone 263 and driver arrived at zone 263
# trip duration  4.761951767119571
# driver drops off passenger at time  2013-06-03 11:38:43.910578
# trip fare from  141 to  263  is 5.707873649982581
# driver total fare earned is  228.8947302607166
# fuel cost from  141 to  263  is 0.12274754363944075
# ************************trip is completed.**************************
# current time is  2013-06-03 11:38:43.910578 and driver is at zone  263
# driver waited for  12  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 11:50:43.910578
# driver is going to zone 48 and driver arrived at zone 48
# trip duration  19.924452736318404
# driver drops off passenger at time  2013-06-03 12:10:39.377742
# trip fare from  263 to  48  is 15.317164179104475
# driver total fare earned is  244.2118944398211
# fuel cost from  263 to  48  is 0.38981229220722563
# ************************trip is completed.**************************
# current time is  2013-06-03 12:10:39.377742 and driver is at zone  48
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 12:13:39.377742
# driver is going to zone 50 and driver arrived at zone 50
# trip duration  5.95272733823317
# driver drops off passenger at time  2013-06-03 12:19:36.541382
# trip fare from  48 to  50  is 5.851275399913532
# driver total fare earned is  250.06316983973463
# fuel cost from  48 to  50  is 0.08949468362021006
# ************************trip is completed.**************************
# current time is  2013-06-03 12:19:36.541382 and driver is at zone  50
# driver waited for  8  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 12:27:36.541382
# driver is going to zone 151 and driver arrived at zone 151
# trip duration  10.25255681818182
# driver drops off passenger at time  2013-06-03 12:37:51.694791
# trip fare from  50 to  151  is 10.948863636363637
# driver total fare earned is  261.0120334760983
# fuel cost from  50 to  151  is 0.33588992476127677
# ************************trip is completed.**************************
# current time is  2013-06-03 12:37:51.694791 and driver is at zone  151
# driver does not get a pick up at the current zone: zone  151
# driver now decides to check reposition info after  6  min of crusing and current time is  2013-06-03 12:43:51.694791
# a_arr:  [ 46.19911888 119.4507489   27.97708054  76.78454407]
# near prob : [1.5389385963732702e-32, 1.0, 1.87711374341253e-40, 2.953266756953366e-19]
# driver is repostioning to zone  238 and arrived at zone  238
# reposition trip duration  4.157897946737132 min
# After repositioning, it is now  2013-06-03 12:48:01.168668
# fuel cost from  151 to  238  is 0.08469692041350763
# ************************reposition is completed.**************************
# current time is  2013-06-03 12:48:01.168668 and driver is at zone  238
# driver waited for  11  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 12:59:01.168668
# driver is going to zone 162 and driver arrived at zone 162
# trip duration  20.73192756730999
# driver drops off passenger at time  2013-06-03 13:19:45.084322
# trip fare from  238 to  162  is 15.294496068620443
# driver total fare earned is  276.3065295447187
# fuel cost from  238 to  162  is 0.319673303305886
# ************************trip is completed.**************************
# current time is  2013-06-03 13:19:45.084322 and driver is at zone  162
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 13:23:45.084322
# driver is going to zone 137 and driver arrived at zone 137
# trip duration  8.270221106412974
# driver drops off passenger at time  2013-06-03 13:32:01.297588
# trip fare from  162 to  137  is 7.541622621564482
# driver total fare earned is  283.8481521662832
# fuel cost from  162 to  137  is 0.14121277213489403
# ************************trip is completed.**************************
# current time is  2013-06-03 13:32:01.297588 and driver is at zone  137
# driver waited for  5  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 13:37:01.297588
# driver is going to zone 79 and driver arrived at zone 79
# trip duration  5.854769364664929
# driver drops off passenger at time  2013-06-03 13:42:52.583750
# trip fare from  137 to  79  is 6.500609225413403
# driver total fare earned is  290.34876139169666
# fuel cost from  137 to  79  is 0.14036233557437164
# ************************trip is completed.**************************
# current time is  2013-06-03 13:42:52.583750 and driver is at zone  79
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 13:43:52.583750
# driver is going to zone 148 and driver arrived at zone 148
# trip duration  7.415992836763202
# driver drops off passenger at time  2013-06-03 13:51:17.543320
# trip fare from  79 to  148  is 6.606173738845383
# driver total fare earned is  296.954935130542
# fuel cost from  79 to  148  is 0.10079478622882863
# ************************trip is completed.**************************
# current time is  2013-06-03 13:51:17.543320 and driver is at zone  148
# driver waited for  2  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 13:53:17.543320
# driver is going to zone 107 and driver arrived at zone 107
# trip duration  8.014132020423043
# driver drops off passenger at time  2013-06-03 14:01:18.391241
# trip fare from  148 to  107  is 7.554850474106492
# driver total fare earned is  304.5097856046485
# fuel cost from  148 to  107  is 0.1594598518803607
# ************************trip is completed.**************************
# current time is  2013-06-03 14:01:18.391241 and driver is at zone  107
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 14:05:18.391241
# driver is going to zone 186 and driver arrived at zone 186
# trip duration  12.2470105396085
# driver drops off passenger at time  2013-06-03 14:17:33.211873
# trip fare from  107 to  186  is 9.148171353635435
# driver total fare earned is  313.657956958284
# fuel cost from  107 to  186  is 0.14806886955820234
# ************************trip is completed.**************************
# current time is  2013-06-03 14:17:33.211873 and driver is at zone  186
# driver does not get a pick up at the current zone: zone  186
# driver now decides to check reposition info after  8  min of crusing and current time is  2013-06-03 14:25:33.211873
# a_arr:  [228.65       454.14647856 343.85844269 223.92525482 164.46071365
#  325.18862457]
# near prob : [1.169832476207935e-98, 1.0, 1.266235840282925e-48, 1.0379893905020304e-100, 1.552640163545851e-126, 9.869965083776094e-57]
# driver is repostioning to zone  234 and arrived at zone  234
# reposition trip duration  7.437189997422004 min
# After repositioning, it is now  2013-06-03 14:32:59.443273
# fuel cost from  186 to  234  is 0.10351918392542175
# ************************reposition is completed.**************************
# current time is  2013-06-03 14:32:59.443273 and driver is at zone  234
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 14:33:59.443273
# driver is going to zone 170 and driver arrived at zone 170
# trip duration  8.146524511341052
# driver drops off passenger at time  2013-06-03 14:42:08.234744
# trip fare from  234 to  170  is 7.177179366572593
# driver total fare earned is  320.8351363248566
# fuel cost from  234 to  170  is 0.13556440581986276
# ************************trip is completed.**************************
# current time is  2013-06-03 14:42:08.234744 and driver is at zone  170
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 14:45:08.234744
# driver is going to zone 148 and driver arrived at zone 148
# trip duration  14.170871261378398
# driver drops off passenger at time  2013-06-03 14:59:18.487020
# trip fare from  170 to  148  is 11.811226701343736
# driver total fare earned is  332.64636302620033
# fuel cost from  170 to  148  is 0.27153751608584076
# ************************trip is completed.**************************
# current time is  2013-06-03 14:59:18.487020 and driver is at zone  148
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 15:00:18.487020
# driver is going to zone 142 and driver arrived at zone 142
# trip duration  24.426388888888876
# driver drops off passenger at time  2013-06-03 15:24:44.070353
# trip fare from  148 to  142  is 19.45833333333333
# driver total fare earned is  352.10469635953365
# fuel cost from  148 to  142  is 0.5136248655156825
# ************************trip is completed.**************************
# current time is  2013-06-03 15:24:44.070353 and driver is at zone  142
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 15:25:44.070353
# driver is going to zone 43 and driver arrived at zone 43
# trip duration  8.214664134346254
# driver drops off passenger at time  2013-06-03 15:33:56.950201
# trip fare from  142 to  43  is 7.694822071171531
# driver total fare earned is  359.7995184307052
# fuel cost from  142 to  43  is 0.15889876970949718
# ************************trip is completed.**************************
# current time is  2013-06-03 15:33:56.950201 and driver is at zone  43
# driver does not get a pick up at the current zone: zone  43
# driver now decides to check reposition info after  8  min of crusing and current time is  2013-06-03 15:41:56.950201
# a_arr:  [ 76.78454407  54.8828331  321.12511148  46.19911888 285.637254
#  170.10585251 247.70259251 119.4507489  209.06707077  27.97708054
#   38.56653259]
# near prob : [7.660195711406359e-107, 2.3574779966627213e-116, 0.9999999999999997, 3.99170539142814e-120, 3.870965670156523e-16, 2.5892212676080756e-66, 1.2971946843959596e-32, 2.5938041977991635e-88, 2.1568069032990298e-49, 4.868865507409921e-128, 1.933607726886557e-123]
# driver is repostioning to zone  142 and arrived at zone  142
# reposition trip duration  7.871725822591064 min
# After repositioning, it is now  2013-06-03 15:49:49.253750
# fuel cost from  43 to  142  is 0.15502004569859693
# ************************reposition is completed.**************************
# current time is  2013-06-03 15:49:49.253750 and driver is at zone  142
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 15:52:49.253750
# driver is going to zone 239 and driver arrived at zone 239
# trip duration  5.740729313390122
# driver drops off passenger at time  2013-06-03 15:58:33.697509
# trip fare from  142 to  239  is 6.112247635656315
# driver total fare earned is  365.9117660663615
# fuel cost from  142 to  239  is 0.10588669243333534
# ************************trip is completed.**************************
# current time is  2013-06-03 15:58:33.697509 and driver is at zone  239
# driver waited for  10  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 16:08:33.697509
# driver is going to zone 238 and driver arrived at zone 238
# trip duration  4.363531932754552
# driver drops off passenger at time  2013-06-03 16:12:55.509425
# trip fare from  239 to  238  is 5.357565113658957
# driver total fare earned is  371.26933118002046
# fuel cost from  239 to  238  is 0.0975438579885471
# ************************trip is completed.**************************
# total fare earned from this shift is  371.26933118002046
# total fuel cost is  15.61665882810451
# profit is  355.65267235191595

# %%
'''TODO: 
Monte Carlo Simulation'''
# Out:
# 'TODO: \nMonte Carlo Simulation'
