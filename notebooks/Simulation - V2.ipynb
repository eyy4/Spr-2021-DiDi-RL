# %%
import numpy as np
import pandas as pd 
import datetime as dt
from datetime import timedelta 
import random
from decimal import Decimal

# %%
class Driver: 
    

    
    def __init__(self, time, location, total_fare, total_cost, is_idle ):
        self.time = time 
        self.location = location 
        self.total_fare = total_fare
        self.total_cost  = total_cost
        self.is_idle = is_idle
    
    def set_time(self, new_time):
        self.time = new_time
    
    def get_time(self):
        return self.__time 
    
    def set_location(self, new_location):
        self.location = new_location
        
    def get_location(self):
        return self.__location 
   
    def set_total_fare(self, new_fare):
        self.total_fare = new_fare
    
    def get_total_fare(self):
        return self.total_fare 
    
    def set_is_idle(self, is_idle):
        self.is_idle = is_idle 
        
    def set_total_cost(self, new_cost):
        self.total_cost = new_cost
    
    def get_total_cost(self):
        return self.total_cost 
    
    def get_shift_time_weekday(self):


        weekend = [5,6]
        weekend_ind = lambda n: 0 if n in weekend else 1
        weekday = weekend_ind(self.time.weekday)

        normtime = driver.time.time()
        roundtime = pd.Timestamp(driver.time).round('30min').time()
        
        
        if weekday:
            if (normtime > dt.time(23, 30)) | (normtime <= dt.time(11, 30)):
                return ('A', roundtime,weekday)
            else:
                return ('B', roundtime,weekday)
        else: ## weekend
            if (normtime > dt.time(2, 0)) & (normtime <= dt.time(14, 0)):
                return ('A', roundtime,weekday)
            else:
                return ('B', roundtime,weekday)

# %%
class Env: 
    
    
    arrivals = pd.read_csv('../data/arrival_rates.csv')[['taxi_zone', 'time_stamp','arr_weekday','arr_weekend']]
    dropoff_counts = pd.read_csv('../data/pickup_dropoff_summary.csv')
    fare_df = pd.read_csv('../data/fare_amount_scr_dst_t.csv')
    dist_df = pd.read_csv('../data/trip_distance_scr_dst.csv')
    trip_time_df = pd.read_csv('../data/trip_time_scr_dst_t.csv')
    prob_df = pd.read_csv('../data/prob_match_combined_new.csv')
    trans_matrix = pd.read_csv('../data/dropoff_after_pickup.csv') # fix this to shift based and a
     # 0 weekend , A night shift 
    
    #time in 1..48,  isWeekday is a boolean
    def __init__(self,  isWeekday):   

        self.isWeekday = isWeekday 
        
    
    def is_matched(self, matching_prob):
        n = random.random()

        if n <= matching_prob:
            return True 
        else: 
            False 
    
    def get_destination(self, zone):
        prob = self.trans_matrix.iloc[zone-1].values[1:]
        n = random.random()

        count = 0
        for i in range(len(prob)):
            count = count + prob[i]
            if n<count:
                return i+1

    def get_adjacent_zone( self, taxi_zone ):
        df = pd.read_csv('../data/adjacent_zone.csv')
        adj_zone_1 = df.loc[df["zone1"]==taxi_zone, "zone2"].values.tolist()
        adj_zone_2 = df.loc[df["zone2"]==taxi_zone, "zone1"].values.tolist()
        adj_zone_list = list(filter(None, adj_zone_1+adj_zone_2))
        return(adj_zone_list)
    
    def get_demand(self, zone, time):
        #row = self.arrivals.loc[ ( self.arrivals['taxi_zone'] == zone ) & (self.arrivals['time_stamp'] == time ) ]
        row = self.prob_df.loc[ ( self.arrivals['taxi_zone'] == zone ) & (self.arrivals['time_stamp'] == time ) ]
       
        if self.isWeekday:
            return row['arr_weekday'].values[0]
        else:
            return row['arr_weekend'].values[0]
    
     #  def get_near_arrival():
    
    
    '''TODO： 
        fix policy fucntion - add randomness'''
   
       
            
    def reposition_to( self, current_zone, time ):
        #adj = self.get_adjacent_zone( current_zone )
        #adj.append( current_zone )
        #demand_list = [self.get_demand(zone, time) for zone in adj]
        #print(demand_list)
        # find the index of the max value of demand_lisy, and find which zone it is
        #return adj[demand_list.index( max(demand_list))]  
    
         
        adj = self.get_adjacent_zone( current_zone )
        adj.insert(0,current_zone)
        # find the index of the max value of near_prob, and find which zone it is 
        demand_list = [self.get_demand(zone, time) for zone in adj]
        a_arr  = np.array([Decimal(x) for x in demand_list]) #np.array(demand_list)
        print("a_arr: ", a_arr)
        #near_prob = list(np.exp((a_arr-a_arr[0])*10)/np.sum(np.exp((a_arr-a_arr[0])*10))) 
        near_prob = list(np.exp((a_arr-a_arr[0]))/np.sum(np.exp((a_arr-a_arr[0]))))
        print("near prob :", near_prob)  
        
        # 20, 28, 52
        
        r = random.random()
        #25
        
        count = 0
        for i in range(len(near_prob)):
            count = count + near_prob[i]
            if r < count:
                return(adj[i])  
        
        #repo_zone = adj[r_index]   
        
        #repo_prob = near_prob.index( max(near_prob))
        
    
        #print("r, repo, repo_prob", r, repo, repo_prob)
            
      
            
          
        #return (adj[near_prob.index( max(near_prob))],  is_repositioned)
    
        #SOFTMAX 
        #NEAR ARRIVAL 
        # return the highest prob of near arrival 
        
        
        ### paper's calculation of nearest prob
        # zone 1 = 10 , zone2 = 10.1 , zone 3 = 5
        # p(zone 1) = 10/25.5 = 0.392
        # p(zone 2) = 10.1/25.5 = 0.396
        # p(zone 3) = 5/25.5 = 0.196 
        
        
        # softmax suggestion way 
        # zone 1 = 10 , zone2 = 10.1 , zone 3 = 5
        # B  = 10 
        #exp(B * (rho1 - rho1) - e) / exp(B * (rho1 - rho1)) + exp(B * (rho2 - rho1)) + exp(B * (rho3 - rho1) - e) = 0.27
        #exp(B * (rho2 - rho1) - e) / exp(10) + exp(10.2) + exp(5)  = 0.73
        #exp(B * (rho3 - rho1) - e) / exp(10) + exp(10.2) + exp(5)  = 0.0
        
        
     
    def wait_time_before_pickup(self, matching_prob):
        if ( matching_prob >= 0.9 ):
            return random.randint(1,4)
        elif ( matching_prob >= 0.7 ):
            return random.randint(5,10)
        elif ( matching_prob >= 0.5 ):
            return random.randint(11,15)
        elif ( matching_prob >= 0.3 ):
            return random.randint(16,20)
        else:
            return random.randint(21,29)
        
    def wait_time_before_reposition(self):
        return random.randint(1,10)
    
    # can look into histortical data combined with random number 

    
    
    def get_trip_duration(self, start_zone, end_zone, shift_time):    
        shift,roundtime,weekday_ind = shift_time
        roundtime = roundtime.strftime('%H:%M:%S') 
        
        zone_to_zone = self.trip_time_df[(self.trip_time_df["pickup_taxizone_id"] == start_zone) & 
                                        (self.trip_time_df["dropoff_taxizone_id"] == end_zone) &
                                        (self.trip_time_df["actual_data"] == 1)]
        
        if len(zone_to_zone)!=0:
            if len(zone_to_zone[(zone_to_zone['_PU_shift']==shift) & (zone_to_zone['pickup_datetime_interval']==roundtime) &
                                (zone_to_zone['pickup_weekday'] == weekday_ind)])>0:

                dur = zone_to_zone.loc[(zone_to_zone["_PU_shift"] == shift) &
                                       (zone_to_zone["pickup_datetime_interval"] == roundtime) &
                                       (zone_to_zone['pickup_weekday'] == weekday_ind), "mean"].mean() 

            elif len(zone_to_zone[(zone_to_zone['_PU_shift']==shift) & (zone_to_zone['pickup_weekday'] == weekday_ind)])>0:
                dur = zone_to_zone.loc[(zone_to_zone["_PU_shift"] == shift) &
                                       (zone_to_zone['pickup_weekday'] == weekday_ind), "mean"].mean()

            else:
                dur = zone_to_zone['mean'].mean()
        else: 
            dur = self.trip_time_df.loc[(self.trip_time_df["pickup_taxizone_id"] == start_zone) & 
                                    (self.trip_time_df["dropoff_taxizone_id"] == end_zone) &
                                    (self.trip_time_df["actual_data"] == 0),"mean"].mean()
        
        return dur
        
    def get_fare(self, start_zone, end_zone, shift_time): 
        
        shift,roundtime,weekday_ind = shift_time
        roundtime = roundtime.strftime('%H:%M:%S') 
        
        zone_to_zone = self.fare_df[(self.fare_df["pickup_taxizone_id"] == start_zone) & 
                                    (self.fare_df["dropoff_taxizone_id"] == end_zone) &
                                    (self.fare_df["actual_data"] == 1)]
                
        if len(zone_to_zone)!=0:
            if len(zone_to_zone[(zone_to_zone['_PU_shift']==shift) & (zone_to_zone['pickup_datetime_interval']==roundtime) &
                                (zone_to_zone['pickup_weekday'] == weekday_ind)])>0:

                fare = zone_to_zone.loc[(zone_to_zone["_PU_shift"] == shift) &
                                       (zone_to_zone["pickup_datetime_interval"] == roundtime) &
                                       (zone_to_zone['pickup_weekday'] == weekday_ind), "mean"].mean() 

            elif len(zone_to_zone[(zone_to_zone['_PU_shift']==shift) & (zone_to_zone['pickup_weekday'] == weekday_ind)])>0:
                fare = zone_to_zone.loc[(zone_to_zone["_PU_shift"] == shift) &
                                       (zone_to_zone['pickup_weekday'] == weekday_ind), "mean"].mean()

            else:
                fare = zone_to_zone['mean'].mean()
        else:
            dur = self.fare_df.loc[(self.fare_df["pickup_taxizone_id"] == start_zone) & 
                                    (self.fare_df["dropoff_taxizone_id"] == end_zone) &
                                    (self.fare_df["actual_data"] == 0),"mean"].mean()
        
        return fare
    
    def get_trip_distance(self, start_zone, end_zone):
        zone_to_zone = self.dist_df.loc[((self.dist_df["pickup_taxizone_id"] == start_zone) &
                                 (self. dist_df["dropoff_taxizone_id"] == end_zone) &
                                 (self.trip_time_df["actual_data"] == 1)), "mean"]
        if len(zone_to_zone) != 0:
            dist = zone_to_zone.mean()
        else:
            dist = self.dist_df.loc[((self.dist_df["pickup_taxizone_id"] == start_zone) &
                                 (self. dist_df["dropoff_taxizone_id"] == end_zone) &
                                 (self.trip_time_df["actual_data"] == 0)), "mean"]
        
        return dist 
    
    def get_fuel_cost(self, start_zone, end_zone): 
        
        cost = self.dist_df.loc[((self.dist_df["pickup_taxizone_id"] == start_zone) &
                                 (self. dist_df["dropoff_taxizone_id"] == end_zone)), "mean"].mean()*0.124
        return cost 
    
    def get_matching_prob(self, zone, time):
        if self.isWeekday:
            prob = self.prob_df.loc[(self.prob_df['taxi_zone'] == zone) & 
                                    (self.prob_df['time_stamp'] == time)].mod_prob_match_weekday.values[0]
        else: 
            prob = self.prob_df.loc[(self.prob_df['taxi_zone'] == zone) & 
                                    (self.prob_df['time_stamp'] == time)].mod_prob_match_weekend.values[0]
            
        return prob 
    
    
    time_bins = [dt.time(0,0),dt.time(0,30), dt.time(1,0), dt.time(1,30), dt.time(2,0), 
        dt.time(2,30), dt.time(3,0), dt.time(3,30), dt.time(4,0),
        dt.time(4,30), dt.time(5,0), dt.time(5,30), dt.time(6,0),
        dt.time(6,30), dt.time(7,0), dt.time(7,30), dt.time(8,0),
        dt.time(8,30), dt.time(9,0), dt.time(9,30), dt.time(10,0),
        dt.time(10,30), dt.time(11,0), dt.time(11,30), dt.time(12,0),
        dt.time(12,30), dt.time(13,0), dt.time(13,30), dt.time(14,0),
        dt.time(14,30), dt.time(15,0), dt.time(15,30), dt.time(16,0), 
        dt.time(16,30), dt.time(17,0), dt.time(17,30), dt.time(18,0),
        dt.time(18,30), dt.time(19,0), dt.time(19,30), dt.time(20,0),
        dt.time(20,30), dt.time(21,0), dt.time(21,30), dt.time(22,0),
        dt.time(22,30), dt.time(23,0), dt.time(23,30), dt.time(23,59,59)] 
    
    
    def get_time_window(self, datetime):
        for i in range(0,48):
            if (datetime.time() >= self.time_bins[i]) & (datetime.time() < self.time_bins[i+1]): 
                print("Debug " ,i, datetime.time())
                return i+1 
            #else :
                #print("Debug " ,48, datetime.time())
                #return 48
        return(48)  
    
     
    def reposition_to_high( self, current_zone, time ):
        #adj = self.get_adjacent_zone( current_zone )
        #adj.append( current_zone )
        #demand_list = [self.get_demand(zone, time) for zone in adj]
        #print(demand_list)
        # find the index of the max value of demand_lisy, and find which zone it is
        #return adj[demand_list.index( max(demand_list))]  
    
         
        adj = self.get_adjacent_zone( current_zone )
        adj.insert(0,current_zone)
        # find the index of the max value of near_prob, and find which zone it is 
        demand_list = [self.get_demand(zone, time) for zone in adj]
        a_arr  = np.array(demand_list)
        print("a_arr: ", a_arr)
        #near_prob = list(np.exp((a_arr-a_arr[0])*10)/np.sum(np.exp((a_arr-a_arr[0])*10))) 
        near_prob = list(np.exp((a_arr-a_arr[0]))/np.sum(np.exp((a_arr-a_arr[0]))))
        print("near prob :", near_prob) 
        
        return(adj[near_prob.index( max(near_prob))])
    
    def reposition_to_any( self, current_zone, time ):
        #adj = self.get_adjacent_zone( current_zone )
        #adj.append( current_zone )
        #demand_list = [self.get_demand(zone, time) for zone in adj]
        #print(demand_list)
        # find the index of the max value of demand_lisy, and find which zone it is
        #return adj[demand_list.index( max(demand_list))]  
    
         
        adj = self.get_adjacent_zone( current_zone )
        adj.insert(0,current_zone)
        # find the index of the max value of near_prob, and find which zone it is 
        r = random.randint(0,len(adj)-1) 
        
        
        return(adj[r])

# %%
# one round of simulation 
#random.seed(500)
init_time = dt.datetime(2013, 6, 3, 5, 0, 0) 
init_zone = 12
avg_speed_waiting = 10 # defined in mph

#Initialize enviorment and driver 
env = Env( isWeekday = True ) 
driver = Driver( time = init_time, location = init_zone, total_fare = 0, total_cost = 0, is_idle = True) 

# print(driver.location)
# print(driver.time)
# print(driver.total_fare)
# print(driver.total_cost)
# print(driver.is_idle)


while driver.time < init_time + timedelta(seconds=0, minutes=0, hours = 11):
    #get prob that driver will be matched to a passenger 
    matching_prob = env.get_matching_prob( zone = driver.location, time = env.get_time_window(driver.time) )
    #print(matching_prob)
    start_zone = driver.location
    print('current time is ', driver.time, 'and driver is at zone ', driver.location)
    if env.is_matched(matching_prob):

        # time it takes before getting matched 
        wait_time = env.wait_time_before_pickup(matching_prob)
        print('driver waited for ', wait_time, ' min before he picks up')

        # cost of cruising
        driver.set_total_cost(driver.total_cost + avg_speed_waiting * wait_time/60 * 0.124)

        # set driver time to new time 
        driver.set_time( driver.time + timedelta(seconds=0, minutes= wait_time, hours=0 ) )
        print('driver gets a pick up and is now at time ', driver.time)    


        #driver is now busy 
        driver.set_is_idle(False)


        # find the destination of the trip and set destination 
        dest = env.get_destination(driver.location)
        driver.set_location(dest)
        print ('driver is going to zone', dest, 'and driver arrived at zone', driver.location)    

         # find the trip duration and update new time 
        duration = env.get_trip_duration(start_zone = start_zone, end_zone = dest, shift_time=driver.get_shift_time_weekday())
        print ('trip duration ', duration)
        driver.set_time( driver.time + timedelta(seconds=0, minutes= duration, hours=0 ) )
        print ('driver drops off passenger at time ', driver.time)


        #find trip fare and update fare 
        fare = env.get_fare( start_zone, dest, driver.get_shift_time_weekday())
        driver.set_total_fare(driver.total_fare + fare)
        print('trip fare from ', start_zone, 'to ', driver.location,   ' is',  fare)
        print('driver total fare earned is ', driver.total_fare )

        #frin trip cost and update cost 
        cost = env.get_fuel_cost(start_zone, dest)
        driver.set_total_cost(driver.total_cost + cost)
        print('fuel cost from ', start_zone, 'to ', driver.location,   ' is', cost  )

        print('************************trip is completed.************************** ')


    else: 
        #time it takes before reposition 
        print('driver does not get a pick up at the current zone: zone ', driver.location )
        
        wait_time = env.wait_time_before_reposition()
        driver.set_time( driver.time + timedelta(seconds=0, minutes= wait_time, hours=0 ) )
        print('driver now decides to check reposition info after ', wait_time, ' min of crusing and current time is ', driver.time)
       
        # cost of cruising
        driver.set_total_cost(driver.total_cost + avg_speed_waiting * wait_time/60 * 0.124)

        
        repo = env.reposition_to(driver.location, env.get_time_window(driver.time) ) #fix this to distribution 
        
        '''
            TODO:
            add cost - assume 10 miles a hour '''
                                                                       
                
        driver.set_location(repo)
        print('driver is repostioning to zone ', repo, 'and arrived at zone ', driver.location)

        # find the trip duration and update new time 
        duration = env.get_trip_duration(start_zone = start_zone, end_zone = repo, shift_time=driver.get_shift_time_weekday())
        print ('reposition trip duration ', duration , 'min')
        driver.set_time( driver.time + timedelta(seconds=0, minutes= duration, hours=0 ) )
        print ('After repositioning, it is now ', driver.time)

        #frin trip cost and update cost 
        cost = env.get_fuel_cost(start_zone, repo)
        driver.set_total_cost(driver.total_cost + cost)
        print('fuel cost from ', start_zone, 'to ', driver.location,   ' is', cost  )


        print('************************reposition is completed.************************** ')


        
print('total fare earned from this shift is ', driver.total_fare )
print('total fuel cost is ', driver.total_cost)
print('profit is ', driver.total_fare - driver.total_cost)
# Out:
# Debug  10 05:00:00
# current time is  2013-06-03 05:00:00 and driver is at zone  12
# driver does not get a pick up at the current zone: zone  12
# driver now decides to check reposition info after  5  min of crusing and current time is  2013-06-03 05:05:00
# Debug  10 05:05:00
# a_arr:  [Decimal('1.000000000000003996802888650563545525074005126953125')
#  Decimal('11.456868896484376563194018672220408916473388671875')
#  Decimal('4.2161425781250017053025658242404460906982421875')
#  Decimal('7.1420507812500009237055564881302416324615478515625')]
# near prob : [Decimal('0.00002834996574590100632003411004'), Decimal('0.9860819250310746450603647998'), Decimal('0.0007068146023526042034757669203'), Decimal('0.01318291040082684972983939902')]
# driver is repostioning to zone  13 and arrived at zone  13
# reposition trip duration  5.317857142857141 min
# After repositioning, it is now  2013-06-03 05:10:19.071429
# fuel cost from  12 to  13  is 0.09376399918380383
# ************************reposition is completed.**************************
# Debug  10 05:10:19.071429
# current time is  2013-06-03 05:10:19.071429 and driver is at zone  13
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 05:14:19.071429
# driver is going to zone 137 and driver arrived at zone 137
# trip duration  16.596277205040092
# driver drops off passenger at time  2013-06-03 05:30:54.848061
# trip fare from  13 to  137  is 17.831615120274915
# driver total fare earned is  17.831615120274915
# fuel cost from  13 to  137  is 0.5731073338621474
# ************************trip is completed.**************************
# Debug  11 05:30:54.848061
# current time is  2013-06-03 05:30:54.848061 and driver is at zone  137
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 05:34:54.848061
# driver is going to zone 158 and driver arrived at zone 158
# trip duration  13.330508474576272
# driver drops off passenger at time  2013-06-03 05:48:14.678569
# trip fare from  137 to  158  is 11.023305084745765
# driver total fare earned is  28.85492020502068
# fuel cost from  137 to  158  is 0.28590860967276555
# ************************trip is completed.**************************
# Debug  11 05:48:14.678569
# current time is  2013-06-03 05:48:14.678569 and driver is at zone  158
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 05:52:14.678569
# driver is going to zone 80 and driver arrived at zone 80
# trip duration  20.00978407557355
# driver drops off passenger at time  2013-06-03 06:12:15.265614
# trip fare from  158 to  80  is 18.9838056680162
# driver total fare earned is  47.83872587303688
# fuel cost from  158 to  80  is 0.6116057838377024
# ************************trip is completed.**************************
# Debug  12 06:12:15.265614
# current time is  2013-06-03 06:12:15.265614 and driver is at zone  80
# driver does not get a pick up at the current zone: zone  80
# driver now decides to check reposition info after  9  min of crusing and current time is  2013-06-03 06:21:15.265614
# Debug  12 06:21:15.265614
# a_arr:  [Decimal('2.090888671875001936228954946273006498813629150390625')
#  Decimal('2.861621093750002398081733190338127315044403076171875')
#  Decimal('1.5208593749999972377651147326105274260044097900390625')
#  Decimal('1.53023437500000003552713678800500929355621337890625')
#  Decimal('1.68320312500000301980662698042578995227813720703125')
#  Decimal('4.60451660156250053290705182007513940334320068359375')
#  Decimal('4.4249023437500003552713678800500929355621337890625')
#  Decimal('1.896818847656249307220832633902318775653839111328125')
#  Decimal('1.93757812500000792255150372511707246303558349609375')
#  Decimal('1.333359375000003677058657558518461883068084716796875')]
# near prob : [Decimal('0.03357721890160860819540905087'), Decimal('0.07257207819663189508833586115'), Decimal('0.01898821514612796139035861379'), Decimal('0.01916706671992902545454817614'), Decimal('0.02233516363702579808689455299'), Decimal('0.4146669872841460011013074419'), Decimal('0.3464926131774409939026102278'), Decimal('0.02765421075059077475973585637'), Decimal('0.02880466292808465518265250374'), Decimal('0.01574178325841428683814771521')]
# driver is repostioning to zone  255 and arrived at zone  255
# reposition trip duration  4.96607905982906 min
# After repositioning, it is now  2013-06-03 06:26:13.230358
# fuel cost from  80 to  255  is 0.13162322361441003
# ************************reposition is completed.**************************
# Debug  12 06:26:13.230358
# current time is  2013-06-03 06:26:13.230358 and driver is at zone  255
# driver does not get a pick up at the current zone: zone  255
# driver now decides to check reposition info after  2  min of crusing and current time is  2013-06-03 06:28:13.230358
# Debug  12 06:28:13.230358
# a_arr:  [Decimal('4.60451660156250053290705182007513940334320068359375')
#  Decimal('4.4249023437500003552713678800500929355621337890625')
#  Decimal('2.090888671875001936228954946273006498813629150390625')
#  Decimal('2.861621093750002398081733190338127315044403076171875')]
# near prob : [Decimal('0.4781076136204886779293178094'), Decimal('0.3995031229960830898724248510'), Decimal('0.03871425624258908412310784813'), Decimal('0.08367500714083914807514949161')]
# driver is repostioning to zone  255 and arrived at zone  255
# reposition trip duration  4.316148263348888 min
# After repositioning, it is now  2013-06-03 06:32:32.199254
# fuel cost from  255 to  255  is 0.0962161849779874
# ************************reposition is completed.**************************
# Debug  13 06:32:32.199254
# current time is  2013-06-03 06:32:32.199254 and driver is at zone  255
# driver does not get a pick up at the current zone: zone  255
# driver now decides to check reposition info after  5  min of crusing and current time is  2013-06-03 06:37:32.199254
# Debug  13 06:37:32.199254
# a_arr:  [Decimal('4.330535888671875')
#  Decimal('4.67145751953124932498440102790482342243194580078125')
#  Decimal('1.68381347656249769073610877967439591884613037109375')
#  Decimal('2.694525146484375799360577730112709105014801025390625')]
# near prob : [Decimal('0.3742680794811848130898401741'), Decimal('0.5263118783037475294779704575'), Decimal('0.02652930360833580382564958306'), Decimal('0.07289073860673185360653978533')]
# driver is repostioning to zone  255 and arrived at zone  255
# reposition trip duration  4.316148263348888 min
# After repositioning, it is now  2013-06-03 06:41:51.168150
# fuel cost from  255 to  255  is 0.0962161849779874
# ************************reposition is completed.**************************
# Debug  13 06:41:51.168150
# current time is  2013-06-03 06:41:51.168150 and driver is at zone  255
# driver waited for  11  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 06:52:51.168150
# driver is going to zone 112 and driver arrived at zone 112
# trip duration  4.881700895208
# driver drops off passenger at time  2013-06-03 06:57:44.070204
# trip fare from  255 to  112  is 5.917588204318062
# driver total fare earned is  53.75631407735494
# fuel cost from  255 to  112  is 0.1324051005919638
# ************************trip is completed.**************************
# Debug  13 06:57:44.070204
# current time is  2013-06-03 06:57:44.070204 and driver is at zone  112
# driver does not get a pick up at the current zone: zone  112
# driver now decides to check reposition info after  6  min of crusing and current time is  2013-06-03 07:03:44.070204
# Debug  14 07:03:44.070204
# a_arr:  [Decimal('3.3655078125000006394884621840901672840118408203125')
#  Decimal('3.5506884765625006394884621840901672840118408203125')
#  Decimal('2.152668457031249094058011905872263014316558837890625')]
# near prob : [Decimal('0.3998740188366020969697191842'), Decimal('0.4812227249916708885229794014'), Decimal('0.1189032561717270145073014144')]
# driver is repostioning to zone  255 and arrived at zone  255
# reposition trip duration  4.891414141414143 min
# After repositioning, it is now  2013-06-03 07:08:37.555052
# fuel cost from  112 to  255  is 0.12397591587271395
# ************************reposition is completed.**************************
# Debug  14 07:08:37.555052
# current time is  2013-06-03 07:08:37.555052 and driver is at zone  255
# driver does not get a pick up at the current zone: zone  255
# driver now decides to check reposition info after  10  min of crusing and current time is  2013-06-03 07:18:37.555052
# Debug  14 07:18:37.555052
# a_arr:  [Decimal('3.5506884765625006394884621840901672840118408203125')
#  Decimal('5.66912841796875')
#  Decimal('2.152668457031249094058011905872263014316558837890625')
#  Decimal('3.3655078125000006394884621840901672840118408203125')]
# near prob : [Decimal('0.09618908086700208200748075970'), Decimal('0.8001152566752392162751907839'), Decimal('0.02376694684036393282271103847'), Decimal('0.07992871561739476889461741825')]
# driver is repostioning to zone  112 and arrived at zone  112
# reposition trip duration  4.881700895208 min
# After repositioning, it is now  2013-06-03 07:23:30.457106
# fuel cost from  255 to  112  is 0.1324051005919638
# ************************reposition is completed.**************************
# Debug  14 07:23:30.457106
# current time is  2013-06-03 07:23:30.457106 and driver is at zone  112
# driver waited for  17  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 07:40:30.457106
# driver is going to zone 255 and driver arrived at zone 255
# trip duration  4.891414141414143
# driver drops off passenger at time  2013-06-03 07:45:23.941954
# trip fare from  112 to  255  is 5.803030303030303
# driver total fare earned is  59.55934438038525
# fuel cost from  112 to  255  is 0.12397591587271395
# ************************trip is completed.**************************
# Debug  15 07:45:23.941954
# current time is  2013-06-03 07:45:23.941954 and driver is at zone  255
# driver waited for  15  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 08:00:23.941954
# driver is going to zone 107 and driver arrived at zone 107
# trip duration  15.122562358276642
# driver drops off passenger at time  2013-06-03 08:15:31.295695
# trip fare from  255 to  107  is 14.989795918367347
# driver total fare earned is  74.54914029875259
# fuel cost from  255 to  107  is 0.4425116347202248
# ************************trip is completed.**************************
# Debug  16 08:15:31.295695
# current time is  2013-06-03 08:15:31.295695 and driver is at zone  107
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 08:19:31.295695
# driver is going to zone 186 and driver arrived at zone 186
# trip duration  9.999026059489342
# driver drops off passenger at time  2013-06-03 08:29:31.237259
# trip fare from  107 to  186  is 8.319557778362727
# driver total fare earned is  82.86869807711531
# fuel cost from  107 to  186  is 0.14806886955820234
# ************************trip is completed.**************************
# Debug  16 08:29:31.237259
# current time is  2013-06-03 08:29:31.237259 and driver is at zone  186
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 08:30:31.237259
# driver is going to zone 4 and driver arrived at zone 4
# trip duration  13.652305665349145
# driver drops off passenger at time  2013-06-03 08:44:10.375599
# trip fare from  186 to  4  is 12.007905138339922
# driver total fare earned is  94.87660321545523
# fuel cost from  186 to  4  is 0.29434495480614264
# ************************trip is completed.**************************
# Debug  17 08:44:10.375599
# current time is  2013-06-03 08:44:10.375599 and driver is at zone  4
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 08:47:10.375599
# driver is going to zone 255 and driver arrived at zone 255
# trip duration  14.067615176151763
# driver drops off passenger at time  2013-06-03 09:01:14.432510
# trip fare from  4 to  255  is 13.621951219512194
# driver total fare earned is  108.49855443496743
# fuel cost from  4 to  255  is 0.37795461776737793
# ************************trip is completed.**************************
# Debug  18 09:01:14.432510
# current time is  2013-06-03 09:01:14.432510 and driver is at zone  255
# driver does not get a pick up at the current zone: zone  255
# driver now decides to check reposition info after  10  min of crusing and current time is  2013-06-03 09:11:14.432510
# Debug  18 09:11:14.432510
# a_arr:  [Decimal('6.7338427734374999289457264239899814128875732421875')
#  Decimal('7.0233154296875')
#  Decimal('3.177207031250004920508445138693787157535552978515625')
#  Decimal('2.339599609375')]
# near prob : [Decimal('0.4207681390124624006292280705'), Decimal('0.5620296460788505139186877004'), Decimal('0.01200647636269056842556820836'), Decimal('0.005195738545996517026516020989')]
# driver is repostioning to zone  255 and arrived at zone  255
# reposition trip duration  4.316148263348888 min
# After repositioning, it is now  2013-06-03 09:15:33.401406
# fuel cost from  255 to  255  is 0.0962161849779874
# ************************reposition is completed.**************************
# Debug  18 09:15:33.401406
# current time is  2013-06-03 09:15:33.401406 and driver is at zone  255
# driver waited for  18  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 09:33:33.401406
# driver is going to zone 246 and driver arrived at zone 246
# trip duration  25.18858024691358
# driver drops off passenger at time  2013-06-03 09:58:44.716221
# trip fare from  255 to  246  is 22.37037037037037
# driver total fare earned is  130.8689248053378
# fuel cost from  255 to  246  is 0.6706543865130163
# ************************trip is completed.**************************
# Debug  19 09:58:44.716221
# current time is  2013-06-03 09:58:44.716221 and driver is at zone  246
# driver does not get a pick up at the current zone: zone  246
# driver now decides to check reposition info after  6  min of crusing and current time is  2013-06-03 10:04:44.716221
# Debug  20 10:04:44.716221
# a_arr:  [Decimal('184.7145499420165606352384202182292938232421875')
#  Decimal('379.26822052001961083078640513122081756591796875')
#  Decimal('149.60278461456294962772517465054988861083984375')
#  Decimal('336.12564180374141642460017465054988861083984375')
#  Decimal('152.486197738647433652658946812152862548828125')]
# near prob : [Decimal('3.209330429652177446543179846E-85'), Decimal('0.9999999999999999998165929067'), Decimal('1.809541311223108465014998834E-100'), Decimal('1.834070934576001940538116557E-19'), Decimal('3.234587554366102106751817952E-99')]
# driver is repostioning to zone  48 and arrived at zone  48
# reposition trip duration  7.274538606403023 min
# After repositioning, it is now  2013-06-03 10:12:01.188537
# fuel cost from  246 to  48  is 0.14842071752753042
# ************************reposition is completed.**************************
# Debug  20 10:12:01.188537
# current time is  2013-06-03 10:12:01.188537 and driver is at zone  48
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 10:15:01.188537
# driver is going to zone 24 and driver arrived at zone 24
# trip duration  10.998525073746316
# driver drops off passenger at time  2013-06-03 10:26:01.100041
# trip fare from  48 to  24  is 12.070796460176991
# driver total fare earned is  142.93972126551478
# fuel cost from  48 to  24  is 0.37661192114160735
# ************************trip is completed.**************************
# Debug  20 10:26:01.100041
# current time is  2013-06-03 10:26:01.100041 and driver is at zone  24
# driver waited for  2  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 10:28:01.100041
# driver is going to zone 142 and driver arrived at zone 142
# trip duration  10.2141134751773
# driver drops off passenger at time  2013-06-03 10:38:13.946850
# trip fare from  24 to  142  is 10.117021276595745
# driver total fare earned is  153.05674254211053
# fuel cost from  24 to  142  is 0.25484700386361564
# ************************trip is completed.**************************
# Debug  21 10:38:13.946850
# current time is  2013-06-03 10:38:13.946850 and driver is at zone  142
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 10:42:13.946850
# driver is going to zone 226 and driver arrived at zone 226
# trip duration  16.355456349206342
# driver drops off passenger at time  2013-06-03 10:58:35.274231
# trip fare from  142 to  226  is 16.071428571428573
# driver total fare earned is  169.1281711135391
# fuel cost from  142 to  226  is 0.538869273905593
# ************************trip is completed.**************************
# Debug  21 10:58:35.274231
# current time is  2013-06-03 10:58:35.274231 and driver is at zone  226
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 10:59:35.274231
# driver is going to zone 7 and driver arrived at zone 7
# trip duration  7.998158914728682
# driver drops off passenger at time  2013-06-03 11:07:35.163766
# trip fare from  226 to  7  is 7.829457364341085
# driver total fare earned is  176.9576284778802
# fuel cost from  226 to  7  is 0.17872383041077175
# ************************trip is completed.**************************
# Debug  22 11:07:35.163766
# current time is  2013-06-03 11:07:35.163766 and driver is at zone  7
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 11:08:35.163766
# driver is going to zone 223 and driver arrived at zone 223
# trip duration  6.534300685207572
# driver drops off passenger at time  2013-06-03 11:15:07.221807
# trip fare from  7 to  223  is 7.311970979443773
# driver total fare earned is  184.26959945732398
# fuel cost from  7 to  223  is 0.17794754125283047
# ************************trip is completed.**************************
# Debug  22 11:15:07.221807
# current time is  2013-06-03 11:15:07.221807 and driver is at zone  223
# driver waited for  10  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 11:25:07.221807
# driver is going to zone 247 and driver arrived at zone 247
# trip duration  12.023015873015874
# driver drops off passenger at time  2013-06-03 11:37:08.602759
# trip fare from  223 to  247  is 17.029411764705884
# driver total fare earned is  201.29901122202986
# fuel cost from  223 to  247  is 0.5539336365103129
# ************************trip is completed.**************************
# Debug  23 11:37:08.602759
# current time is  2013-06-03 11:37:08.602759 and driver is at zone  247
# driver does not get a pick up at the current zone: zone  247
# driver now decides to check reposition info after  3  min of crusing and current time is  2013-06-03 11:40:08.602759
# Debug  23 11:40:08.602759
# a_arr:  [Decimal('2.09811035156250458300064565264619886875152587890625')
#  Decimal('1.000000000000003996802888650563545525074005126953125')
#  Decimal('1.93757812500000792255150372511707246303558349609375')
#  Decimal('1.9740234374999967581487680945429019629955291748046875')
#  Decimal('3.829003906250007194245199571014381945133209228515625')
#  Decimal('1.000000000000003996802888650563545525074005126953125')]
# near prob : [Decimal('0.1105254342406136412575414689'), Decimal('0.03686030832747956738594872072'), Decimal('0.09413344865441242799039684870'), Decimal('0.09762745494549638294474081481'), Decimal('0.6239930455045184130354234262'), Decimal('0.03686030832747956738594872072')]
# driver is repostioning to zone  168 and arrived at zone  168
# reposition trip duration  12.5 min
# After repositioning, it is now  2013-06-03 11:52:38.602759
# fuel cost from  247 to  168  is 0.179890598002075
# ************************reposition is completed.**************************
# Debug  23 11:52:38.602759
# current time is  2013-06-03 11:52:38.602759 and driver is at zone  168
# driver does not get a pick up at the current zone: zone  168
# driver now decides to check reposition info after  9  min of crusing and current time is  2013-06-03 12:01:38.602759
# Debug  24 12:01:38.602759
# a_arr:  [Decimal('1.8767236328124976552089719916693866252899169921875')
#  Decimal('1.8282128906250039168668308775522746145725250244140625')
#  Decimal('1.000000000000003996802888650563545525074005126953125')
#  Decimal('1.7999999999999964916952421845053322613239288330078125')
#  Decimal('0')
#  Decimal('1.93757812500000792255150372511707246303558349609375')]
# near prob : [Decimal('0.2216915353506801121155071666'), Decimal('0.2111937995182270624757532656'), Decimal('0.09225562922189041416321350269'), Decimal('0.2053186787171412780441992761'), Decimal('0.03393894932306869413238751066'), Decimal('0.2356014078689924390689392786')]
# driver is repostioning to zone  69 and arrived at zone  69
# reposition trip duration  9.305555555555555 min
# After repositioning, it is now  2013-06-03 12:10:56.936092
# fuel cost from  168 to  69  is 0.22824939970064842
# ************************reposition is completed.**************************
# Debug  24 12:10:56.936092
# current time is  2013-06-03 12:10:56.936092 and driver is at zone  69
# driver does not get a pick up at the current zone: zone  69
# driver now decides to check reposition info after  7  min of crusing and current time is  2013-06-03 12:17:56.936092
# Debug  24 12:17:56.936092
# a_arr:  [Decimal('1.000000000000003996802888650563545525074005126953125')
#  Decimal('1.93757812500000792255150372511707246303558349609375')
#  Decimal('1.93757812500000792255150372511707246303558349609375')
#  Decimal('1.8767236328124976552089719916693866252899169921875')
#  Decimal('2.437675781249999840127884453977458178997039794921875')
#  Decimal('1.8282128906250039168668308775522746145725250244140625')
#  Decimal('1.000000000000003108624468950438313186168670654296875')]
# near prob : [Decimal('0.06245818055376840637259718636'), Decimal('0.1595050122742204610422615186'), Decimal('0.1595050122742204610422615186'), Decimal('0.1500878597757092137528921572'), Decimal('0.2630049893467163658234802528'), Decimal('0.1429807652215967410679182815'), Decimal('0.06245818055376835089858908477')]
# driver is repostioning to zone  169 and arrived at zone  169
# reposition trip duration  4.941666666666666 min
# After repositioning, it is now  2013-06-03 12:22:53.436092
# fuel cost from  69 to  169  is 0.2413308435866742
# ************************reposition is completed.**************************
# Debug  24 12:22:53.436092
# current time is  2013-06-03 12:22:53.436092 and driver is at zone  169
# driver waited for  14  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 12:36:53.436092
# driver is going to zone 169 and driver arrived at zone 169
# trip duration  11.567094017094016
# driver drops off passenger at time  2013-06-03 12:48:27.461733
# trip fare from  169 to  169  is 9.474358974358974
# driver total fare earned is  210.77337019638884
# fuel cost from  169 to  169  is 0.21087342195230555
# ************************trip is completed.**************************
# Debug  25 12:48:27.461733
# current time is  2013-06-03 12:48:27.461733 and driver is at zone  169
# driver waited for  20  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 13:08:27.461733
# driver is going to zone 247 and driver arrived at zone 247
# trip duration  10.0
# driver drops off passenger at time  2013-06-03 13:18:27.461733
# trip fare from  169 to  247  is 9.0
# driver total fare earned is  219.77337019638884
# fuel cost from  169 to  247  is 0.17448970521101934
# ************************trip is completed.**************************
# Debug  26 13:18:27.461733
# current time is  2013-06-03 13:18:27.461733 and driver is at zone  247
# driver does not get a pick up at the current zone: zone  247
# driver now decides to check reposition info after  7  min of crusing and current time is  2013-06-03 13:25:27.461733
# Debug  26 13:25:27.461733
# a_arr:  [Decimal('1.59698730468750316191517413244582712650299072265625')
#  Decimal('1.554667968750000017763568394002504646778106689453125')
#  Decimal('1.554667968750000017763568394002504646778106689453125')
#  Decimal('1.5246826171875020872192862952942959964275360107421875')
#  Decimal('1.000000000000003996802888650563545525074005126953125')
#  Decimal('1.93757812500000792255150372511707246303558349609375')]
# near prob : [Decimal('0.1723062468980645625692008419'), Decimal('0.1651665011325723390269947214'), Decimal('0.1651665011325723390269947214'), Decimal('0.1602874412593082044076031047'), Decimal('0.09484899438152235352243098678'), Decimal('0.2422243151959602014467756237')]
# driver is repostioning to zone  168 and arrived at zone  168
# reposition trip duration  12.5 min
# After repositioning, it is now  2013-06-03 13:37:57.461733
# fuel cost from  247 to  168  is 0.179890598002075
# ************************reposition is completed.**************************
# Debug  27 13:37:57.461733
# current time is  2013-06-03 13:37:57.461733 and driver is at zone  168
# driver does not get a pick up at the current zone: zone  168
# driver now decides to check reposition info after  4  min of crusing and current time is  2013-06-03 13:41:57.461733
# Debug  27 13:41:57.461733
# a_arr:  [Decimal('2.207021484374995790034290621406398713588714599609375')
#  Decimal('1.4304687500000021760371282653068192303180694580078125')
#  Decimal('1.93757812500000792255150372511707246303558349609375')
#  Decimal('1.93757812500000792255150372511707246303558349609375')
#  Decimal('0')
#  Decimal('1.000000000000003996802888650563545525074005126953125')]
# near prob : [Decimal('0.2944022876371596454147714463'), Decimal('0.1354218096158320261366232812'), Decimal('0.2248658040790590536639800813'), Decimal('0.2248658040790590536639800813'), Decimal('0.03239245978264245355368357362'), Decimal('0.08805183480624776756696153664')]
# driver is repostioning to zone  69 and arrived at zone  69
# reposition trip duration  9.305555555555555 min
# After repositioning, it is now  2013-06-03 13:51:15.795066
# fuel cost from  168 to  69  is 0.22824939970064842
# ************************reposition is completed.**************************
# Debug  27 13:51:15.795066
# current time is  2013-06-03 13:51:15.795066 and driver is at zone  69
# driver does not get a pick up at the current zone: zone  69
# driver now decides to check reposition info after  5  min of crusing and current time is  2013-06-03 13:56:15.795066
# Debug  27 13:56:15.795066
# a_arr:  [Decimal('1.93757812500000792255150372511707246303558349609375')
#  Decimal('1.000000000000003996802888650563545525074005126953125')
#  Decimal('2.437675781249999840127884453977458178997039794921875')
#  Decimal('2.207021484374995790034290621406398713588714599609375')
#  Decimal('1.9633593750000069011463210699730552732944488525390625')
#  Decimal('1.4304687500000021760371282653068192303180694580078125')
#  Decimal('0')]
# near prob : [Decimal('0.1633427623949280605478317528'), Decimal('0.06396094768654861173502906537'), Decimal('0.2693329875407592907738524539'), Decimal('0.2138541389829674988921796460'), Decimal('0.1676086972696931917376330537'), Decimal('0.09837054843338008049067675632'), Decimal('0.02352991769172326582279727188')]
# driver is repostioning to zone  69 and arrived at zone  69
# reposition trip duration  8.25909090909091 min
# After repositioning, it is now  2013-06-03 14:04:31.340521
# fuel cost from  69 to  69  is 0.1473004464268975
# ************************reposition is completed.**************************
# Debug  28 14:04:31.340521
# current time is  2013-06-03 14:04:31.340521 and driver is at zone  69
# driver does not get a pick up at the current zone: zone  69
# driver now decides to check reposition info after  3  min of crusing and current time is  2013-06-03 14:07:31.340521
# Debug  28 14:07:31.340521
# a_arr:  [Decimal('0')
#  Decimal('2.437675781249999840127884453977458178997039794921875')
#  Decimal('1.000000000000003996802888650563545525074005126953125')
#  Decimal('1.815527343750001687538997430237941443920135498046875')
#  Decimal('1.93757812500000792255150372511707246303558349609375')
#  Decimal('2.26823242187500540012479177676141262054443359375')
#  Decimal('1.000000000000003996802888650563545525074005126953125')]
# near prob : [Decimal('0.02461144074859588075222705961'), Decimal('0.2817125393869681773649897149'), Decimal('0.06690083215910493116486797907'), Decimal('0.1512204566136064207747384821'), Decimal('0.1708506069194127442064102743'), Decimal('0.2378032920132069145718985114'), Decimal('0.06690083215910493116486797907')]
# driver is repostioning to zone  159 and arrived at zone  159
# reposition trip duration  6.441666666666666 min
# After repositioning, it is now  2013-06-03 14:13:57.840521
# fuel cost from  69 to  159  is 0.07715119829506256
# ************************reposition is completed.**************************
# Debug  28 14:13:57.840521
# current time is  2013-06-03 14:13:57.840521 and driver is at zone  159
# driver does not get a pick up at the current zone: zone  159
# driver now decides to check reposition info after  9  min of crusing and current time is  2013-06-03 14:22:57.840521
# Debug  28 14:22:57.840521
# a_arr:  [Decimal('2.437675781249999840127884453977458178997039794921875')
#  Decimal('1.000000000000003996802888650563545525074005126953125')
#  Decimal('1.815527343750001687538997430237941443920135498046875')
#  Decimal('0') Decimal('0')]
# near prob : [Decimal('0.5130845947826085798651066195'), Decimal('0.1218468529433218010108454178'), Decimal('0.2754186479354937050636555594'), Decimal('0.04482495216928795703019620165'), Decimal('0.04482495216928795703019620165')]
# driver is repostioning to zone  159 and arrived at zone  159
# reposition trip duration  9.037179487179488 min
# After repositioning, it is now  2013-06-03 14:32:00.071290
# fuel cost from  159 to  159  is 0.14698646551263828
# ************************reposition is completed.**************************
# Debug  29 14:32:00.071290
# current time is  2013-06-03 14:32:00.071290 and driver is at zone  159
# driver does not get a pick up at the current zone: zone  159
# driver now decides to check reposition info after  10  min of crusing and current time is  2013-06-03 14:42:00.071290
# Debug  29 14:42:00.071290
# a_arr:  [Decimal('0')
#  Decimal('1.000000000000003108624468950438313186168670654296875')
#  Decimal('1.4545312500000024957813593573519028723239898681640625')
#  Decimal('0') Decimal('0')]
# near prob : [Decimal('0.09999242644292558691899315662'), Decimal('0.2718075957833331939566157128'), Decimal('0.4282151248878900452864048174'), Decimal('0.09999242644292558691899315662'), Decimal('0.09999242644292558691899315662')]
# driver is repostioning to zone  168 and arrived at zone  168
# reposition trip duration  9.333333333333334 min
# After repositioning, it is now  2013-06-03 14:51:20.071290
# fuel cost from  159 to  168  is 0.18718412090655562
# ************************reposition is completed.**************************
# Debug  29 14:51:20.071290
# current time is  2013-06-03 14:51:20.071290 and driver is at zone  168
# driver does not get a pick up at the current zone: zone  168
# driver now decides to check reposition info after  6  min of crusing and current time is  2013-06-03 14:57:20.071290
# Debug  29 14:57:20.071290
# a_arr:  [Decimal('1.4545312500000024957813593573519028723239898681640625')
#  Decimal('1.63007812500000337507799486047588288784027099609375')
#  Decimal('0')
#  Decimal('2.80863281249999996447286321199499070644378662109375')
#  Decimal('0') Decimal('0')]
# near prob : [Decimal('0.1478042189235118212805075860'), Decimal('0.1761675318723611013711567375'), Decimal('0.03451373300401908715717106827'), Decimal('0.5724870501920698158768224716'), Decimal('0.03451373300401908715717106827'), Decimal('0.03451373300401908715717106827')]
# driver is repostioning to zone  247 and arrived at zone  247
# reposition trip duration  8.683333333333334 min
# After repositioning, it is now  2013-06-03 15:06:01.071290
# fuel cost from  168 to  247  is 0.21159877577985278
# ************************reposition is completed.**************************
# Debug  30 15:06:01.071290
# current time is  2013-06-03 15:06:01.071290 and driver is at zone  247
# driver waited for  28  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 15:34:01.071290
# driver is going to zone 20 and driver arrived at zone 20
# trip duration  20.27333333333333
# driver drops off passenger at time  2013-06-03 15:54:17.471290
# trip fare from  247 to  20  is 16.4
# driver total fare earned is  236.17337019638884
# fuel cost from  247 to  20  is 0.4192493361327299
# ************************trip is completed.**************************
# Debug  31 15:54:17.471290
# current time is  2013-06-03 15:54:17.471290 and driver is at zone  20
# driver does not get a pick up at the current zone: zone  20
# driver now decides to check reposition info after  5  min of crusing and current time is  2013-06-03 15:59:17.471290
# Debug  31 15:59:17.471290
# a_arr:  [Decimal('0')
#  Decimal('1.000000000000003996802888650563545525074005126953125')
#  Decimal('0') Decimal('0') Decimal('0') Decimal('0') Decimal('0')]
# near prob : [Decimal('0.1147014996390347908967417283'), Decimal('0.3117910021657912546195496301'), Decimal('0.1147014996390347908967417283'), Decimal('0.1147014996390347908967417283'), Decimal('0.1147014996390347908967417283'), Decimal('0.1147014996390347908967417283'), Decimal('0.1147014996390347908967417283')]
# driver is repostioning to zone  94 and arrived at zone  94
# reposition trip duration  6.066666666666666 min
# After repositioning, it is now  2013-06-03 16:05:21.471290
# fuel cost from  20 to  94  is 0.13706521314820141
# ************************reposition is completed.**************************
# total fare earned from this shift is  236.17337019638884
# total fuel cost is  15.319817448368752
# profit is  220.8535527480201

# %%
'''TODO: 
Monte Carlo Simulation'''
# Out:
# 'TODO: \nMonte Carlo Simulation'
