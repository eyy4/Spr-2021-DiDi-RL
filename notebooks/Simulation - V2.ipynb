# %%
import numpy as np
import pandas as pd 
import datetime as dt
from datetime import timedelta 
import random

# %%
class Driver: 
    

    
    def __init__(self, time, location, total_fare, total_cost, is_idle ):
        self.time = time 
        self.location = location 
        self.total_fare = total_fare
        self.total_cost  = total_cost
        self.is_idle = is_idle
    
    def set_time(self, new_time):
        self.time = new_time
    
    def get_time(self):
        return self.__time 
    
    def set_location(self, new_location):
        self.location = new_location
        
    def get_location(self):
        return self.__location 
   
    def set_total_fare(self, new_fare):
        self.total_fare = new_fare
    
    def get_total_fare(self):
        return self.total_fare 
    
    def set_is_idle(self, is_idle):
        self.is_idle = is_idle 
        
    def set_total_cost(self, new_cost):
        self.total_cost = new_cost
    
    def get_total_cost(self):
        return self.total_cost 
    
    def get_shift_time_weekday(self):


        weekend = [5,6]
        weekend_ind = lambda n: 0 if n in weekend else 1
        weekday = weekend_ind(self.time.weekday)

        normtime = driver.time.time()
        roundtime = pd.Timestamp(driver.time).round('30min').time()
        
        
        if weekday:
            if (normtime > dt.time(23, 30)) | (normtime <= dt.time(11, 30)):
                return ('A', roundtime,weekday)
            else:
                return ('B', roundtime,weekday)
        else: ## weekend
            if (normtime > dt.time(2, 0)) & (normtime <= dt.time(14, 0)):
                return ('A', roundtime,weekday)
            else:
                return ('B', roundtime,weekday)

# %%
class Env: 
    
    
    arrivals = pd.read_csv('../data/arrival_rates.csv')[['taxi_zone', 'time_stamp','arr_weekday','arr_weekend']]
    dropoff_counts = pd.read_csv('../data/pickup_dropoff_summary.csv')
    fare_df = pd.read_csv('../data/fare_amount_scr_dst_t.csv')
    dist_df = pd.read_csv('../data/trip_distance_scr_dst.csv')
    trip_time_df = pd.read_csv('../data/trip_time_scr_dst_t.csv')
    prob_df = pd.read_csv('../data/prob_match_combined_new.csv')
    trans_matrix = pd.read_csv('../data/dropoff_after_pickup.csv') # fix this to shift based and a
     # 0 weekend , A night shift 
    
    #time in 1..48,  isWeekday is a boolean
    def __init__(self,  isWeekday):   

        self.isWeekday = isWeekday 
        
    
    def is_matched(self, matching_prob):
        n = random.random()

        if n <= matching_prob:
            return True 
        else: 
            False 
    
    def get_destination(self, zone):
        prob = self.trans_matrix.iloc[zone-1].values[1:]
        n = random.random()

        count = 0
        for i in range(len(prob)):
            count = count + prob[i]
            if n<count:
                return i+1

    def get_adjacent_zone( self, taxi_zone ):
        df = pd.read_csv('../data/adjacent_zone.csv')
        adj_zone_1 = df.loc[df["zone1"]==taxi_zone, "zone2"].values.tolist()
        adj_zone_2 = df.loc[df["zone2"]==taxi_zone, "zone1"].values.tolist()
        adj_zone_list = list(filter(None, adj_zone_1+adj_zone_2))
        return(adj_zone_list)
    
    def get_demand(self, zone, time):
        #row = self.arrivals.loc[ ( self.arrivals['taxi_zone'] == zone ) & (self.arrivals['time_stamp'] == time ) ]
        row = self.prob_df.loc[ ( self.arrivals['taxi_zone'] == zone ) & (self.arrivals['time_stamp'] == time ) ]
       
        if self.isWeekday:
            return row['arr_weekday'].values[0]
        else:
            return row['arr_weekend'].values[0]
    
     #  def get_near_arrival():
    
    
    '''TODO： 
        fix policy fucntion - add randomness'''
   
       
            
    def reposition_to( self, current_zone, time ):
        #adj = self.get_adjacent_zone( current_zone )
        #adj.append( current_zone )
        #demand_list = [self.get_demand(zone, time) for zone in adj]
        #print(demand_list)
        # find the index of the max value of demand_lisy, and find which zone it is
        #return adj[demand_list.index( max(demand_list))]  
    
         
        adj = self.get_adjacent_zone( current_zone )
        adj.insert(0,current_zone)
        # find the index of the max value of near_prob, and find which zone it is 
        demand_list = [self.get_demand(zone, time) for zone in adj]
        a_arr  = np.array(demand_list)
        print("a_arr: ", a_arr)
        #near_prob = list(np.exp((a_arr-a_arr[0])*10)/np.sum(np.exp((a_arr-a_arr[0])*10))) 
        near_prob = list(np.exp((a_arr-a_arr[0]))/np.sum(np.exp((a_arr-a_arr[0]))))
        print("near prob :", near_prob)  
        
        # 20, 28, 52
        
        r = random.random()
        #25
        
        count = 0
        for i in range(len(near_prob)):
            count = count + near_prob[i]
            if r < count:
                return(adj[i])  
        
        #repo_zone = adj[r_index]   
        
        #repo_prob = near_prob.index( max(near_prob))
        
    
        #print("r, repo, repo_prob", r, repo, repo_prob)
            
      
            
          
        #return (adj[near_prob.index( max(near_prob))],  is_repositioned)
    
        #SOFTMAX 
        #NEAR ARRIVAL 
        # return the highest prob of near arrival 
        
        
        ### paper's calculation of nearest prob
        # zone 1 = 10 , zone2 = 10.1 , zone 3 = 5
        # p(zone 1) = 10/25.5 = 0.392
        # p(zone 2) = 10.1/25.5 = 0.396
        # p(zone 3) = 5/25.5 = 0.196 
        
        
        # softmax suggestion way 
        # zone 1 = 10 , zone2 = 10.1 , zone 3 = 5
        # B  = 10 
        #exp(B * (rho1 - rho1) - e) / exp(B * (rho1 - rho1)) + exp(B * (rho2 - rho1)) + exp(B * (rho3 - rho1) - e) = 0.27
        #exp(B * (rho2 - rho1) - e) / exp(10) + exp(10.2) + exp(5)  = 0.73
        #exp(B * (rho3 - rho1) - e) / exp(10) + exp(10.2) + exp(5)  = 0.0
        
        
     
    def wait_time_before_pickup(self, matching_prob):
        if ( matching_prob >= 0.9 ):
            return random.randint(1,4)
        elif ( matching_prob >= 0.7 ):
            return random.randint(5,10)
        elif ( matching_prob >= 0.5 ):
            return random.randint(11,15)
        elif ( matching_prob >= 0.3 ):
            return random.randint(16,20)
        else:
            return random.randint(21,29)
        
    def wait_time_before_reposition(self):
        return random.randint(1,10)
    
    # can look into histortical data combined with random number 

    
    
    def get_trip_duration(self, start_zone, end_zone, shift_time):    
        shift,roundtime,weekday_ind = shift_time
        roundtime = roundtime.strftime('%H:%M:%S') 
        
        zone_to_zone = self.trip_time_df[(self.trip_time_df["pickup_taxizone_id"] == start_zone) & 
                                        (self.trip_time_df["dropoff_taxizone_id"] == end_zone) &
                                        (self.trip_time_df["actual_data"] == 1)]
        
        if len(zone_to_zone)!=0:
            if len(zone_to_zone[(zone_to_zone['_PU_shift']==shift) & (zone_to_zone['pickup_datetime_interval']==roundtime) &
                                (zone_to_zone['pickup_weekday'] == weekday_ind)])>0:

                dur = zone_to_zone.loc[(zone_to_zone["_PU_shift"] == shift) &
                                       (zone_to_zone["pickup_datetime_interval"] == roundtime) &
                                       (zone_to_zone['pickup_weekday'] == weekday_ind), "mean"].mean() 

            elif len(zone_to_zone[(zone_to_zone['_PU_shift']==shift) & (zone_to_zone['pickup_weekday'] == weekday_ind)])>0:
                dur = zone_to_zone.loc[(zone_to_zone["_PU_shift"] == shift) &
                                       (zone_to_zone['pickup_weekday'] == weekday_ind), "mean"].mean()

            else:
                dur = zone_to_zone['mean'].mean()
        else: 
            dur = self.trip_time_df.loc[(self.trip_time_df["pickup_taxizone_id"] == start_zone) & 
                                    (self.trip_time_df["dropoff_taxizone_id"] == end_zone) &
                                    (self.trip_time_df["actual_data"] == 0),"mean"].mean()
        
        return dur
        
    def get_fare(self, start_zone, end_zone, shift_time): 
        
        shift,roundtime,weekday_ind = shift_time
        roundtime = roundtime.strftime('%H:%M:%S') 
        
        zone_to_zone = self.fare_df[(self.fare_df["pickup_taxizone_id"] == start_zone) & 
                                    (self.fare_df["dropoff_taxizone_id"] == end_zone) &
                                    (self.fare_df["actual_data"] == 1)]
                
        if len(zone_to_zone)!=0:
            if len(zone_to_zone[(zone_to_zone['_PU_shift']==shift) & (zone_to_zone['pickup_datetime_interval']==roundtime) &
                                (zone_to_zone['pickup_weekday'] == weekday_ind)])>0:

                fare = zone_to_zone.loc[(zone_to_zone["_PU_shift"] == shift) &
                                       (zone_to_zone["pickup_datetime_interval"] == roundtime) &
                                       (zone_to_zone['pickup_weekday'] == weekday_ind), "mean"].mean() 

            elif len(zone_to_zone[(zone_to_zone['_PU_shift']==shift) & (zone_to_zone['pickup_weekday'] == weekday_ind)])>0:
                fare = zone_to_zone.loc[(zone_to_zone["_PU_shift"] == shift) &
                                       (zone_to_zone['pickup_weekday'] == weekday_ind), "mean"].mean()

            else:
                fare = zone_to_zone['mean'].mean()
        else:
            dur = self.fare_df.loc[(self.fare_df["pickup_taxizone_id"] == start_zone) & 
                                    (self.fare_df["dropoff_taxizone_id"] == end_zone) &
                                    (self.fare_df["actual_data"] == 0),"mean"].mean()
        
        return fare
    
    def get_trip_distance(self, start_zone, end_zone):
        zone_to_zone = self.dist_df.loc[((self.dist_df["pickup_taxizone_id"] == start_zone) &
                                 (self. dist_df["dropoff_taxizone_id"] == end_zone) &
                                 (self.trip_time_df["actual_data"] == 1)), "mean"]
        if len(zone_to_zone) != 0:
            dist = zone_to_zone.mean()
        else:
            dist = self.dist_df.loc[((self.dist_df["pickup_taxizone_id"] == start_zone) &
                                 (self. dist_df["dropoff_taxizone_id"] == end_zone) &
                                 (self.trip_time_df["actual_data"] == 0)), "mean"]
        
        return dist 
    
    def get_fuel_cost(self, start_zone, end_zone): 
        
        cost = self.dist_df.loc[((self.dist_df["pickup_taxizone_id"] == start_zone) &
                                 (self. dist_df["dropoff_taxizone_id"] == end_zone)), "mean"].mean()*0.124
        return cost 
    
    def get_matching_prob(self, zone, time):
        if self.isWeekday:
            prob = self.prob_df.loc[(self.prob_df['taxi_zone'] == zone) & 
                                    (self.prob_df['time_stamp'] == time)].mod_prob_match_weekday.values[0]
        else: 
            prob = self.prob_df.loc[(self.prob_df['taxi_zone'] == zone) & 
                                    (self.prob_df['time_stamp'] == time)].mod_prob_match_weekend.values[0]
            
        return prob 
    
    
    time_bins = [dt.time(0,0),dt.time(0,30), dt.time(1,0), dt.time(1,30), dt.time(2,0), 
        dt.time(2,30), dt.time(3,0), dt.time(3,30), dt.time(4,0),
        dt.time(4,30), dt.time(5,0), dt.time(5,30), dt.time(6,0),
        dt.time(6,30), dt.time(7,0), dt.time(7,30), dt.time(8,0),
        dt.time(8,30), dt.time(9,0), dt.time(9,30), dt.time(10,0),
        dt.time(10,30), dt.time(11,0), dt.time(11,30), dt.time(12,0),
        dt.time(12,30), dt.time(13,0), dt.time(13,30), dt.time(14,0),
        dt.time(14,30), dt.time(15,0), dt.time(15,30), dt.time(16,0), 
        dt.time(16,30), dt.time(17,0), dt.time(17,30), dt.time(18,0),
        dt.time(18,30), dt.time(19,0), dt.time(19,30), dt.time(20,0),
        dt.time(20,30), dt.time(21,0), dt.time(21,30), dt.time(22,0),
        dt.time(22,30), dt.time(23,0), dt.time(23,30), dt.time(23,59,59)] 
    
    
    def get_time_window(self, datetime):
        for i in range(0,48):
            if (datetime.time() >= self.time_bins[i]) & (datetime.time() < self.time_bins[i+1]): 
                return i+1 
    
     
    def reposition_to_high( self, current_zone, time ):
        #adj = self.get_adjacent_zone( current_zone )
        #adj.append( current_zone )
        #demand_list = [self.get_demand(zone, time) for zone in adj]
        #print(demand_list)
        # find the index of the max value of demand_lisy, and find which zone it is
        #return adj[demand_list.index( max(demand_list))]  
    
         
        adj = self.get_adjacent_zone( current_zone )
        adj.insert(0,current_zone)
        # find the index of the max value of near_prob, and find which zone it is 
        demand_list = [self.get_demand(zone, time) for zone in adj]
        a_arr  = np.array(demand_list)
        print("a_arr: ", a_arr)
        #near_prob = list(np.exp((a_arr-a_arr[0])*10)/np.sum(np.exp((a_arr-a_arr[0])*10))) 
        near_prob = list(np.exp((a_arr-a_arr[0]))/np.sum(np.exp((a_arr-a_arr[0]))))
        print("near prob :", near_prob) 
        
        return(adj[near_prob.index( max(near_prob))])
    
    def reposition_to_any( self, current_zone, time ):
        #adj = self.get_adjacent_zone( current_zone )
        #adj.append( current_zone )
        #demand_list = [self.get_demand(zone, time) for zone in adj]
        #print(demand_list)
        # find the index of the max value of demand_lisy, and find which zone it is
        #return adj[demand_list.index( max(demand_list))]  
    
         
        adj = self.get_adjacent_zone( current_zone )
        adj.insert(0,current_zone)
        # find the index of the max value of near_prob, and find which zone it is 
        r = random.randint(0,len(adj)-1) 
        
        
        return(adj[r])

# %%
# one round of simulation 
#random.seed(500)
init_time = dt.datetime(2013, 6, 3, 5, 0, 0) 
init_zone = 12
avg_speed_waiting = 10 # defined in mph

#Initialize enviorment and driver 
env = Env( isWeekday = False ) 
driver = Driver( time = init_time, location = init_zone, total_fare = 0, total_cost = 0, is_idle = True) 

# print(driver.location)
# print(driver.time)
# print(driver.total_fare)
# print(driver.total_cost)
# print(driver.is_idle)


while driver.time < init_time + timedelta(seconds=0, minutes=0, hours = 11):
    #get prob that driver will be matched to a passenger 
    matching_prob = env.get_matching_prob( zone = driver.location, time = env.get_time_window(driver.time) )
    #print(matching_prob)
    start_zone = driver.location
    print('current time is ', driver.time, 'and driver is at zone ', driver.location)
    if env.is_matched(matching_prob):

        # time it takes before getting matched 
        wait_time = env.wait_time_before_pickup(matching_prob)
        print('driver waited for ', wait_time, ' min before he picks up')

        # cost of cruising
        driver.set_total_cost(driver.total_cost + avg_speed_waiting * wait_time/60 * 0.124)

        # set driver time to new time 
        driver.set_time( driver.time + timedelta(seconds=0, minutes= wait_time, hours=0 ) )
        print('driver gets a pick up and is now at time ', driver.time)    


        #driver is now busy 
        driver.set_is_idle(False)


        # find the destination of the trip and set destination 
        dest = env.get_destination(driver.location)
        driver.set_location(dest)
        print ('driver is going to zone', dest, 'and driver arrived at zone', driver.location)    

         # find the trip duration and update new time 
        duration = env.get_trip_duration(start_zone = start_zone, end_zone = dest, shift_time=driver.get_shift_time_weekday())
        print ('trip duration ', duration)
        driver.set_time( driver.time + timedelta(seconds=0, minutes= duration, hours=0 ) )
        print ('driver drops off passenger at time ', driver.time)


        #find trip fare and update fare 
        fare = env.get_fare( start_zone, dest, driver.get_shift_time_weekday())
        driver.set_total_fare(driver.total_fare + fare)
        print('trip fare from ', start_zone, 'to ', driver.location,   ' is',  fare)
        print('driver total fare earned is ', driver.total_fare )

        #frin trip cost and update cost 
        cost = env.get_fuel_cost(start_zone, dest)
        driver.set_total_cost(driver.total_cost + cost)
        print('fuel cost from ', start_zone, 'to ', driver.location,   ' is', cost  )

        print('************************trip is completed.************************** ')


    else: 
        #time it takes before reposition 
        print('driver does not get a pick up at the current zone: zone ', driver.location )
        
        wait_time = env.wait_time_before_reposition()
        driver.set_time( driver.time + timedelta(seconds=0, minutes= wait_time, hours=0 ) )
        print('driver now decides to check reposition info after ', wait_time, ' min of crusing and current time is ', driver.time)
       
        # cost of cruising
        driver.set_total_cost(driver.total_cost + avg_speed_waiting * wait_time/60 * 0.124)

        
        repo = env.reposition_to(driver.location, env.get_time_window(driver.time) ) #fix this to distribution 
        
        '''
            TODO:
            add cost - assume 10 miles a hour '''
                                                                       
                
        driver.set_location(repo)
        print('driver is repostioning to zone ', repo, 'and arrived at zone ', driver.location)

        # find the trip duration and update new time 
        duration = env.get_trip_duration(start_zone = start_zone, end_zone = repo, shift_time=driver.get_shift_time_weekday())
        print ('reposition trip duration ', duration , 'min')
        driver.set_time( driver.time + timedelta(seconds=0, minutes= duration, hours=0 ) )
        print ('After repositioning, it is now ', driver.time)

        #frin trip cost and update cost 
        cost = env.get_fuel_cost(start_zone, repo)
        driver.set_total_cost(driver.total_cost + cost)
        print('fuel cost from ', start_zone, 'to ', driver.location,   ' is', cost  )


        print('************************reposition is completed.************************** ')


        
print('total fare earned from this shift is ', driver.total_fare )
print('total fuel cost is ', driver.total_cost)
print('profit is ', driver.total_fare - driver.total_cost)
# Out:
# current time is  2013-06-03 05:00:00 and driver is at zone  12
# driver does not get a pick up at the current zone: zone  12
# driver now decides to check reposition info after  4  min of crusing and current time is  2013-06-03 05:04:00
# a_arr:  [1.43356445 9.17509094 6.14044189 9.        ]
# near prob : [0.00023010033613637168, 0.5296872129806424, 0.02547347259492599, 0.44460921408829523]
# driver is repostioning to zone  13 and arrived at zone  13
# reposition trip duration  5.317857142857141 min
# After repositioning, it is now  2013-06-03 05:09:19.071429
# fuel cost from  12 to  13  is 0.09376399918380383
# ************************reposition is completed.**************************
# current time is  2013-06-03 05:09:19.071429 and driver is at zone  13
# driver does not get a pick up at the current zone: zone  13
# driver now decides to check reposition info after  3  min of crusing and current time is  2013-06-03 05:12:19.071429
# a_arr:  [ 9.17509094 49.98118393  9.          1.43356445]
# near prob : [1.8973130230062517e-18, 1.0, 1.592567899254018e-18, 8.24207860131237e-22]
# driver is repostioning to zone  231 and arrived at zone  231
# reposition trip duration  5.96365466177844 min
# After repositioning, it is now  2013-06-03 05:18:16.890709
# fuel cost from  13 to  231  is 0.11366661753577893
# ************************reposition is completed.**************************
# current time is  2013-06-03 05:18:16.890709 and driver is at zone  231
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 05:21:16.890709
# driver is going to zone 87 and driver arrived at zone 87
# trip duration  8.302251002158505
# driver drops off passenger at time  2013-06-03 05:29:35.025769
# trip fare from  231 to  87  is 7.368246993524514
# driver total fare earned is  7.368246993524514
# fuel cost from  231 to  87  is 0.12114121561159089
# ************************trip is completed.**************************
# current time is  2013-06-03 05:29:35.025769 and driver is at zone  87
# driver does not get a pick up at the current zone: zone  87
# driver now decides to check reposition info after  7  min of crusing and current time is  2013-06-03 05:36:35.025769
# a_arr:  [15.9         8.05514648  4.33332275  9.39182495]
# near prob : [0.9981111362878023, 0.0003910230041799266, 9.45877291838147e-06, 0.001488381935099465]
# driver is repostioning to zone  87 and arrived at zone  87
# reposition trip duration  7.038592750533047 min
# After repositioning, it is now  2013-06-03 05:43:37.341334
# fuel cost from  87 to  87  is 0.13343121116748782
# ************************reposition is completed.**************************
# current time is  2013-06-03 05:43:37.341334 and driver is at zone  87
# driver does not get a pick up at the current zone: zone  87
# driver now decides to check reposition info after  6  min of crusing and current time is  2013-06-03 05:49:37.341334
# a_arr:  [15.9         8.05514648  4.33332275  9.39182495]
# near prob : [0.9981111362878023, 0.0003910230041799266, 9.45877291838147e-06, 0.001488381935099465]
# driver is repostioning to zone  87 and arrived at zone  87
# reposition trip duration  7.038592750533047 min
# After repositioning, it is now  2013-06-03 05:56:39.656899
# fuel cost from  87 to  87  is 0.13343121116748782
# ************************reposition is completed.**************************
# current time is  2013-06-03 05:56:39.656899 and driver is at zone  87
# driver waited for  8  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 06:04:39.656899
# driver is going to zone 163 and driver arrived at zone 163
# trip duration  22.03974358974359
# driver drops off passenger at time  2013-06-03 06:26:42.041514
# trip fare from  87 to  163  is 21.235294117647054
# driver total fare earned is  28.60354111117157
# fuel cost from  87 to  163  is 0.63525848883457
# ************************trip is completed.**************************
# current time is  2013-06-03 06:26:42.041514 and driver is at zone  163
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 06:30:42.041514
# driver is going to zone 229 and driver arrived at zone 229
# trip duration  7.687081048141374
# driver drops off passenger at time  2013-06-03 06:38:23.266377
# trip fare from  163 to  229  is 6.910877513711152
# driver total fare earned is  35.51441862488272
# fuel cost from  163 to  229  is 0.11987311879926713
# ************************trip is completed.**************************
# current time is  2013-06-03 06:38:23.266377 and driver is at zone  229
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 06:39:23.266377
# driver is going to zone 234 and driver arrived at zone 234
# trip duration  15.639414414414423
# driver drops off passenger at time  2013-06-03 06:55:01.631242
# trip fare from  229 to  234  is 12.027837837837838
# driver total fare earned is  47.54225646272056
# fuel cost from  229 to  234  is 0.26140853332618497
# ************************trip is completed.**************************
# current time is  2013-06-03 06:55:01.631242 and driver is at zone  234
# driver waited for  2  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 06:57:01.631242
# driver is going to zone 90 and driver arrived at zone 90
# trip duration  5.344627787824001
# driver drops off passenger at time  2013-06-03 07:02:22.308909
# trip fare from  234 to  90  is 5.577079566003617
# driver total fare earned is  53.11933602872418
# fuel cost from  234 to  90  is 0.08649877845530875
# ************************trip is completed.**************************
# current time is  2013-06-03 07:02:22.308909 and driver is at zone  90
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 07:03:22.308909
# driver is going to zone 79 and driver arrived at zone 79
# trip duration  8.94166050751417
# driver drops off passenger at time  2013-06-03 07:12:18.808539
# trip fare from  90 to  79  is 8.28048780487805
# driver total fare earned is  61.39982383360223
# fuel cost from  90 to  79  is 0.17990614296372814
# ************************trip is completed.**************************
# current time is  2013-06-03 07:12:18.808539 and driver is at zone  79
# driver waited for  2  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 07:14:18.808539
# driver is going to zone 138 and driver arrived at zone 138
# trip duration  21.505010087424345
# driver drops off passenger at time  2013-06-03 07:35:49.109144
# trip fare from  79 to  138  is 30.4724277067922
# driver total fare earned is  91.87225154039443
# fuel cost from  79 to  138  is 1.22763239731455
# ************************trip is completed.**************************
# current time is  2013-06-03 07:35:49.109144 and driver is at zone  138
# driver does not get a pick up at the current zone: zone  138
# driver now decides to check reposition info after  4  min of crusing and current time is  2013-06-03 07:39:49.109144
# a_arr:  [14.70579346  0.          9.30880371  0.          2.32119141  1.53023438
#   8.44478882]
# near prob : [0.9935948661123398, 4.0791003398176134e-07, 0.004501180960964564, 4.0791003398176134e-07, 4.1557078400350955e-06, 1.8842422320430072e-06, 0.0018970971565555157]
# driver is repostioning to zone  138 and arrived at zone  138
# reposition trip duration  10.164436619718312 min
# After repositioning, it is now  2013-06-03 07:49:58.975341
# fuel cost from  138 to  138  is 0.31844720101703594
# ************************reposition is completed.**************************
# current time is  2013-06-03 07:49:58.975341 and driver is at zone  138
# driver does not get a pick up at the current zone: zone  138
# driver now decides to check reposition info after  5  min of crusing and current time is  2013-06-03 07:54:58.975341
# a_arr:  [14.70579346  0.          9.30880371  0.          2.32119141  1.53023438
#   8.44478882]
# near prob : [0.9935948661123398, 4.0791003398176134e-07, 0.004501180960964564, 4.0791003398176134e-07, 4.1557078400350955e-06, 1.8842422320430072e-06, 0.0018970971565555157]
# driver is repostioning to zone  138 and arrived at zone  138
# reposition trip duration  10.164436619718312 min
# After repositioning, it is now  2013-06-03 08:05:08.841538
# fuel cost from  138 to  138  is 0.31844720101703594
# ************************reposition is completed.**************************
# current time is  2013-06-03 08:05:08.841538 and driver is at zone  138
# driver does not get a pick up at the current zone: zone  138
# driver now decides to check reposition info after  4  min of crusing and current time is  2013-06-03 08:09:08.841538
# a_arr:  [21.92438232  0.         14.57700806  0.          2.8061084   1.67548828
#   8.6       ]
# near prob : [0.9993544937489713, 3.006639142669736e-10, 0.0006438659650938215, 3.006639142669736e-10, 4.974606124319306e-09, 1.6059670191584156e-09, 1.6331040337049438e-06]
# driver is repostioning to zone  138 and arrived at zone  138
# reposition trip duration  10.164436619718312 min
# After repositioning, it is now  2013-06-03 08:19:18.707735
# fuel cost from  138 to  138  is 0.31844720101703594
# ************************reposition is completed.**************************
# current time is  2013-06-03 08:19:18.707735 and driver is at zone  138
# driver does not get a pick up at the current zone: zone  138
# driver now decides to check reposition info after  2  min of crusing and current time is  2013-06-03 08:21:18.707735
# a_arr:  [21.92438232  0.         14.57700806  0.          2.8061084   1.67548828
#   8.6       ]
# near prob : [0.9993544937489713, 3.006639142669736e-10, 0.0006438659650938215, 3.006639142669736e-10, 4.974606124319306e-09, 1.6059670191584156e-09, 1.6331040337049438e-06]
# driver is repostioning to zone  138 and arrived at zone  138
# reposition trip duration  10.164436619718312 min
# After repositioning, it is now  2013-06-03 08:31:28.573932
# fuel cost from  138 to  138  is 0.31844720101703594
# ************************reposition is completed.**************************
# current time is  2013-06-03 08:31:28.573932 and driver is at zone  138
# driver does not get a pick up at the current zone: zone  138
# driver now decides to check reposition info after  1  min of crusing and current time is  2013-06-03 08:32:28.573932
# a_arr:  [46.7449292   0.         14.39911621  0.          2.85445313  1.97408203
#  10.69950256]
# near prob : [0.9999999999999909, 4.9995992221736665e-21, 8.961731056794702e-15, 4.9995992221736665e-21, 8.68177313175344e-20, 3.599715058497553e-20, 2.2165121397141136e-16]
# driver is repostioning to zone  138 and arrived at zone  138
# reposition trip duration  10.164436619718312 min
# After repositioning, it is now  2013-06-03 08:42:38.440129
# fuel cost from  138 to  138  is 0.31844720101703594
# ************************reposition is completed.**************************
# current time is  2013-06-03 08:42:38.440129 and driver is at zone  138
# driver waited for  20  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 09:02:38.440129
# driver is going to zone 143 and driver arrived at zone 143
# trip duration  31.597038019451794
# driver drops off passenger at time  2013-06-03 09:34:14.262410
# trip fare from  138 to  143  is 33.94031830238727
# driver total fare earned is  125.8125698427817
# fuel cost from  138 to  143  is 1.2510473290632274
# ************************trip is completed.**************************
# current time is  2013-06-03 09:34:14.262410 and driver is at zone  143
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 09:38:14.262410
# driver is going to zone 68 and driver arrived at zone 68
# trip duration  11.955279503105585
# driver drops off passenger at time  2013-06-03 09:50:11.579180
# trip fare from  143 to  68  is 10.609316770186336
# driver total fare earned is  136.42188661296802
# fuel cost from  143 to  68  is 0.2641358082673419
# ************************trip is completed.**************************
# current time is  2013-06-03 09:50:11.579180 and driver is at zone  68
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 09:53:11.579180
# driver is going to zone 170 and driver arrived at zone 170
# trip duration  11.724665624457202
# driver drops off passenger at time  2013-06-03 10:04:55.059117
# trip fare from  68 to  170  is 9.49882751433038
# driver total fare earned is  145.9207141272984
# fuel cost from  68 to  170  is 0.206113367380038
# ************************trip is completed.**************************
# current time is  2013-06-03 10:04:55.059117 and driver is at zone  170
# driver waited for  2  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 10:06:55.059117
# driver is going to zone 239 and driver arrived at zone 239
# trip duration  17.80358829084042
# driver drops off passenger at time  2013-06-03 10:24:43.274414
# trip fare from  170 to  239  is 14.711756373937677
# driver total fare earned is  160.63247050123607
# fuel cost from  170 to  239  is 0.34872135530110404
# ************************trip is completed.**************************
# current time is  2013-06-03 10:24:43.274414 and driver is at zone  239
# driver waited for  2  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 10:26:43.274414
# driver is going to zone 79 and driver arrived at zone 79
# trip duration  19.931129943502818
# driver drops off passenger at time  2013-06-03 10:46:39.142211
# trip fare from  239 to  79  is 18.60338983050848
# driver total fare earned is  179.23586033174456
# fuel cost from  239 to  79  is 0.5386486402007158
# ************************trip is completed.**************************
# current time is  2013-06-03 10:46:39.142211 and driver is at zone  79
# driver waited for  2  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 10:48:39.142211
# driver is going to zone 239 and driver arrived at zone 239
# trip duration  18.543954248366017
# driver drops off passenger at time  2013-06-03 11:07:11.779466
# trip fare from  79 to  239  is 18.01388888888889
# driver total fare earned is  197.24974922063345
# fuel cost from  79 to  239  is 0.5297319302929598
# ************************trip is completed.**************************
# current time is  2013-06-03 11:07:11.779466 and driver is at zone  239
# driver waited for  2  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 11:09:11.779466
# driver is going to zone 229 and driver arrived at zone 229
# trip duration  16.241429418742587
# driver drops off passenger at time  2013-06-03 11:25:26.265231
# trip fare from  239 to  229  is 13.000889679715302
# driver total fare earned is  210.25063890034875
# fuel cost from  239 to  229  is 0.29253267658927096
# ************************trip is completed.**************************
# current time is  2013-06-03 11:25:26.265231 and driver is at zone  229
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 11:28:26.265231
# driver is going to zone 262 and driver arrived at zone 262
# trip duration  8.011136999068034
# driver drops off passenger at time  2013-06-03 11:36:26.933451
# trip fare from  229 to  262  is 8.31335710367526
# driver total fare earned is  218.563996004024
# fuel cost from  229 to  262  is 0.21204199827810916
# ************************trip is completed.**************************
# current time is  2013-06-03 11:36:26.933451 and driver is at zone  262
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 11:37:26.933451
# driver is going to zone 141 and driver arrived at zone 141
# trip duration  7.479832553558229
# driver drops off passenger at time  2013-06-03 11:44:55.723404
# trip fare from  262 to  141  is 6.962447672986949
# driver total fare earned is  225.52644367701095
# fuel cost from  262 to  141  is 0.1373820822203253
# ************************trip is completed.**************************
# current time is  2013-06-03 11:44:55.723404 and driver is at zone  141
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 11:45:55.723404
# driver is going to zone 262 and driver arrived at zone 262
# trip duration  5.952154545454545
# driver drops off passenger at time  2013-06-03 11:51:52.852677
# trip fare from  141 to  262  is 6.297
# driver total fare earned is  231.82344367701094
# fuel cost from  141 to  262  is 0.13388937020829209
# ************************trip is completed.**************************
# current time is  2013-06-03 11:51:52.852677 and driver is at zone  262
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 11:52:52.852677
# driver is going to zone 141 and driver arrived at zone 141
# trip duration  7.479832553558229
# driver drops off passenger at time  2013-06-03 12:00:21.642630
# trip fare from  262 to  141  is 6.962447672986949
# driver total fare earned is  238.78589134999788
# fuel cost from  262 to  141  is 0.1373820822203253
# ************************trip is completed.**************************
# current time is  2013-06-03 12:00:21.642630 and driver is at zone  141
# driver waited for  2  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 12:02:21.642630
# driver is going to zone 236 and driver arrived at zone 236
# trip duration  6.166329158533939
# driver drops off passenger at time  2013-06-03 12:08:31.622380
# trip fare from  141 to  236  is 6.383620689655173
# driver total fare earned is  245.16951203965306
# fuel cost from  141 to  236  is 0.11980936375379796
# ************************trip is completed.**************************
# current time is  2013-06-03 12:08:31.622380 and driver is at zone  236
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 12:12:31.622380
# driver is going to zone 237 and driver arrived at zone 237
# trip duration  7.828799404471105
# driver drops off passenger at time  2013-06-03 12:20:21.350344
# trip fare from  236 to  237  is 7.042505408611905
# driver total fare earned is  252.21201744826496
# fuel cost from  236 to  237  is 0.12481089372666046
# ************************trip is completed.**************************
# current time is  2013-06-03 12:20:21.350344 and driver is at zone  237
# driver waited for  2  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 12:22:21.350344
# driver is going to zone 236 and driver arrived at zone 236
# trip duration  5.923524514613623
# driver drops off passenger at time  2013-06-03 12:28:16.761815
# trip fare from  237 to  236  is 6.3003448993548
# driver total fare earned is  258.5123623476198
# fuel cost from  237 to  236  is 0.12266569258352837
# ************************trip is completed.**************************
# current time is  2013-06-03 12:28:16.761815 and driver is at zone  236
# driver waited for  2  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 12:30:16.761815
# driver is going to zone 141 and driver arrived at zone 141
# trip duration  8.031430919550719
# driver drops off passenger at time  2013-06-03 12:38:18.647670
# trip fare from  236 to  141  is 7.2253675463428
# driver total fare earned is  265.7377298939626
# fuel cost from  236 to  141  is 0.12215826862840826
# ************************trip is completed.**************************
# current time is  2013-06-03 12:38:18.647670 and driver is at zone  141
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 12:39:18.647670
# driver is going to zone 263 and driver arrived at zone 263
# trip duration  4.761951767119571
# driver drops off passenger at time  2013-06-03 12:44:04.364776
# trip fare from  141 to  263  is 5.707873649982581
# driver total fare earned is  271.44560354394514
# fuel cost from  141 to  263  is 0.12274754363944075
# ************************trip is completed.**************************
# current time is  2013-06-03 12:44:04.364776 and driver is at zone  263
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 12:45:04.364776
# driver is going to zone 79 and driver arrived at zone 79
# trip duration  16.823834196891184
# driver drops off passenger at time  2013-06-03 13:01:53.794828
# trip fare from  263 to  79  is 16.458549222797927
# driver total fare earned is  287.9041527667431
# fuel cost from  263 to  79  is 0.5082735403693339
# ************************trip is completed.**************************
# current time is  2013-06-03 13:01:53.794828 and driver is at zone  79
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 13:04:53.794828
# driver is going to zone 224 and driver arrived at zone 224
# trip duration  5.340999315537304
# driver drops off passenger at time  2013-06-03 13:10:14.254787
# trip fare from  79 to  224  is 5.663244353182751
# driver total fare earned is  293.56739711992583
# fuel cost from  79 to  224  is 0.10226065934880635
# ************************trip is completed.**************************
# current time is  2013-06-03 13:10:14.254787 and driver is at zone  224
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 13:13:14.254787
# driver is going to zone 140 and driver arrived at zone 140
# trip duration  12.409012345679018
# driver drops off passenger at time  2013-06-03 13:25:38.795528
# trip fare from  224 to  140  is 11.809259259259258
# driver total fare earned is  305.3766563791851
# fuel cost from  224 to  140  is 0.3242827601167953
# ************************trip is completed.**************************
# current time is  2013-06-03 13:25:38.795528 and driver is at zone  140
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 13:28:38.795528
# driver is going to zone 100 and driver arrived at zone 100
# trip duration  23.155013256206328
# driver drops off passenger at time  2013-06-03 13:51:48.096323
# trip fare from  140 to  100  is 16.287418655097614
# driver total fare earned is  321.6640750342827
# fuel cost from  140 to  100  is 0.3515828150647672
# ************************trip is completed.**************************
# current time is  2013-06-03 13:51:48.096323 and driver is at zone  100
# driver waited for  7  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 13:58:48.096323
# driver is going to zone 48 and driver arrived at zone 48
# trip duration  7.912207005530697
# driver drops off passenger at time  2013-06-03 14:06:42.828743
# trip fare from  100 to  48  is 6.874901237819331
# driver total fare earned is  328.53897627210205
# fuel cost from  100 to  48  is 0.09460420395001616
# ************************trip is completed.**************************
# current time is  2013-06-03 14:06:42.828743 and driver is at zone  48
# driver waited for  10  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 14:16:42.828743
# driver is going to zone 164 and driver arrived at zone 164
# trip duration  12.590752084396811
# driver drops off passenger at time  2013-06-03 14:29:18.273868
# trip fare from  48 to  164  is 9.451505870342013
# driver total fare earned is  337.9904821424441
# fuel cost from  48 to  164  is 0.1478412076284138
# ************************trip is completed.**************************
# current time is  2013-06-03 14:29:18.273868 and driver is at zone  164
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 14:33:18.273868
# driver is going to zone 231 and driver arrived at zone 231
# trip duration  18.516768627450976
# driver drops off passenger at time  2013-06-03 14:51:49.279986
# trip fare from  164 to  231  is 14.30164705882353
# driver total fare earned is  352.2921292012676
# fuel cost from  164 to  231  is 0.3353173472743345
# ************************trip is completed.**************************
# current time is  2013-06-03 14:51:49.279986 and driver is at zone  231
# driver waited for  2  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 14:53:49.279986
# driver is going to zone 144 and driver arrived at zone 144
# trip duration  9.898523531221164
# driver drops off passenger at time  2013-06-03 15:03:43.191398
# trip fare from  231 to  144  is 7.928944940018455
# driver total fare earned is  360.22107414128607
# fuel cost from  231 to  144  is 0.12295029575574777
# ************************trip is completed.**************************
# current time is  2013-06-03 15:03:43.191398 and driver is at zone  144
# driver waited for  2  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 15:05:43.191398
# driver is going to zone 112 and driver arrived at zone 112
# trip duration  15.89773882113821
# driver drops off passenger at time  2013-06-03 15:21:37.055727
# trip fare from  144 to  112  is 15.990091463414634
# driver total fare earned is  376.2111656047007
# fuel cost from  144 to  112  is 0.4990651635364117
# ************************trip is completed.**************************
# current time is  2013-06-03 15:21:37.055727 and driver is at zone  112
# driver does not get a pick up at the current zone: zone  112
# driver now decides to check reposition info after  7  min of crusing and current time is  2013-06-03 15:28:37.055727
# a_arr:  [ 5.4        34.6         7.00582764]
# near prob : [2.0825772910529e-13, 0.9999999999987541, 1.0375360843829538e-12]
# driver is repostioning to zone  255 and arrived at zone  255
# reposition trip duration  5.4192581300813 min
# After repositioning, it is now  2013-06-03 15:34:02.211215
# fuel cost from  112 to  255  is 0.12397591587271395
# ************************reposition is completed.**************************
# current time is  2013-06-03 15:34:02.211215 and driver is at zone  255
# driver waited for  10  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 15:44:02.211215
# driver is going to zone 144 and driver arrived at zone 144
# trip duration  15.343434343434344
# driver drops off passenger at time  2013-06-03 15:59:22.817276
# trip fare from  255 to  144  is 13.228956228956228
# driver total fare earned is  389.4401218336569
# fuel cost from  255 to  144  is 0.36576920719436773
# ************************trip is completed.**************************
# current time is  2013-06-03 15:59:22.817276 and driver is at zone  144
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 16:02:22.817276
# driver is going to zone 232 and driver arrived at zone 232
# trip duration  9.135045422781271
# driver drops off passenger at time  2013-06-03 16:11:30.920001
# trip fare from  144 to  232  is 7.670335429769392
# driver total fare earned is  397.1104572634263
# fuel cost from  144 to  232  is 0.13964327090739154
# ************************trip is completed.**************************
# total fare earned from this shift is  397.1104572634263
# total fuel cost is  15.86696584215092
# profit is  381.2434914212754

# %%
'''TODO: 
Monte Carlo Simulation'''
# Out:
# 'TODO: \nMonte Carlo Simulation'
