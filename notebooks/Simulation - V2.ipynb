# %%
import numpy as np
import pandas as pd 
import datetime as dt
from datetime import timedelta 
import random
from decimal import Decimal

# %%
class Driver: 
    

    
    def __init__(self, time, location, total_fare, total_cost, is_idle ):
        self.time = time 
        self.location = location 
        self.total_fare = total_fare
        self.total_cost  = total_cost
        self.is_idle = is_idle
    
    def set_time(self, new_time):
        self.time = new_time
    
    def get_time(self):
        return self.__time 
    
    def set_location(self, new_location):
        self.location = new_location
        
    def get_location(self):
        return self.__location 
   
    def set_total_fare(self, new_fare):
        self.total_fare = new_fare
    
    def get_total_fare(self):
        return self.total_fare 
    
    def set_is_idle(self, is_idle):
        self.is_idle = is_idle 
        
    def set_total_cost(self, new_cost):
        self.total_cost = new_cost
    
    def get_total_cost(self):
        return self.total_cost 
    
    def get_shift_time_weekday(self):


        weekend = [5,6]
        weekend_ind = lambda n: 0 if n in weekend else 1
        weekday = weekend_ind(self.time.weekday)

        normtime = driver.time.time()
        roundtime = pd.Timestamp(driver.time).round('30min').time()
        
        
        if weekday:
            if (normtime > dt.time(23, 30)) | (normtime <= dt.time(11, 30)):
                return ('A', roundtime,weekday)
            else:
                return ('B', roundtime,weekday)
        else: ## weekend
            if (normtime > dt.time(2, 0)) & (normtime <= dt.time(14, 0)):
                return ('A', roundtime,weekday)
            else:
                return ('B', roundtime,weekday)

# %%
class Env: 
    
    
    arrivals = pd.read_csv('../data/arrival_rates.csv')[['taxi_zone', 'time_stamp','arr_weekday','arr_weekend']]
    dropoff_counts = pd.read_csv('../data/pickup_dropoff_summary.csv')
    fare_df = pd.read_csv('../data/fare_amount_scr_dst_t.csv')
    dist_df = pd.read_csv('../data/trip_distance_scr_dst.csv')
    trip_time_df = pd.read_csv('../data/trip_time_scr_dst_t.csv')
    prob_df = pd.read_csv('../data/prob_match_combined_new.csv')
    trans_matrix = pd.read_csv('../data/dropoff_after_pickup.csv') # fix this to shift based and a
     # 0 weekend , A night shift 
    
    #time in 1..48,  isWeekday is a boolean
    def __init__(self,  isWeekday):   

        self.isWeekday = isWeekday 
        
    
    def is_matched(self, matching_prob):
        n = random.random()

        if n <= matching_prob:
            return True 
        else: 
            False 
    
    def get_destination(self, zone):
        prob = self.trans_matrix.iloc[zone-1].values[1:]
        n = random.random()

        count = 0
        for i in range(len(prob)):
            count = count + prob[i]
            if n<count:
                return i+1

    def get_adjacent_zone( self, taxi_zone ):
        df = pd.read_csv('../data/adjacent_zone.csv')
        adj_zone_1 = df.loc[df["zone1"]==taxi_zone, "zone2"].values.tolist()
        adj_zone_2 = df.loc[df["zone2"]==taxi_zone, "zone1"].values.tolist()
        adj_zone_list = list(filter(None, adj_zone_1+adj_zone_2))
        return(adj_zone_list)
    
    def get_demand(self, zone, time):
        #row = self.arrivals.loc[ ( self.arrivals['taxi_zone'] == zone ) & (self.arrivals['time_stamp'] == time ) ]
        row = self.prob_df.loc[ ( self.arrivals['taxi_zone'] == zone ) & (self.arrivals['time_stamp'] == time ) ]
       
        if self.isWeekday:
            return row['arr_weekday'].values[0]
        else:
            return row['arr_weekend'].values[0]
    
     #  def get_near_arrival():
    
    
    '''TODO： 
        fix policy fucntion - add randomness'''
   
       
            
    def reposition_to( self, current_zone, time ):
        #adj = self.get_adjacent_zone( current_zone )
        #adj.append( current_zone )
        #demand_list = [self.get_demand(zone, time) for zone in adj]
        #print(demand_list)
        # find the index of the max value of demand_lisy, and find which zone it is
        #return adj[demand_list.index( max(demand_list))]  
    
         
        adj = self.get_adjacent_zone( current_zone )
        adj.insert(0,current_zone)
        # find the index of the max value of near_prob, and find which zone it is 
        demand_list = [self.get_demand(zone, time) for zone in adj]
        a_arr  = np.array([Decimal(x) for x in demand_list]) #np.array(demand_list)
        print("a_arr: ", a_arr)
        #near_prob = list(np.exp((a_arr-a_arr[0])*10)/np.sum(np.exp((a_arr-a_arr[0])*10))) 
        near_prob = list(np.exp((a_arr-a_arr[0]))/np.sum(np.exp((a_arr-a_arr[0]))))
        print("near prob :", near_prob)  
        
        # 20, 28, 52
        
        r = random.random()
        #25
        
        count = 0
        for i in range(len(near_prob)):
            count = count + near_prob[i]
            if r < count:
                return(adj[i])  
        
        #repo_zone = adj[r_index]   
        
        #repo_prob = near_prob.index( max(near_prob))
        
    
        #print("r, repo, repo_prob", r, repo, repo_prob)
            
      
            
          
        #return (adj[near_prob.index( max(near_prob))],  is_repositioned)
    
        #SOFTMAX 
        #NEAR ARRIVAL 
        # return the highest prob of near arrival 
        
        
        ### paper's calculation of nearest prob
        # zone 1 = 10 , zone2 = 10.1 , zone 3 = 5
        # p(zone 1) = 10/25.5 = 0.392
        # p(zone 2) = 10.1/25.5 = 0.396
        # p(zone 3) = 5/25.5 = 0.196 
        
        
        # softmax suggestion way 
        # zone 1 = 10 , zone2 = 10.1 , zone 3 = 5
        # B  = 10 
        #exp(B * (rho1 - rho1) - e) / exp(B * (rho1 - rho1)) + exp(B * (rho2 - rho1)) + exp(B * (rho3 - rho1) - e) = 0.27
        #exp(B * (rho2 - rho1) - e) / exp(10) + exp(10.2) + exp(5)  = 0.73
        #exp(B * (rho3 - rho1) - e) / exp(10) + exp(10.2) + exp(5)  = 0.0
        
        
     
    def wait_time_before_pickup(self, matching_prob):
        if ( matching_prob >= 0.9 ):
            return random.randint(1,4)
        elif ( matching_prob >= 0.7 ):
            return random.randint(5,10)
        elif ( matching_prob >= 0.5 ):
            return random.randint(11,15)
        elif ( matching_prob >= 0.3 ):
            return random.randint(16,20)
        else:
            return random.randint(21,29)
        
    def wait_time_before_reposition(self):
        return random.randint(1,10)
    
    # can look into histortical data combined with random number 

    
    
    def get_trip_duration(self, start_zone, end_zone, shift_time):    
        shift,roundtime,weekday_ind = shift_time
        roundtime = roundtime.strftime('%H:%M:%S') 
        
        zone_to_zone = self.trip_time_df[(self.trip_time_df["pickup_taxizone_id"] == start_zone) & 
                                        (self.trip_time_df["dropoff_taxizone_id"] == end_zone) &
                                        (self.trip_time_df["actual_data"] == 1)]
        
        if len(zone_to_zone)!=0:
            if len(zone_to_zone[(zone_to_zone['_PU_shift']==shift) & (zone_to_zone['pickup_datetime_interval']==roundtime) &
                                (zone_to_zone['pickup_weekday'] == weekday_ind)])>0:

                dur = zone_to_zone.loc[(zone_to_zone["_PU_shift"] == shift) &
                                       (zone_to_zone["pickup_datetime_interval"] == roundtime) &
                                       (zone_to_zone['pickup_weekday'] == weekday_ind), "mean"].mean() 

            elif len(zone_to_zone[(zone_to_zone['_PU_shift']==shift) & (zone_to_zone['pickup_weekday'] == weekday_ind)])>0:
                dur = zone_to_zone.loc[(zone_to_zone["_PU_shift"] == shift) &
                                       (zone_to_zone['pickup_weekday'] == weekday_ind), "mean"].mean()

            else:
                dur = zone_to_zone['mean'].mean()
        else: 
            dur = self.trip_time_df.loc[(self.trip_time_df["pickup_taxizone_id"] == start_zone) & 
                                    (self.trip_time_df["dropoff_taxizone_id"] == end_zone) &
                                    (self.trip_time_df["actual_data"] == 0),"mean"].mean()
        
        return dur
        
    def get_fare(self, start_zone, end_zone, shift_time): 
        
        shift,roundtime,weekday_ind = shift_time
        roundtime = roundtime.strftime('%H:%M:%S') 
        
        zone_to_zone = self.fare_df[(self.fare_df["pickup_taxizone_id"] == start_zone) & 
                                    (self.fare_df["dropoff_taxizone_id"] == end_zone) &
                                    (self.fare_df["actual_data"] == 1)]
                
        if len(zone_to_zone)!=0:
            if len(zone_to_zone[(zone_to_zone['_PU_shift']==shift) & (zone_to_zone['pickup_datetime_interval']==roundtime) &
                                (zone_to_zone['pickup_weekday'] == weekday_ind)])>0:

                fare = zone_to_zone.loc[(zone_to_zone["_PU_shift"] == shift) &
                                       (zone_to_zone["pickup_datetime_interval"] == roundtime) &
                                       (zone_to_zone['pickup_weekday'] == weekday_ind), "mean"].mean() 

            elif len(zone_to_zone[(zone_to_zone['_PU_shift']==shift) & (zone_to_zone['pickup_weekday'] == weekday_ind)])>0:
                fare = zone_to_zone.loc[(zone_to_zone["_PU_shift"] == shift) &
                                       (zone_to_zone['pickup_weekday'] == weekday_ind), "mean"].mean()

            else:
                fare = zone_to_zone['mean'].mean()
        else:
            dur = self.fare_df.loc[(self.fare_df["pickup_taxizone_id"] == start_zone) & 
                                    (self.fare_df["dropoff_taxizone_id"] == end_zone) &
                                    (self.fare_df["actual_data"] == 0),"mean"].mean()
        
        return fare
    
    def get_trip_distance(self, start_zone, end_zone):
        zone_to_zone = self.dist_df.loc[((self.dist_df["pickup_taxizone_id"] == start_zone) &
                                 (self. dist_df["dropoff_taxizone_id"] == end_zone) &
                                 (self.trip_time_df["actual_data"] == 1)), "mean"]
        if len(zone_to_zone) != 0:
            dist = zone_to_zone.mean()
        else:
            dist = self.dist_df.loc[((self.dist_df["pickup_taxizone_id"] == start_zone) &
                                 (self. dist_df["dropoff_taxizone_id"] == end_zone) &
                                 (self.trip_time_df["actual_data"] == 0)), "mean"]
        
        return dist 
    
    def get_fuel_cost(self, start_zone, end_zone): 
        
        cost = self.dist_df.loc[((self.dist_df["pickup_taxizone_id"] == start_zone) &
                                 (self. dist_df["dropoff_taxizone_id"] == end_zone)), "mean"].mean()*0.124
        return cost 
    
    def get_matching_prob(self, zone, time):
        if self.isWeekday:
            prob = self.prob_df.loc[(self.prob_df['taxi_zone'] == zone) & 
                                    (self.prob_df['time_stamp'] == time)].mod_prob_match_weekday.values[0]
        else: 
            prob = self.prob_df.loc[(self.prob_df['taxi_zone'] == zone) & 
                                    (self.prob_df['time_stamp'] == time)].mod_prob_match_weekend.values[0]
            
        return prob 
    
    
    time_bins = [dt.time(0,0),dt.time(0,30), dt.time(1,0), dt.time(1,30), dt.time(2,0), 
        dt.time(2,30), dt.time(3,0), dt.time(3,30), dt.time(4,0),
        dt.time(4,30), dt.time(5,0), dt.time(5,30), dt.time(6,0),
        dt.time(6,30), dt.time(7,0), dt.time(7,30), dt.time(8,0),
        dt.time(8,30), dt.time(9,0), dt.time(9,30), dt.time(10,0),
        dt.time(10,30), dt.time(11,0), dt.time(11,30), dt.time(12,0),
        dt.time(12,30), dt.time(13,0), dt.time(13,30), dt.time(14,0),
        dt.time(14,30), dt.time(15,0), dt.time(15,30), dt.time(16,0), 
        dt.time(16,30), dt.time(17,0), dt.time(17,30), dt.time(18,0),
        dt.time(18,30), dt.time(19,0), dt.time(19,30), dt.time(20,0),
        dt.time(20,30), dt.time(21,0), dt.time(21,30), dt.time(22,0),
        dt.time(22,30), dt.time(23,0), dt.time(23,30), dt.time(23,59,59)] 
    
    
    def get_time_window(self, datetime):
        for i in range(0,48):
            if (datetime.time() >= self.time_bins[i]) & (datetime.time() < self.time_bins[i+1]): 
                return i+1 
            else :
                return 48
    
     
    def reposition_to_high( self, current_zone, time ):
        #adj = self.get_adjacent_zone( current_zone )
        #adj.append( current_zone )
        #demand_list = [self.get_demand(zone, time) for zone in adj]
        #print(demand_list)
        # find the index of the max value of demand_lisy, and find which zone it is
        #return adj[demand_list.index( max(demand_list))]  
    
         
        adj = self.get_adjacent_zone( current_zone )
        adj.insert(0,current_zone)
        # find the index of the max value of near_prob, and find which zone it is 
        demand_list = [self.get_demand(zone, time) for zone in adj]
        a_arr  = np.array(demand_list)
        print("a_arr: ", a_arr)
        #near_prob = list(np.exp((a_arr-a_arr[0])*10)/np.sum(np.exp((a_arr-a_arr[0])*10))) 
        near_prob = list(np.exp((a_arr-a_arr[0]))/np.sum(np.exp((a_arr-a_arr[0]))))
        print("near prob :", near_prob) 
        
        return(adj[near_prob.index( max(near_prob))])
    
    def reposition_to_any( self, current_zone, time ):
        #adj = self.get_adjacent_zone( current_zone )
        #adj.append( current_zone )
        #demand_list = [self.get_demand(zone, time) for zone in adj]
        #print(demand_list)
        # find the index of the max value of demand_lisy, and find which zone it is
        #return adj[demand_list.index( max(demand_list))]  
    
         
        adj = self.get_adjacent_zone( current_zone )
        adj.insert(0,current_zone)
        # find the index of the max value of near_prob, and find which zone it is 
        r = random.randint(0,len(adj)-1) 
        
        
        return(adj[r])

# %%
# one round of simulation 
#random.seed(500)
init_time = dt.datetime(2013, 6, 3, 5, 0, 0) 
init_zone = 12
avg_speed_waiting = 10 # defined in mph

#Initialize enviorment and driver 
env = Env( isWeekday = True ) 
driver = Driver( time = init_time, location = init_zone, total_fare = 0, total_cost = 0, is_idle = True) 

# print(driver.location)
# print(driver.time)
# print(driver.total_fare)
# print(driver.total_cost)
# print(driver.is_idle)


while driver.time < init_time + timedelta(seconds=0, minutes=0, hours = 11):
    #get prob that driver will be matched to a passenger 
    matching_prob = env.get_matching_prob( zone = driver.location, time = env.get_time_window(driver.time) )
    #print(matching_prob)
    start_zone = driver.location
    print('current time is ', driver.time, 'and driver is at zone ', driver.location)
    if env.is_matched(matching_prob):

        # time it takes before getting matched 
        wait_time = env.wait_time_before_pickup(matching_prob)
        print('driver waited for ', wait_time, ' min before he picks up')

        # cost of cruising
        driver.set_total_cost(driver.total_cost + avg_speed_waiting * wait_time/60 * 0.124)

        # set driver time to new time 
        driver.set_time( driver.time + timedelta(seconds=0, minutes= wait_time, hours=0 ) )
        print('driver gets a pick up and is now at time ', driver.time)    


        #driver is now busy 
        driver.set_is_idle(False)


        # find the destination of the trip and set destination 
        dest = env.get_destination(driver.location)
        driver.set_location(dest)
        print ('driver is going to zone', dest, 'and driver arrived at zone', driver.location)    

         # find the trip duration and update new time 
        duration = env.get_trip_duration(start_zone = start_zone, end_zone = dest, shift_time=driver.get_shift_time_weekday())
        print ('trip duration ', duration)
        driver.set_time( driver.time + timedelta(seconds=0, minutes= duration, hours=0 ) )
        print ('driver drops off passenger at time ', driver.time)


        #find trip fare and update fare 
        fare = env.get_fare( start_zone, dest, driver.get_shift_time_weekday())
        driver.set_total_fare(driver.total_fare + fare)
        print('trip fare from ', start_zone, 'to ', driver.location,   ' is',  fare)
        print('driver total fare earned is ', driver.total_fare )

        #frin trip cost and update cost 
        cost = env.get_fuel_cost(start_zone, dest)
        driver.set_total_cost(driver.total_cost + cost)
        print('fuel cost from ', start_zone, 'to ', driver.location,   ' is', cost  )

        print('************************trip is completed.************************** ')


    else: 
        #time it takes before reposition 
        print('driver does not get a pick up at the current zone: zone ', driver.location )
        
        wait_time = env.wait_time_before_reposition()
        driver.set_time( driver.time + timedelta(seconds=0, minutes= wait_time, hours=0 ) )
        print('driver now decides to check reposition info after ', wait_time, ' min of crusing and current time is ', driver.time)
       
        # cost of cruising
        driver.set_total_cost(driver.total_cost + avg_speed_waiting * wait_time/60 * 0.124)

        
        repo = env.reposition_to(driver.location, env.get_time_window(driver.time) ) #fix this to distribution 
        
        '''
            TODO:
            add cost - assume 10 miles a hour '''
                                                                       
                
        driver.set_location(repo)
        print('driver is repostioning to zone ', repo, 'and arrived at zone ', driver.location)

        # find the trip duration and update new time 
        duration = env.get_trip_duration(start_zone = start_zone, end_zone = repo, shift_time=driver.get_shift_time_weekday())
        print ('reposition trip duration ', duration , 'min')
        driver.set_time( driver.time + timedelta(seconds=0, minutes= duration, hours=0 ) )
        print ('After repositioning, it is now ', driver.time)

        #frin trip cost and update cost 
        cost = env.get_fuel_cost(start_zone, repo)
        driver.set_total_cost(driver.total_cost + cost)
        print('fuel cost from ', start_zone, 'to ', driver.location,   ' is', cost  )


        print('************************reposition is completed.************************** ')


        
print('total fare earned from this shift is ', driver.total_fare )
print('total fuel cost is ', driver.total_cost)
print('profit is ', driver.total_fare - driver.total_cost)
# Out:
# current time is  2013-06-03 05:00:00 and driver is at zone  12
# driver waited for  18  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 05:18:00
# driver is going to zone 246 and driver arrived at zone 246
# trip duration  13.47936507936508
# driver drops off passenger at time  2013-06-03 05:31:28.761905
# trip fare from  12 to  246  is 13.476190476190476
# driver total fare earned is  13.476190476190476
# fuel cost from  12 to  246  is 0.3967336568473071
# ************************trip is completed.**************************
# current time is  2013-06-03 05:31:28.761905 and driver is at zone  246
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 05:34:28.761905
# driver is going to zone 116 and driver arrived at zone 116
# trip duration  16.115311653116528
# driver drops off passenger at time  2013-06-03 05:50:35.680604
# trip fare from  246 to  116  is 21.5609756097561
# driver total fare earned is  35.03716608594657
# fuel cost from  246 to  116  is 0.7725066012506647
# ************************trip is completed.**************************
# current time is  2013-06-03 05:50:35.680604 and driver is at zone  116
# driver does not get a pick up at the current zone: zone  116
# driver now decides to check reposition info after  8  min of crusing and current time is  2013-06-03 05:58:35.680604
# a_arr:  [Decimal('14.070117187499999289457264239899814128875732421875')
#  Decimal('1.554667968750000017763568394002504646778106689453125')
#  Decimal('13.8290902709960956684653865522705018520355224609375')
#  Decimal('15.8999996948242152683405947755090892314910888671875')
#  Decimal('10.0586718749999999289457264239899814128875732421875')]
# near prob : [Decimal('0.1244232110815428489700853214'), Decimal('4.565736788077961445367778978E-7'), Decimal('0.09777430677885098869507891544'), Decimal('0.7755490688834753954482486621'), Decimal('0.002252956682451959090442564294')]
# driver is repostioning to zone  244 and arrived at zone  244
# reposition trip duration  5.874171539961014 min
# After repositioning, it is now  2013-06-03 06:04:28.130896
# fuel cost from  116 to  244  is 0.15124122299700157
# ************************reposition is completed.**************************
# current time is  2013-06-03 06:04:28.130896 and driver is at zone  244
# driver waited for  21  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 06:25:28.130896
# driver is going to zone 116 and driver arrived at zone 116
# trip duration  4.937962962962962
# driver drops off passenger at time  2013-06-03 06:30:24.408674
# trip fare from  244 to  116  is 6.05
# driver total fare earned is  41.08716608594657
# fuel cost from  244 to  116  is 0.12470368100394937
# ************************trip is completed.**************************
# current time is  2013-06-03 06:30:24.408674 and driver is at zone  116
# driver does not get a pick up at the current zone: zone  116
# driver now decides to check reposition info after  10  min of crusing and current time is  2013-06-03 06:40:24.408674
# a_arr:  [Decimal('14.070117187499999289457264239899814128875732421875')
#  Decimal('1.554667968750000017763568394002504646778106689453125')
#  Decimal('13.8290902709960956684653865522705018520355224609375')
#  Decimal('15.8999996948242152683405947755090892314910888671875')
#  Decimal('10.0586718749999999289457264239899814128875732421875')]
# near prob : [Decimal('0.1244232110815428489700853214'), Decimal('4.565736788077961445367778978E-7'), Decimal('0.09777430677885098869507891544'), Decimal('0.7755490688834753954482486621'), Decimal('0.002252956682451959090442564294')]
# driver is repostioning to zone  244 and arrived at zone  244
# reposition trip duration  5.874171539961014 min
# After repositioning, it is now  2013-06-03 06:46:16.858966
# fuel cost from  116 to  244  is 0.15124122299700157
# ************************reposition is completed.**************************
# current time is  2013-06-03 06:46:16.858966 and driver is at zone  244
# driver does not get a pick up at the current zone: zone  244
# driver now decides to check reposition info after  7  min of crusing and current time is  2013-06-03 06:53:16.858966
# a_arr:  [Decimal('15.8999996948242152683405947755090892314910888671875')
#  Decimal('14.070117187499999289457264239899814128875732421875')
#  Decimal('1.554667968750000017763568394002504646778106689453125')
#  Decimal('5.0520983886718742184029906638897955417633056640625')]
# near prob : [Decimal('0.8617328522737288005534079695'), Decimal('0.1382498836968672231887550329'), Decimal('5.073109546486551263022698782E-7'), Decimal('0.00001675671844932760271069536531')]
# driver is repostioning to zone  244 and arrived at zone  244
# reposition trip duration  5.73461221122112 min
# After repositioning, it is now  2013-06-03 06:59:00.935699
# fuel cost from  244 to  244  is 0.13562578339873213
# ************************reposition is completed.**************************
# current time is  2013-06-03 06:59:00.935699 and driver is at zone  244
# driver waited for  27  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 07:26:00.935699
# driver is going to zone 74 and driver arrived at zone 74
# trip duration  15.292207792207789
# driver drops off passenger at time  2013-06-03 07:41:18.468167
# trip fare from  244 to  74  is 14.37012987012987
# driver total fare earned is  55.45729595607644
# fuel cost from  244 to  74  is 0.37345077534230753
# ************************trip is completed.**************************
# current time is  2013-06-03 07:41:18.468167 and driver is at zone  74
# driver waited for  17  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 07:58:18.468167
# driver is going to zone 75 and driver arrived at zone 75
# trip duration  5.768959107806691
# driver drops off passenger at time  2013-06-03 08:04:04.605713
# trip fare from  74 to  75  is 6.1627013630731104
# driver total fare earned is  61.619997319149554
# fuel cost from  74 to  75  is 0.11843058082255309
# ************************trip is completed.**************************
# current time is  2013-06-03 08:04:04.605713 and driver is at zone  75
# driver does not get a pick up at the current zone: zone  75
# driver now decides to check reposition info after  5  min of crusing and current time is  2013-06-03 08:09:04.605713
# a_arr:  [Decimal('54.88283309936525000694018672220408916473388671875')
#  Decimal('170.105852508544927559341886080801486968994140625')
#  Decimal('57.63484863281249914734871708787977695465087890625')
#  Decimal('167.50216415405276393357780762016773223876953125')
#  Decimal('38.5665325927734414790393202565610408782958984375')
#  Decimal('76.7845440673828107946974341757595539093017578125')
#  Decimal('29.186279296875003552713678800500929355621337890625')]
# near prob : [Decimal('8.477623910031283892905777924E-51'), Decimal('0.9310985789775804123632012408'), Decimal('1.328799042459228403267511309E-49'), Decimal('0.06890142102241958763679875929'), Decimal('6.953362500638404276202166286E-58'), Decimal('2.754649604809376115310829280E-41'), Decimal('5.866818136100229145354994381E-62')]
# driver is repostioning to zone  263 and arrived at zone  263
# reposition trip duration  5.732915831663326 min
# After repositioning, it is now  2013-06-03 08:14:48.580663
# fuel cost from  75 to  263  is 0.1125147498319103
# ************************reposition is completed.**************************
# current time is  2013-06-03 08:14:48.580663 and driver is at zone  263
# driver does not get a pick up at the current zone: zone  263
# driver now decides to check reposition info after  10  min of crusing and current time is  2013-06-03 08:24:48.580663
# a_arr:  [Decimal('167.50216415405276393357780762016773223876953125')
#  Decimal('54.88283309936525000694018672220408916473388671875')
#  Decimal('111.540734863281244315658113919198513031005859375')
#  Decimal('227.785580749511694875764078460633754730224609375')
#  Decimal('170.105852508544927559341886080801486968994140625')
#  Decimal('57.63484863281249914734871708787977695465087890625')]
# near prob : [Decimal('6.595455922905321072082969085E-27'), Decimal('8.115042331476154584821730096E-76'), Decimal('3.277214607104018340080142190E-51'), Decimal('0.9999999999999999999999999044'), Decimal('8.912761952366999982361487011E-26'), Decimal('1.271967309946617636802321813E-74')]
# driver is repostioning to zone  141 and arrived at zone  141
# reposition trip duration  5.506953642384099 min
# After repositioning, it is now  2013-06-03 08:30:18.997882
# fuel cost from  263 to  141  is 0.11471380993158653
# ************************reposition is completed.**************************
# current time is  2013-06-03 08:30:18.997882 and driver is at zone  141
# driver waited for  5  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 08:35:18.997882
# driver is going to zone 229 and driver arrived at zone 229
# trip duration  7.344907922382888
# driver drops off passenger at time  2013-06-03 08:42:39.692357
# trip fare from  141 to  229  is 6.833889506859474
# driver total fare earned is  68.45388682600903
# fuel cost from  141 to  229  is 0.11051237207469507
# ************************trip is completed.**************************
# current time is  2013-06-03 08:42:39.692357 and driver is at zone  229
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 08:43:39.692357
# driver is going to zone 238 and driver arrived at zone 238
# trip duration  16.02738343771747
# driver drops off passenger at time  2013-06-03 08:59:41.335363
# trip fare from  229 to  238  is 13.98643006263048
# driver total fare earned is  82.4403168886395
# fuel cost from  229 to  238  is 0.34965289342990796
# ************************trip is completed.**************************
# current time is  2013-06-03 08:59:41.335363 and driver is at zone  238
# driver waited for  14  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 09:13:41.335363
# driver is going to zone 75 and driver arrived at zone 75
# trip duration  8.418206204805227
# driver drops off passenger at time  2013-06-03 09:22:06.427735
# trip fare from  238 to  75  is 8.074527641707487
# driver total fare earned is  90.51484453034699
# fuel cost from  238 to  75  is 0.2035567139955283
# ************************trip is completed.**************************
# current time is  2013-06-03 09:22:06.427735 and driver is at zone  75
# driver waited for  20  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 09:42:06.427735
# driver is going to zone 238 and driver arrived at zone 238
# trip duration  7.377799607072698
# driver drops off passenger at time  2013-06-03 09:49:29.095711
# trip fare from  75 to  238  is 7.653241650294696
# driver total fare earned is  98.1680861806417
# fuel cost from  75 to  238  is 0.1917269850645532
# ************************trip is completed.**************************
# current time is  2013-06-03 09:49:29.095711 and driver is at zone  238
# driver does not get a pick up at the current zone: zone  238
# driver now decides to check reposition info after  7  min of crusing and current time is  2013-06-03 09:56:29.095711
# a_arr:  [Decimal('119.45074890136720568989403545856475830078125')
#  Decimal('209.06707077026368324368377216160297393798828125')
#  Decimal('76.7845440673828107946974341757595539093017578125')
#  Decimal('46.199118881225587074368377216160297393798828125')]
# near prob : [Decimal('1.202613082252168039798420349E-39'), Decimal('1'), Decimal('3.551637237292551087259144723E-58'), Decimal('1.850747688781283613715821637E-71')]
# driver is repostioning to zone  239 and arrived at zone  239
# reposition trip duration  4.525886524822692 min
# After repositioning, it is now  2013-06-03 10:01:00.648902
# fuel cost from  238 to  239  is 0.0946274325764142
# ************************reposition is completed.**************************
# current time is  2013-06-03 10:01:00.648902 and driver is at zone  239
# driver does not get a pick up at the current zone: zone  239
# driver now decides to check reposition info after  5  min of crusing and current time is  2013-06-03 10:06:00.648902
# a_arr:  [Decimal('209.06707077026368324368377216160297393798828125')
#  Decimal('76.7845440673828107946974341757595539093017578125')
#  Decimal('321.12511148452762199667631648480892181396484375')
#  Decimal('69.4480053710937426103555480949580669403076171875')
#  Decimal('119.45074890136720568989403545856475830078125')]
# near prob : [Decimal('2.156806903299030346269775073E-49'), Decimal('7.660195711406470528372897384E-107'), Decimal('1'), Decimal('4.989092931129385886834599046E-110'), Decimal('2.593804197799200621367639037E-88')]
# driver is repostioning to zone  142 and arrived at zone  142
# reposition trip duration  5.410203082945924 min
# After repositioning, it is now  2013-06-03 10:11:25.261087
# fuel cost from  239 to  142  is 0.09833458025669344
# ************************reposition is completed.**************************
# current time is  2013-06-03 10:11:25.261087 and driver is at zone  142
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 10:15:25.261087
# driver is going to zone 237 and driver arrived at zone 237
# trip duration  9.45259150915094
# driver drops off passenger at time  2013-06-03 10:24:52.416578
# trip fare from  142 to  237  is 8.166404140414041
# driver total fare earned is  106.33449032105574
# fuel cost from  142 to  237  is 0.16163692271250643
# ************************trip is completed.**************************
# current time is  2013-06-03 10:24:52.416578 and driver is at zone  237
# driver waited for  2  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 10:26:52.416578
# driver is going to zone 237 and driver arrived at zone 237
# trip duration  5.711570943407556
# driver drops off passenger at time  2013-06-03 10:32:35.110835
# trip fare from  237 to  237  is 5.720539175908394
# driver total fare earned is  112.05502949696414
# fuel cost from  237 to  237  is 0.08128115718237208
# ************************trip is completed.**************************
# current time is  2013-06-03 10:32:35.110835 and driver is at zone  237
# driver waited for  1  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 10:33:35.110835
# driver is going to zone 142 and driver arrived at zone 142
# trip duration  8.774782696583802
# driver drops off passenger at time  2013-06-03 10:42:21.597797
# trip fare from  237 to  142  is 7.867647058823529
# driver total fare earned is  119.92267655578766
# fuel cost from  237 to  142  is 0.16209070983443907
# ************************trip is completed.**************************
# current time is  2013-06-03 10:42:21.597797 and driver is at zone  142
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 10:45:21.597797
# driver is going to zone 164 and driver arrived at zone 164
# trip duration  15.425117370892014
# driver drops off passenger at time  2013-06-03 11:00:47.104839
# trip fare from  142 to  164  is 11.764788732394369
# driver total fare earned is  131.68746528818204
# fuel cost from  142 to  164  is 0.2318730771192253
# ************************trip is completed.**************************
# current time is  2013-06-03 11:00:47.104839 and driver is at zone  164
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 11:04:47.104839
# driver is going to zone 161 and driver arrived at zone 161
# trip duration  8.11491923059994
# driver drops off passenger at time  2013-06-03 11:12:53.999993
# trip fare from  164 to  161  is 7.091047141159382
# driver total fare earned is  138.77851242934142
# fuel cost from  164 to  161  is 0.12090870123816451
# ************************trip is completed.**************************
# current time is  2013-06-03 11:12:53.999993 and driver is at zone  161
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 11:15:53.999993
# driver is going to zone 233 and driver arrived at zone 233
# trip duration  8.205997079682927
# driver drops off passenger at time  2013-06-03 11:24:06.359818
# trip fare from  161 to  233  is 6.997352941176471
# driver total fare earned is  145.7758653705179
# fuel cost from  161 to  233  is 0.11004347761441421
# ************************trip is completed.**************************
# current time is  2013-06-03 11:24:06.359818 and driver is at zone  233
# driver does not get a pick up at the current zone: zone  233
# driver now decides to check reposition info after  6  min of crusing and current time is  2013-06-03 11:30:06.359818
# a_arr:  [Decimal('144.760621261596725162235088646411895751953125')
#  Decimal('156.147211284637506878425483591854572296142578125')
#  Decimal('386.44751571655280031336587853729724884033203125')
#  Decimal('377.94999999999998863131622783839702606201171875')
#  Decimal('255.02719879150390625')]
# near prob : [Decimal('1.087994785570599120586438547E-105'), Decimal('9.588706568060573085106703588E-101'), Decimal('0.9997960671265985789133534300'), Decimal('0.0002039328734014210866465700257'), Decimal('8.409941474596181446043089168E-58')]
# driver is repostioning to zone  162 and arrived at zone  162
# reposition trip duration  7.072911246024865 min
# After repositioning, it is now  2013-06-03 11:37:10.734493
# fuel cost from  233 to  162  is 0.08435453597986581
# ************************reposition is completed.**************************
# current time is  2013-06-03 11:37:10.734493 and driver is at zone  162
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 11:40:10.734493
# driver is going to zone 95 and driver arrived at zone 95
# trip duration  27.428255208333336
# driver drops off passenger at time  2013-06-03 12:07:36.429806
# trip fare from  162 to  95  is 28.609375
# driver total fare earned is  174.3852403705179
# fuel cost from  162 to  95  is 1.0826433444509502
# ************************trip is completed.**************************
# current time is  2013-06-03 12:07:36.429806 and driver is at zone  95
# driver does not get a pick up at the current zone: zone  95
# driver now decides to check reposition info after  4  min of crusing and current time is  2013-06-03 12:11:36.429806
# a_arr:  [Decimal('4.60546875000000088817841970012523233890533447265625')
#  Decimal('1.000000000000003108624468950438313186168670654296875')
#  Decimal('1.000000000000003996802888650563545525074005126953125')
#  Decimal('2.16863281250000472510919280466623604297637939453125')
#  Decimal('2.043305664062499804600747665972448885440826416015625')
#  Decimal('1.20000000000000017763568394002504646778106689453125')
#  Decimal('1.855805664062497584154698415659368038177490234375')]
# near prob : [Decimal('0.7598409797311673765220815707'), Decimal('0.02064845347171131048040306798'), Decimal('0.02064845347171132881991384174'), Decimal('0.06643826938985165368529435041'), Decimal('0.05861238886132084436682245765'), Decimal('0.02522007802209005504408375541'), Decimal('0.04859137705214743108140095551')]
# driver is repostioning to zone  95 and arrived at zone  95
# reposition trip duration  7.560611979166666 min
# After repositioning, it is now  2013-06-03 12:19:10.066525
# fuel cost from  95 to  95  is 0.1463706224117085
# ************************reposition is completed.**************************
# current time is  2013-06-03 12:19:10.066525 and driver is at zone  95
# driver does not get a pick up at the current zone: zone  95
# driver now decides to check reposition info after  10  min of crusing and current time is  2013-06-03 12:29:10.066525
# a_arr:  [Decimal('4.60546875000000088817841970012523233890533447265625')
#  Decimal('1.000000000000003108624468950438313186168670654296875')
#  Decimal('1.000000000000003996802888650563545525074005126953125')
#  Decimal('2.16863281250000472510919280466623604297637939453125')
#  Decimal('2.043305664062499804600747665972448885440826416015625')
#  Decimal('1.20000000000000017763568394002504646778106689453125')
#  Decimal('1.855805664062497584154698415659368038177490234375')]
# near prob : [Decimal('0.7598409797311673765220815707'), Decimal('0.02064845347171131048040306798'), Decimal('0.02064845347171132881991384174'), Decimal('0.06643826938985165368529435041'), Decimal('0.05861238886132084436682245765'), Decimal('0.02522007802209005504408375541'), Decimal('0.04859137705214743108140095551')]
# driver is repostioning to zone  196 and arrived at zone  196
# reposition trip duration  8.613636363636365 min
# After repositioning, it is now  2013-06-03 12:37:46.884707
# fuel cost from  95 to  196  is 0.16071569758984816
# ************************reposition is completed.**************************
# current time is  2013-06-03 12:37:46.884707 and driver is at zone  196
# driver does not get a pick up at the current zone: zone  196
# driver now decides to check reposition info after  9  min of crusing and current time is  2013-06-03 12:46:46.884707
# a_arr:  [Decimal('2.043305664062499804600747665972448885440826416015625')
#  Decimal('1.20000000000000017763568394002504646778106689453125')
#  Decimal('3.58179687500000110134124042815528810024261474609375')
#  Decimal('4.60546875000000088817841970012523233890533447265625')
#  Decimal('1.000000000000003996802888650563545525074005126953125')
#  Decimal('1.93757812500000792255150372511707246303558349609375')]
# near prob : [Decimal('0.04925227579326118779285060857'), Decimal('0.02119255437976619688585033648'), Decimal('0.2293953161111219033767387368'), Decimal('0.6384980755738793347719989845'), Decimal('0.01735099600699212738715127035'), Decimal('0.04431078213497924978541006336')]
# driver is repostioning to zone  56 and arrived at zone  56
# reposition trip duration  7.034999999999999 min
# After repositioning, it is now  2013-06-03 12:53:48.984707
# fuel cost from  196 to  56  is 0.14102957249407663
# ************************reposition is completed.**************************
# current time is  2013-06-03 12:53:48.984707 and driver is at zone  56
# driver does not get a pick up at the current zone: zone  56
# driver now decides to check reposition info after  1  min of crusing and current time is  2013-06-03 12:54:48.984707
# a_arr:  [Decimal('1.20000000000000017763568394002504646778106689453125')
#  Decimal('0')
#  Decimal('3.58179687500000110134124042815528810024261474609375')
#  Decimal('1.855805664062497584154698415659368038177490234375')
#  Decimal('4.60546875000000088817841970012523233890533447265625')
#  Decimal('1.63007812500000337507799486047588288784027099609375')
#  Decimal('2.043305664062499804600747665972448885440826416015625')]
# near prob : [Decimal('0.02081509702601191799116787510'), Decimal('0.006269386744625680151276420428'), Decimal('0.2253095911234064004277155903'), Decimal('0.04010432588995446345580628403'), Decimal('0.6271258837340217118037548847'), Decimal('0.03200066446087965208961316204'), Decimal('0.04837505102110017408066578346')]
# driver is repostioning to zone  95 and arrived at zone  95
# reposition trip duration  29.416666666666668 min
# After repositioning, it is now  2013-06-03 13:24:13.984707
# fuel cost from  56 to  95  is 0.4086085468725653
# ************************reposition is completed.**************************
# current time is  2013-06-03 13:24:13.984707 and driver is at zone  95
# driver does not get a pick up at the current zone: zone  95
# driver now decides to check reposition info after  5  min of crusing and current time is  2013-06-03 13:29:13.984707
# a_arr:  [Decimal('4.60546875000000088817841970012523233890533447265625')
#  Decimal('1.000000000000003108624468950438313186168670654296875')
#  Decimal('1.000000000000003996802888650563545525074005126953125')
#  Decimal('2.16863281250000472510919280466623604297637939453125')
#  Decimal('2.043305664062499804600747665972448885440826416015625')
#  Decimal('1.20000000000000017763568394002504646778106689453125')
#  Decimal('1.855805664062497584154698415659368038177490234375')]
# near prob : [Decimal('0.7598409797311673765220815707'), Decimal('0.02064845347171131048040306798'), Decimal('0.02064845347171132881991384174'), Decimal('0.06643826938985165368529435041'), Decimal('0.05861238886132084436682245765'), Decimal('0.02522007802209005504408375541'), Decimal('0.04859137705214743108140095551')]
# driver is repostioning to zone  95 and arrived at zone  95
# reposition trip duration  7.560611979166666 min
# After repositioning, it is now  2013-06-03 13:36:47.621426
# fuel cost from  95 to  95  is 0.1463706224117085
# ************************reposition is completed.**************************
# current time is  2013-06-03 13:36:47.621426 and driver is at zone  95
# driver does not get a pick up at the current zone: zone  95
# driver now decides to check reposition info after  9  min of crusing and current time is  2013-06-03 13:45:47.621426
# a_arr:  [Decimal('4.60546875000000088817841970012523233890533447265625')
#  Decimal('1.000000000000003108624468950438313186168670654296875')
#  Decimal('1.000000000000003996802888650563545525074005126953125')
#  Decimal('2.16863281250000472510919280466623604297637939453125')
#  Decimal('2.043305664062499804600747665972448885440826416015625')
#  Decimal('1.20000000000000017763568394002504646778106689453125')
#  Decimal('1.855805664062497584154698415659368038177490234375')]
# near prob : [Decimal('0.7598409797311673765220815707'), Decimal('0.02064845347171131048040306798'), Decimal('0.02064845347171132881991384174'), Decimal('0.06643826938985165368529435041'), Decimal('0.05861238886132084436682245765'), Decimal('0.02522007802209005504408375541'), Decimal('0.04859137705214743108140095551')]
# driver is repostioning to zone  95 and arrived at zone  95
# reposition trip duration  7.560611979166666 min
# After repositioning, it is now  2013-06-03 13:53:21.258145
# fuel cost from  95 to  95  is 0.1463706224117085
# ************************reposition is completed.**************************
# current time is  2013-06-03 13:53:21.258145 and driver is at zone  95
# driver does not get a pick up at the current zone: zone  95
# driver now decides to check reposition info after  10  min of crusing and current time is  2013-06-03 14:03:21.258145
# a_arr:  [Decimal('4.60546875000000088817841970012523233890533447265625')
#  Decimal('1.000000000000003108624468950438313186168670654296875')
#  Decimal('1.000000000000003996802888650563545525074005126953125')
#  Decimal('2.16863281250000472510919280466623604297637939453125')
#  Decimal('2.043305664062499804600747665972448885440826416015625')
#  Decimal('1.20000000000000017763568394002504646778106689453125')
#  Decimal('1.855805664062497584154698415659368038177490234375')]
# near prob : [Decimal('0.7598409797311673765220815707'), Decimal('0.02064845347171131048040306798'), Decimal('0.02064845347171132881991384174'), Decimal('0.06643826938985165368529435041'), Decimal('0.05861238886132084436682245765'), Decimal('0.02522007802209005504408375541'), Decimal('0.04859137705214743108140095551')]
# driver is repostioning to zone  95 and arrived at zone  95
# reposition trip duration  7.560611979166666 min
# After repositioning, it is now  2013-06-03 14:10:54.894864
# fuel cost from  95 to  95  is 0.1463706224117085
# ************************reposition is completed.**************************
# current time is  2013-06-03 14:10:54.894864 and driver is at zone  95
# driver does not get a pick up at the current zone: zone  95
# driver now decides to check reposition info after  10  min of crusing and current time is  2013-06-03 14:20:54.894864
# a_arr:  [Decimal('4.60546875000000088817841970012523233890533447265625')
#  Decimal('1.000000000000003108624468950438313186168670654296875')
#  Decimal('1.000000000000003996802888650563545525074005126953125')
#  Decimal('2.16863281250000472510919280466623604297637939453125')
#  Decimal('2.043305664062499804600747665972448885440826416015625')
#  Decimal('1.20000000000000017763568394002504646778106689453125')
#  Decimal('1.855805664062497584154698415659368038177490234375')]
# near prob : [Decimal('0.7598409797311673765220815707'), Decimal('0.02064845347171131048040306798'), Decimal('0.02064845347171132881991384174'), Decimal('0.06643826938985165368529435041'), Decimal('0.05861238886132084436682245765'), Decimal('0.02522007802209005504408375541'), Decimal('0.04859137705214743108140095551')]
# driver is repostioning to zone  93 and arrived at zone  93
# reposition trip duration  11.32843137254902 min
# After repositioning, it is now  2013-06-03 14:32:14.600746
# fuel cost from  95 to  93  is 0.30906541887432115
# ************************reposition is completed.**************************
# current time is  2013-06-03 14:32:14.600746 and driver is at zone  93
# driver does not get a pick up at the current zone: zone  93
# driver now decides to check reposition info after  5  min of crusing and current time is  2013-06-03 14:37:14.600746
# a_arr:  [Decimal('1.855805664062497584154698415659368038177490234375')
#  Decimal('4.60546875000000088817841970012523233890533447265625')
#  Decimal('2.16863281250000472510919280466623604297637939453125')
#  Decimal('0') Decimal('325.11264240264887348530464805662631988525390625')
#  Decimal('1.63007812500000337507799486047588288784027099609375')
#  Decimal('1.554667968750000017763568394002504646778106689453125')
#  Decimal('0')
#  Decimal('1.461591796875003179678742526448331773281097412109375')
#  Decimal('1.20000000000000017763568394002504646778106689453125')
#  Decimal('0')
#  Decimal('3.819221191406251936228954946273006498813629150390625')
#  Decimal('1.554667968750000017763568394002504646778106689453125')]
# near prob : [Decimal('4.086387686542915424856779162E-141'), Decimal('6.390032577121470568585881956E-140'), Decimal('5.587257295847980959040871660E-141'), Decimal('6.388125028135921656147892889E-142'), Decimal('1'), Decimal('3.260673713178789780203398353E-141'), Decimal('3.023828301986064524392063778E-141'), Decimal('6.388125028135921656147892889E-142'), Decimal('2.755082826963604764981324351E-141'), Decimal('2.120932201047096082645748190E-141'), Decimal('6.388125028135921656147892889E-142'), Decimal('2.910985861773932062019627109E-140'), Decimal('3.023828301986064524392063778E-141')]
# driver is repostioning to zone  138 and arrived at zone  138
# reposition trip duration  14.683333333333335 min
# After repositioning, it is now  2013-06-03 14:51:55.600746
# fuel cost from  93 to  138  is 0.522558170313624
# ************************reposition is completed.**************************
# current time is  2013-06-03 14:51:55.600746 and driver is at zone  138
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 14:54:55.600746
# driver is going to zone 234 and driver arrived at zone 234
# trip duration  28.49906424992628
# driver drops off passenger at time  2013-06-03 15:23:25.544601
# trip fare from  138 to  234  is 30.659151193633956
# driver total fare earned is  205.04439156415185
# fuel cost from  138 to  234  is 1.1860678500408048
# ************************trip is completed.**************************
# current time is  2013-06-03 15:23:25.544601 and driver is at zone  234
# driver waited for  4  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 15:27:25.544601
# driver is going to zone 68 and driver arrived at zone 68
# trip duration  8.593249478193972
# driver drops off passenger at time  2013-06-03 15:36:01.139570
# trip fare from  234 to  68  is 7.3536746127650225
# driver total fare earned is  212.39806617691687
# fuel cost from  234 to  68  is 0.12706798198021724
# ************************trip is completed.**************************
# current time is  2013-06-03 15:36:01.139570 and driver is at zone  68
# driver waited for  3  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 15:39:01.139570
# driver is going to zone 230 and driver arrived at zone 230
# trip duration  12.144141355516853
# driver drops off passenger at time  2013-06-03 15:51:09.788051
# trip fare from  68 to  230  is 9.38905010640356
# driver total fare earned is  221.78711628332044
# fuel cost from  68 to  230  is 0.17576803147789652
# ************************trip is completed.**************************
# current time is  2013-06-03 15:51:09.788051 and driver is at zone  230
# driver waited for  2  min before he picks up
# driver gets a pick up and is now at time  2013-06-03 15:53:09.788051
# driver is going to zone 163 and driver arrived at zone 163
# trip duration  8.369068886182186
# driver drops off passenger at time  2013-06-03 16:01:31.932184
# trip fare from  230 to  163  is 7.028894302341318
# driver total fare earned is  228.81601058566176
# fuel cost from  230 to  163  is 0.10297477638186442
# ************************trip is completed.**************************
# total fare earned from this shift is  228.81601058566176
# total fuel cost is  15.019743523624804
# profit is  213.79626706203695

# %%
'''TODO: 
Monte Carlo Simulation'''
# Out:
# 'TODO: \nMonte Carlo Simulation'
